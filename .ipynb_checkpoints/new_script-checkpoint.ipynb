# %%
import re
import os
import pandas as pd
import numpy as np
import csv
import jieba
import jieba.posseg as pseg

# %%
#import theano

# %%
#pip install theano-pymc==1.1.2

# %%
#conda install -c conda-forge arviz

# %%
#import theano
#import theano.tensor as tt

# %%
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
 
# spacy for lemmatization
import spacy
 
# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
#读入数据
group_3 = pd.read_csv('D:\my_research\gensim_group\group_3\group_3.csv',encoding='utf-8')
group_3.columns = ['0','content','date','time','user_id']
group_3 = group_3.drop(columns='0')
group_3_del = group_3.dropna(axis=0, how='any')
#group_1 = group_1[0:100]
group_3_del.head()
# Out:
#                                 content        date                 time  \
# 0                 好的，我知道了～拜拜啦您～不懂事的小屁孩   2022-08-01  2022-08-01 16:49:32
# 1              太开心啦，一次成功！小朋友太爱吃了～为娘很欣慰   2022-07-31  2022-07-31 11:27:09
# 2                 南汇好朋友的再次投喂～🍇葡萄太好吃了吧！   2022-07-30  2022-07-30 20:16:07
# 3  周五ootd9.9的F21的T恤真香～我真是省钱小能手包包也是同事送的   2022-07-29  2022-07-29 08:59:32
# 4         小可爱太乖了～以后妈妈多带你出门哈 上海·上海月星环球港   2022-07-24  2022-07-24 13:32:46
#
#       user_id
# 0  1000347570
# 1  1000347570
# 2  1000347570
# 3  1000347570
# 4  1000347570

# %%
#cloud=[]
#with open('D:\my research\cloud.txt', 'r', encoding='utf-8') as f:
#    for ann in f.readlines():
#        ann = ann.strip('\n') #去除文本中的换行符
#        cloud.append(ann)
#        print(ann)

# %%
def clean(text):
    text = re.sub(r"(回复)?(//)?\s*@\S*?\s*(:| |$)", " ", text)  # 去除正文中的@和回复/转发中的用户名
    text = re.sub(r"\[\S+\]", "", text)      # 去除表情符号
    text = re.sub(r"#\S+#", "", text)      # 保留话题内容
    URL_REGEX = re.compile(
        r'(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’]))',
        re.IGNORECASE)
    text = re.sub(URL_REGEX, "", text)       # 去除网址
    text = text.replace('转发微博','') # 去除无意义的词语
    text = text.replace('网页链接','')
    text = text.replace('的微博视频','')
    text = text.replace('妞妞端午花草','')
    text = text.replace('bluepoint2006','')
    text = text.replace('上海','')
    text = text.replace('博','')
    text = re.sub(r"\s+", " ", text) # 合并正文中过多的空格
    return text.strip()

# %%
count = []
for i in group_3_del['content']:
    line_u = str(i)
    line_uu = clean(line_u)
    count.append(line_uu)

# %%
res = list ( filter ( None , count))

# %%
res
# Out:
# ['好的，我知道了～拜拜啦您～不懂事的小屁孩',
#  '太开心啦，一次成功！小朋友太爱吃了～为娘很欣慰',
#  '南汇好朋友的再次投喂～🍇葡萄太好吃了吧！',
#  '周五ootd9.9的F21的T恤真香～我真是省钱小能手包包也是同事送的',
#  '小可爱太乖了～以后妈妈多带你出门哈 ·月星环球港',
#  '今天穿了幸运色～🟠',
#  '太快乐了～工作终于如我所愿了～',
#  '今天的快乐是螺蛳粉给的～还有同事的manner抹茶冰淇淋～',
#  '🍊妈妈也会想妈妈👩我已经三年没有见过我爸爸了👨',
#  '好久不做越南春卷～就是备菜有点累～',
#  '出门又有人说我们是洋娃娃了好吧，摊牌了～我们是混血荷（河）兰（南） ·金桥国际商业广场',
#  '711会员的一元气泡水真不错！我真是省钱小能手',
#  '🐂♊️♏️♊️ ·小尝 GOP STORY 韩国料理',
#  '两只双子座♊️👭',
#  '🍊爸爸越来越会～',
#  '🥩 ·西塔老太太泥炉烤肉(华润时代广场店)',
#  '大杨浦的路，真的很需要耐心～🚗',
#  '周五两杯水果茶的快乐～🥤',
#  '带薪休假的快乐还有18天',
#  '跟聂总的周一🍵',
#  '四年前的今天～🌉库存📷怀念自由出行的日子～',
#  '今年疫情封闭2个多月没吃到第一批南汇西瓜，没想到第二批8424🍉也那么给力！南汇的朋友下午3点亲自采摘，亲自驱车送到家～太幸福了！感恩～',
#  'B&C蹭的生日福利～不用排队的快乐～ 我的虹口赵露思～ ·瑞虹天地太阳宫',
#  '小朋友🍊第一次逛山姆 ·山姆会员商店(旗舰店)',
#  '今天家门口的大学毕业典礼🎓羡慕年轻真好～如果时光倒流，我一定好好读书～',
#  '新同事的小礼物🎁真阔气～还人手一个',
#  '时隔两年～我终于来M了～哈哈哈哈，喝个新品🥤庆祝一下～老板没办法白送的不喝不行',
#  '🍊爸爸除了不会生孩子，什么都会～做老公可能不是💯但是做爸爸绝对是超满分💯祝全世界父亲👨节日快乐🍾️🎉',
#  '30岁前想要的都实现了未来只想一路陪着🍊你们一起实现你们的梦想～愿我们都健康平安～感恩🧡',
#  '今天是我的生日06月16日，来祝福我吧~',
#  '微博记录📝31岁的最后一天即将32打卡📷～太喜欢30➕的自己～',
#  '奶妈功成身退了～谢谢♏️辣妈的鲜花😍',
#  '12元一杯的瑞幸真香～',
#  '打工人的周一～🍵',
#  '解封后的第一次堂食 ·喜马拉雅美术馆',
#  '又又又失败了比昨天更蓬松的馒头',
#  '国际贸易 手上有24w吨非转基因菜籽油，俄罗斯进口，含税价11000，不含税9700',
#  '进出口贸易 手上有24w吨非转基因俄罗斯菜籽油，出售，含税价11000，不含税9700',
#  '采购需求：非转可食用菜籽油，俄罗斯的，乌克兰的都行，巴西总量：每月2W吨+价格：9700要求：四级，非转基因食用级满足以上条件的人私聊，谢谢',
#  '到家的新宠',
#  '见证历史',
#  '又是认真摆烂的一天',
#  '姐妹们的周末',
#  '被牵引绳束缚住的小朋友 Moon_wai',
#  '阳就阳老，怎么地啦，值得这么大惊小怪吗',
#  '前天晚上肠胃炎，昨天38度，不敢去医院，感觉只有新冠才配去医院，还好今天退烧了',
#  '回不去了',
#  '众口难调，呵呵',
#  '近期第二起了……怎么了，ZF知道吗？',
#  '就是老觉得一直做核酸哪里不对了，一直说不上来，现在知道了，那个猪肉都要通过检疫盖章后才能拿出来卖的……',
#  '37度，我把口罩戴得严严实实再闷也不敢拿下来，扪心自问，我怕的是什么？是病毒吗？不是，我怕的是被隔离被封控，一系列的防疫政策……',
#  '好怀念歌舞升平，满微博都是娱乐明星的日子……',
#  '完全没有了分享欲……',
#  '桌长制？不管经济复苏不复苏，反正消费复苏障碍重重，障碍哪来的呢？希望经济复苏的设置的',
#  '作为调理身体，中医是挺不错的，但是不是按需要去设置中医馆，而是这样强制安排，怎么感觉又是一种什么节奏或者风向呢……',
#  '我也想你好，但你确实不太好，周末的，8点多，商场里面的商铺都关门了',
#  '就因为离朝鲜近，抗疫方法也和朝鲜如出一辙？',
#  '身为妈妈的我，看不得这样的新闻看不了这样的视频，就为了核酸报告，怀胎十月的孩子没了。我真的想问问由于新冠耽误的其他病导致死亡的有多少？难道中国就这一个病？新冠肺炎——哪里伤害到肺了，病毒已经变了，怎么变通一下就那么难呢？担心后遗症，那么多感染了又恢复了，你们去采访一下他们后遗症是什么？',
#  '花草 乱涂了一幅钢笔水彩，按照去年去拾芳园拍的照片画的',
#  '分享图片',
#  '劝慰别人被别人劝慰',
#  '想做鼻子的第n天',
#  '哇前一秒被恶心死后一秒被气死我现在就想杀到公司 giaotmd',
#  '一直在生气一直在生气一直在生气不知道自己在气什么人生这么无聊 公司令人厌恶毁灭吧',
#  '白天减肥晚上增肥',
#  '女生之间的攀比心：你的朋友没有我的朋友好看！',
#  '这就是所谓的眼里没光了吧',
#  '我是大冤种吗？哦 我是！！！',
#  '救命啊为什么我要上班呀',
#  '我可能真的会冲动之下裸辞',
#  '滴滴滴',
#  'Never late than before',
#  '难得のfacial time 妥妥滴躺了3个小时感觉又活过来了～喜茶の宝藏美式☕～纯苦不带一点酸',
#  '来自堂食の快落～昨晚撸串烧烤到今天都不饿～绝绝子',
#  '如『7』而至 不定时拖延de唄可爱',
#  'June…June…June…',
#  '入梅啦…啦……啦………',
#  '八月满而不溢，美而不腻！',
#  '慢摇❤️上🌹',
#  '咖啡拉花 🦢flat white☕️',
#  '慢摇千层心偏要怼进一朵小玫瑰找到一份“热血沸腾“的爱好',
#  '咖啡拉花 🌹☕️山本拓也～超轻的大肚杯',
#  '☕️🍛',
#  '咖啡拉花 用心去活，而不是用脸去活，用心去活无非是认真的去感受生活中的点滴',
#  '咖啡拉花 慢摇千层心💘',
#  '咖啡拉花 空心叶🌿🌿',
#  '安适如常安静而舒适☕️',
#  '夏日透凉',
#  '自己喜欢的生活取悦自己',
#  '咖啡拉花 3+1推推乐',
#  '重度奶油爱好者的心头爱',
#  '夏天知了声和午睡最配',
#  '还是重瓣的美咖啡的油脂挂杯壁',
#  '周末继续大筛查先自测抗原',
#  '人的乐观心态，将使你心理年龄永远年轻☕️早',
#  '咖啡拉花 latte霸占了2/3的地盘肥猫招不招财',
#  '咖啡拉花 今夏的绣球真的是便宜又漂亮',
#  '咖啡拉花 🌿第一次永必如鲜奶比较厚重，更适合dirty☕️',
#  '手冲豆盲盒双重厌氧云南\U0001fad8发酵的果酒味☕️',
#  '早🌹☕️',
#  '刚营业一周的健身房又闭馆了早点能过上正常生活',
#  '☕️',
#  '咖啡拉花 生活是自己的☕️',
#  '咖啡拉花 一场雨过后 知了声声高唱 下楼核酸',
#  'latte🐱平躺着睡说明对周围环境很放心，完全放松就躺开了',
#  '咖啡拉花 认真生活',
#  '恰到好处的喜欢最舒服 ，我喜欢就好',
#  '冰美式瞬间清醒',
#  '重瓣就是好看呀',
#  '郁闷过去了，开⼼在⾃由中苏醒',
#  'M家的手握 很温柔的配色',
#  '吃不完的红莓蓝莓冷冻保存，🫐早餐🍞配着自己打发的奶油满足☕️',
#  '咖啡拉花 玫瑰、心结、心上🌹',
#  '潮湿闷热的午后，多喝茶',
#  '咖啡拉花 🦢🌿',
#  '咖啡拉花 山姆的柚子三文鱼方便好吃拉花～空心该会的都会，既能独立生活生存，又能彼此照顾',
#  '咖啡拉花 双层空心、光圈空心叶☕️',
#  '白桃乌龙风味的咖啡豆夏天限定',
#  '栀子花洁白的花瓣夹杂在绿叶之中，可人香气舒心',
#  '手冲☕️桃乐茜，白桃乌龙风味的咖啡豆，豆经过冲煮之后，能闻出有淡淡茉莉的香味（为了让口感有茉莉味道加了盐水浸泡过的茉莉花）和浓郁的蜜桃香气😄入口整体感受犹如饮用了一杯茉莉白桃乌龙茶☺️',
#  '咖啡拉花 努力发光的心结',
#  '被 偷走了太多时光',
#  '荷香入茶香🍵',
#  '☕️想去看山看海',
#  '咖啡拉花 ❤️泉田之也 手作咖啡杯☕️140ml',
#  '咖啡拉花 🦢☕️',
#  '咖啡拉花',
#  '竹节手柄完美融合',
#  '可能是在钢铁混凝土里生活久了，不记得青山绿水长啥样了！',
#  '刘律师开庭，我在外面等！这地方，没有大树，车停下来不能空调不能停，太热了！我看附近有观海公园，过来逛逛！高温天，真受罪！ ·南汇嘴观海公园',
#  '一岁一枯荣',
#  '想游泳了',
#  '昨日晚霞，魔都涅槃重生！',
#  '在看npc商量吓人时间 有一种混入内部的感觉 加油我的伙伴们！',
#  '在为朋友们应援中',
#  '在听npc们聊吓人感想。。还有一个溜出来上厕所的npc。。点头示意了一下',
#  '从恐怖密室临阵脱逃了我对不起我的五个朋友们我真的怕死里面 在外面等你们平安归来',
#  '权顺荣和李灿🤔有点访问我心了',
#  '睡觉好难！',
#  '我很喜欢很喜欢的搭配 胡辣汤泡蛋炒饭',
#  '翻什么白眼 眼皮上打小抄了？',
#  '梦到和一个韩国帅哥谈恋爱 然后被骗财骗感情 但是好像真的挺帅的',
#  '想换发型 又怕换了后悔',
#  'watching the～vide～o that u sent～me～',
#  '休7上7？ 我宁愿正常过周末',
#  '小亮的夢でKiss Me和fearless对比着看好感慨',
#  '一呼吸就痛 后背右侧内部痛的像被揪起来了… 想左右对折一下',
#  '脊椎疼 但是又不知道明确的是哪里疼 歪7歪8的活下去吧！',
#  '十七',
#  '今天是我的生日07月28日，来祝福我吧~',
#  '好想睡觉',
#  '中村一叶有一场blue flame直拍简直是每天必看的节目',
#  '崔然竣ins破千万了',
#  '脑子好迟钝 完全动不了 玩了',
#  '畏手畏脚的好烦',
#  'ˊ_>ˋ',
#  '开头已升天 让我死一死 现在在听后面的部分 好听 r&b\U0001faf6🏻☝🏻🦾🚬🪐👄',
#  '😌☝🏻\U0001faf6🏻🦾',
#  '平常出门最喜欢喊 我要没衣服穿了！！ 真理起衣柜发现很多买了只穿了一次或根本没动过的 还有一些叫做“已在朋友圈露过面所以被雪藏”',
#  '梦到理想型 交换电话号码后醒了 气死我了！！！！',
#  '在思考早饭吃什么 昨天和美乐蒂去b&c了 买了一点面包回来',
#  '机关枪要气死了 我自己都感觉自己在狡辩',
#  '拉面和鸭血粉丝汤开始了激烈的争吵 究竟谁会胜出！',
#  'whiplash whiplash',
#  '高三朋友们取得好成绩！！！！',
#  '目前最讨厌的事情就是晕车',
#  '我明明可以享受空调房。',
#  '梦想是ssy起床',
#  '什么时候起床啊',
#  '没看过阿黛尔拍屁股的舞台的人生是不完整的',
#  '亲爱的奶奶',
#  'airpodsmax还行 和孙彩瑛一个颜色',
#  'newjeans好美啊 虽然有一点脸盲了',
#  'honey talk to me when you‘ve learned to use ur brain🥰',
#  '闫妮讲话好可爱啊哈哈哈哈',
#  '37篇听力 拖延症我🚬',
#  '为什么我不能长在床上',
#  '想买苹果的头戴式耳机但是好多人说重ㅠㅠ',
#  '破碎太阳之心',
#  '妈妈不太想我再打洞 爸爸倒是支持 唉 以后还要打别的洞 这可怎么办',
#  '发现很多封面不好看的歌曲都很好听 再也不以貌取歌了。、',
#  '翻了一圈七哥女朋友的ins关注发现几乎完全重叠幸福死！今天！我！幸福死！',
#  '！！！！！！！！！！！！！！！！',
#  '还是分手了 ，谢谢你。今天是7月20日，我们最终和平分手，其实从朋友到恋人我们发生了挺多事情，能走到一起也是很不容易。我喜欢你，很喜欢你，也想和你幼稚。对啊，我总问我自己为什么还能坚持，可能没有答案，我没有备胎，也不玩暧昧，我所有的脾气爱笑爱哭都给了你，我能为你做的最后一件事竟然是走出你的人生。我一点都不后悔，更谢谢你教会我成长。我也不知道这是谁写的，感觉挺感动的我就复制下来了，不说了，崔杋圭做好饭菜等我了。',
#  '宝 你太笨啦别学别人咯以为自己真的能变成那个样子吗 dumb ass bitch',
#  '宁愿当狗',
#  '生日礼物不知道要要什么 zl让我随便想 我啥也想不到。我操',
#  '朴成训',
#  'ˊ_>ˋ抹茶抹茶',
#  '8点起床点帕斯雀和香草拿铁 一定要起得来 一定要吃一次早饭',
#  'yuna长大了有一种女儿成长的感觉',
#  '宫胁咲良越看越漂亮ㅠㅠ',
#  '金采源长发的时候一直没get到 知道是美女但是没有疯狂的爱 直到最近先是看了几个les的物料然后关键点就是 一叶第二个vlog里夸金采源做的好的时候金采源抬起头的时候那个亮晶晶的眼睛！！！！！啊啊啊啊啊啊啊美的不可方物怎么会这么一下就击中人心',
#  '浪漫的夜晚需要ariana',
#  'but even closer to you you seem so very far',
#  '一年多前 以后赶作业的时候都能让猫猫趴我腿上 想想就觉得好幸福现在的我 “快用碘伏消毒一下伤口”',
#  'if我能一小时写完这6篇b稿 今晚一定要把佩小姐的奇幻城堡再看一遍！！！！！！！！！！',
#  '橡胶。。。',
#  'taste like lemonade',
#  '休宁妹妹生日就和我差一天比我大一岁零一天 嘿嘿嘿',
#  '下次出门就是再打一个耳洞之时',
#  '快融化了起身才发现没开空调。。明天早上安慰自己一杯冰香草拿铁不然说不过去',
#  '郑在玹的脸和肉体。',
#  '听点r&b 梦会更香',
#  '22.5度空调房融化中',
#  '闵玧其闵玧其你是我的骄傲',
#  '🫂 ！在夏天的晚上和好朋友一起骑自行车 ！',
#  'dylan给虚拟语气举的例子',
#  '睡太晚了感觉头内部都在冒血',
#  '老师布置了20篇 我没看明白页码他妈做了22篇',
#  '🦾',
#  '！！！！拖延症去死、、、、、、！',
#  '出分顺利我的朋友们',
#  'lana的Salvatoreˊ_>ˋ',
#  '不知道头发要不要继续留长 想染回去了',
#  '写完拖欠的东西 誊写 吃沸腾鱼 冰香草拿铁 问朋友 看海',
#  'airpodsmax 黑还是白呢',
#  '我一定要克服拖延症！',
#  '该说不说最近心情真的很好 但是一想到不知道晚饭应该吃什么 又迷茫了 唉',
#  '怎么和教育局举报 我八月还有别的好多事情你开个屁的学啊 学校能帮忙补雅思吗',
#  '想提前开学？迈过我的尸体再说',
#  '机关枪一开口我就觉得自己被人当弱智了。',
#  '五炽怎么闹哄哄的 笑死我了 好快乐',
#  '写完作业！看团综！',
#  '和朋友说了不止一遍开心就好 开心就好 其他的管他呢',
#  '0714解药 凌晨听starboy💉',
#  '今天晚上把作业赶完 赶不完我是狗 明天早上点冰香草拿铁',
#  '为什么我不能当条狗？',
#  '我为什么不是狗？',
#  '有没有推荐的日料外卖啊 好想吃三文鱼',
#  '急',
#  '78月怎么这么多回归的 有好多歌听了',
#  '每次刷新热搜都几乎能看到一个新的人名... 内娱最近怎么感觉房塌得和地震一样... 是为了挡住什么更大的东西吗？',
#  '有没有推荐电影 适合吃甜品看的那种 要he的 动漫真人皆可 国外电影',
#  '电脑碰都不想碰但是再不碰我就会死 19点is my死期',
#  '唉',
#  '很少泥塑 直到看到李泰容moonlight舞台...',
#  '目前听了最有画面感的歌必须有strawberries&cigarettes🍓🚬然后想到原来我以前还是有过冒险的勇气的',
#  '想毕业 想飞走',
#  '陶陶居的叉烧饭 好吃 冻柠茶也挺好喝的 711急救计划',
#  '感觉自己好久没喝奶茶了 喝到后面反胃 喝果茶又怕茶底太涩 但是总有点开外卖软件的冲动🥲',
#  '为什么开了imessage之后垃圾短信变多了',
#  '做梦做的不想醒了 怎么会有这么开心的梦',
#  '外面在打雷 刚听完听力发现明天早上的课是九点钟的我也是。',
#  '眼皮困的要粘上了 还有他妈的听力作业没写 今天晚上本来还想再看一遍天气之子的🥲',
#  '怎么还他妈的不下班',
#  '整照片看到这个 太可爱了维尼 “怎么会有这么长的尾巴”',
#  '在迪士尼两次碰到同一个美国小帅哥 目测十七八 阿迪达斯上衣 黑色中裤 金发 身高187左右',
#  '再也不想和家人出行',
#  '迪士尼 停车的噩梦。。',
#  'call it what you want <3',
#  '下雨的话迪士尼停哪些项目啊 还会再开吗 我真的不想下雨啊 操',
#  '凭什么要下雨啊 凭什么啊 凭什么？你告诉我凭什么下雨？凭什么啊？啊？你妈的',
#  '你他妈的今天要是真敢下雨 我就',
#  '时间他妈的为什么过得这么慢 希望闭眼睁眼就是早上6:20',
#  '睡了两个小时醒了 没事情干 在反思自己不登陆微信的这段时间 昨天被机关枪说人还是需要点网络的 不然收不到雅思材料。',
#  '高考加油！！！！！！来晚了',
#  '若能与你共乘海浪之上ㅠㅠ',
#  '睡不着 感觉要和下辈子招手了',
#  '罗帕你带我走吧罗帕🥵',
#  '今天午饭吃什么',
#  '左脚痛着还要处理鼻血 倒霉蛋了',
#  '有什么好看的电影推荐吗 这几天的凌晨喜欢泡在客厅看电影 不要恐怖电影 很多都看过了',
#  '养了快一年半 我的猫听到我叫它名字终于会应声了',
#  '连续第几个夜晚失眠 一夜未眠起来的早上整个人都像幽灵 生命要和我分道扬镳了 为了逃避 白天再是弥补丢失的睡眠 循环之后晚上如何合眼 心悸手抖发烫 看着天变白再是照明灯 纠结的断翅 肋骨变成机械壳 好想睡觉',
#  '按道理 我现在的精神状态不允许我查看任何社交软件 如果大家收到了我奇怪的消息一定要提醒我 我真的记不住🚬',
#  '刚醒看到外面像阴天就更不想起床了。',
#  '不可避免的side effect！手抖心悸😦',
#  '晚上看了新蝙蝠侠 猫女好美 第一次发现真的有美女留寸头都美得不像话 看的时候不知道是字幕颜色问题还是我视力下降了 有一段要眯着眼睛看。。挺好看的 时长挺长的 no more lies 脱离屏幕的色塞厄题又好到哪儿去 祝我的朋友们考试一切顺利！！！！！A+♾️',
#  '在后悔几年前做过的事情如果能让我从头来过',
#  'BV1434y1575n',
#  '我们乂园 生日快乐ε-(´∀｀; )',
#  '所有社交软件和我作对 我不磕哪家就给我推哪家 什么意思 我真的没有强心脏',
#  '这辈子没写过这么烂的作文从头烂到尾',
#  '今天晚上打算看部电影 有推荐的吗 除了恐怖片 最近没心情看恐怖片',
#  '反正最后都会消失的',
#  '目前对我来说最解压的方式是咀嚼软糖 前提是我牙齿和腮帮子足够坚强 希望房间里装满软糖',
#  '减肥这件事情不着急了 上大学前减下来就好',
#  'sun&moon',
#  '今天有人生日吗 生日快乐',
#  '为了转身拍背影扭死我了。腰真的很痛扭得。',
#  '正在为1.3年前的染黑付出代价',
#  '看私信',
#  '拯救全宇宙！',
#  '现在如果放大家放假各自上各自的课外班效率能不知道高多少 高一都集体进入放假模式了都学不进去了 为什么不放假 相同的其他学校现在已经放假了 就这个破地方又想着上满六月又做梦提前两周开学 怎么就什么便宜都让你占了呢想的美',
#  '喜欢的文再不更新我的人生真的会123456789876654321',
#  '真的不喜欢写议论文因为我写不好议论文',
#  '这个世界好可怕 了解越多 恐惧越多',
#  '这是什么意思 我注销成功了对吧',
#  '汉姆蜡笔',
#  '张庭和马丁两个疯批，太配了',
#  '“一群傻逼”',
#  '“传谣造谣的傻逼们还有那些披着皮骂的，不是又觉得要封吗？那求求你们快滚吧，越远越好行吗，反正发菜本来就困难，你们走了还好发一点是吧，真的很阻碍地球转。人民已经很焦虑了，听到这些东西就开始屯屯屯，你们这些b还有空长舌，怎么还没死啊？”',
#  '“真的很好笑，没有想过为什么会发生这种事，只是一直说他们疯了，他们为什么疯，为什么会变成这样，你们心里应该清楚”',
#  '“一个月过去了，我仍然觉得那些手握“小道消息”造谣传谣的人，跟防控不力的这群sb是一样的无耻之徒，全世界已经不剩几个好人了”',
#  '今天是6月20日了无事发生那所以造谣的是不是应该……',
#  '“原来，事实根本就没有人在乎每个人都只在乎自己的利益所有的人都是这样“不在乎自己的利益，还能在乎什么”你们一定会这样说，我知道可你们知道吗，因为你们不在乎真相，不在乎事实一切都不可能得到改变，不会有改善永远都是这样，或者越来越坏已经不会变好了我已经再也不会，也不想，用“一定会好起来的”这句话安慰任何人，包括我自己因为我真的已经不相信了尽管我知道，这句话帮助过无数人原来，这一切都是骗局区别只不过就是，在每个人心里拆穿得早一点，或晚一点可是如果可以我真想被骗一辈子。”',
#  '精灵之境第二留念',
#  '我围观了 的回答，该问题价值100.00元，围观仅1元，快来一起围观~ 微博问答',
#  '继续刷剧',
#  'N刷N刷',
#  '我还要回去刷个N遍呢！内娱88，隔壁的真恶心',
#  '新娘子 喜糖喜糖',
#  '冲着梦华录开的VIP，希望梦华录可以出蓝光DVD，一直珍藏。告别内娱',
#  '敬梦华录！大梦一场！文化自信！感谢导演编剧演员的用心制作',
#  '期待',
#  '老子花了18元钱！给我看阉割版的！腾讯，还钱！',
#  '梦华录 舍不得#舍不得啊舍不得，最好再拍200集，拍到她们孙子孙女那一代',
#  '讲老实话 准备材料的时候就做好了最后去不了的打算 可惜肯定可惜 麻痹一下自己说白忙活也没啥啊 给2022制造一段热血时刻也挺好的啊 收到的所有通知都是做好……的准备 对啊 反正我连毕业典礼一边看着录播一边想着“这也是没有办法的事”的准备都做好了 只是没想到我妈取名让我随遇而安在2022是这个意思而已',
#  '好激动 116天以来第一次坐地铁Summer Reminds Me',
#  '邻居是受刺激了么，大半夜开着门开吸尘器吸尘，这是脑子有毛病吧',
#  '这么热的天跑来，冒着中暑的风险4月份的计划因为突如起来的封闭，今天算是完成计划……衷心建议：不要暑假来，除了小朋友多就是🥵热，暴热 ·海昌海洋公园 第六空间里',
#  '我去，看了浪琴的视频，我有种再买一只表的冲动，儿子长大了，真的是绝了。浪琴，干得漂亮！',
#  '想你去演戏，知道你一定是个体验派的好演员。可是当你站在舞台上唱歌跳舞，我的眼睛就移不开了。罗一舟，真的好适合做爱豆啊，为舞台而生，我的dna复苏了。黑子没必要黑我鹅，没不要yygq。我追kang ta的时候，搞不好你们还没出生……姐姐比你懂好吗？',
#  '罗一舟 麻麻虽然很想你进组，踏踏实实做个好演员，每天追你的剧，但是……罗一舟你好适合做爱豆啊！继续发光吧，站在舞台中央！',
#  '罗一舟，我鹅子！',
#  '#IXFORM 门票#点开一些yygq骂的，怎么又是我拉黑过的，你们好空哦！',
#  '#IXFORM 门票#牛逼，只要有罗一舟的地方，就有你！不要太关注，其实爱恨是同源的，你懂我的意思吗？多关注一下你自己主页那位吧。恨久了，关注久了，事实证明大多最后会喜欢上这个人的……为你考虑，请屏蔽罗一舟的信息，你将看不到他任何消息！我就是屏蔽了**，***和***',
#  '#IXFORM 门票#哈哈哈哈，服了这rs想去的，当天都是再和黄牛抢票，当时1388直接缺货了。现在，买好票的，位置也确认了，又不能退。谁会去退了自己的票，再买黄牛？让我看看是谁急死了！祝演出成功，没有黄牛抢票！',
#  '#IXFORM 门票#Cjad，点你那！出来走两步！',
#  '我还想这一期怎么会这么有水准，哎……脑子不动要生锈的，亲爱的制作人们！',
#  '我的首页好绿啊……哈哈哈哈哈',
#  '绚烂的烟火如流星闪耀，祝罗一舟明天演出成功！小情歌好听，Love time 每一天！ ·迪士尼乐园 Cannahuang0711',
#  '有没有看这一期密逃啊！又恐怖又好笑！',
#  '宝宝，吃饭饭啦！',
#  '宝子，我主持稿写好啦！期待麻麻明天的表现吧！',
#  '儿啊，怎么办？我明天要主持员工大会，我主持稿还没写完……想摆烂……救救我！',
#  '罗一舟 宝子，今天大暑，记得多喝水！这几天有点忙，好好照顾自己！不定时上线看你！',
#  'Dy 高盖伦 Cannahuang0711',
#  '好了，各位，今天最后一条了。这个世界就是这样，你若胡搅蛮缠，我唯有装疯卖傻，反正大家都不讲道理。是吧？晚安，rs！姐姐要睡觉啦！',
#  '各位让一让，我也要蹭rs，让我发个博！',
#  '这也能上rs？罗一舟发的不多，至少每个月都是有的。有啥值得rs的？以后每次rs，都要给我们买吗？太破费了！感谢各位关注，正常工作宣传！',
#  '看片头有种香蜜+琉璃的感觉！好的，我去了！',
#  '这词条下面真没必要装路人，这团有多糊，大家心知肚明。点开骂人的首页，不是熟人，就是7月小号。借着热度的事件，骂得都是成年旧事。都是千年的狐狸，装什么那？',
#  '这个词条下什么妖魔鬼怪都有啊！Srds，这可能是最后限定版的爱豆舟了！我计划一下。',
#  '没啥可多说的，没用的，扯后腿的人，即使不开除，也请他速度远离我鹅，有多远滚多远。给公司造成重大影响，解聘！你们员工手册里有吗？',
#  '罗一舟 发视频能上gc咩？ Cannahuang0711',
#  '咱就是说，各位挑事的可以休息了，罗一舟和罗一舟粉丝都很忙，勿扰。本粉丝在看密逃！',
#  '我不指望所有人都能懂他这么做的意义。当你的年龄不够，阅历不够，你看不到更多更深的东西。你想要他回应，只能说明你不够相信他，你也不够相信你自己，你只是想给你自己一个交代。或者你只是想看倒油，看热闹。但是回不回应这件事，已经不是他一个人的问题了，11天了，它需要出现一个拐点，这个就是拐点。他年纪不大，但比我认识的很多人都成熟。他的预判能力来自于他的学识和沉淀，我一直相信他一定会做出最合时宜的选择。一个能把嬴渠梁写进rap的男孩，他心中所想怎会是只有自己，怎会是只有风花雪月？大浪淘沙，懂的自然会留下。前进的路上，有人走，有人留，聚散离合，再正常不过的事了，人生也不过如此。有一天，当你足够成熟，你看问题就会更深刻了。Ps，卖惨讨好不是我鹅的性格，他是个有想法，有判断力的男人！',
#  '突然好恨这个世界，你把这个样子的他还给我！',
#  '吃完饭了，儿，你还在榜上？你看看那些hei子蹦跶的，这个世界很多人就是这样，我不好，你也别想好过，都毁灭吧！是吧！奇怪又正常的思想，记得好好吃饭！',
#  '各位路人点进来，是不是发现啥也没有？是的，就是啥也没有！吃完饭了，各位！',
#  '儿啊，你爆了？这句话的主语是经纪人，怎么感觉大家只看到了你？气着气着笑了',
#  '那你们看看这位疑似的发文啊，管罗一舟什么事？网暴很好玩吗？你们很空吗？',
#  '真的能笑死，我认识罗一舟451天，这位是谁啊？',
#  '真是无语，你们这群黑子，姐姐我好歹智商超过了135了（小学，中学一共测过三次，可以去查），你们喷之前，造谣之前，冒充粉丝tuo fen 之前，能先理一下逻辑吗？我看着都想笑……',
#  '郑重说明，别人我不管，我也不知道。罗一舟拍戏期间，仅5/1-5/3请假回了北京。私人行程，全程未公开。你问为啥不公开？你去国话考试，要在当天门口拍视频炫耀那是你的事，他没必要这么做。你要了解他，就知道他有多低调。国话排话剧骨折，粉丝是隔了很久通过国话的周年刊采访才知道的。一个问心无愧的人，他根本不需要和你解释什么。你要不相信，他解释了，你也不会相信。但是作为粉丝，我无比心痛。被网暴，被连坐，被无脑黑，被无良的yxh抹黑带节奏。九天了，有些人不但眼瞎还心盲，除了带节奏，造谣，啥也不会干。我不知道别人，但我相信罗一舟合法合规，且有足够的实力考进国话。但是太惨了，虐得我心肝脾肺肾都痛！',
#  '吃瓜吃全了吗？别人我不清楚，我就知道有人看到罗一舟了。',
#  '正常人都看得懂了吧！九天了，你们会道歉吗？我觉得不会，你永远叫不醒一个装睡的人。',
#  '九天了，广大的所谓的路人网友知道我在想什么吗？感谢你们毫无证据的造谣，煽动舆论，诋毁罗一舟。这九天，我憋了一肚子气，忍得额头全是痘痘。感谢你们，从今天开始，我就是一个疯子。不要说粉丝疯，没脑子。每一个被逼疯的粉丝，你们都是罪魁祸首，谢谢你们终于逼疯我。所有不分青红皂白，无脑骂过罗一舟的，无论你是用左手打字，还是右手打字，还是脚趾头打字，我会每天祈求上天保佑你，保佑你恶有恶报，保佑此生所念皆不如愿！保佑你不得善/zhong！从今天开始，我就是一个发疯的粉丝，见一个撕一个！去你妈的“路人”，网络暴力的刽子手！禁搬运，搬运者撕/全家！禁视监，视监者不得好/撕！',
#  '舟舟，给你推荐一款冷饮，老字号，夏天极品，盐水棒冰！你猜猜多少钱？',
#  '罗一舟你今天吃了啥？麻麻减肥，看你吃就行。给你吃生煎！',
#  '我不管，我不听，我不信，你就是有问题。你不要解释，解释就是洗，洗就是你有问题。你解释一下A，好我解释。不接受，你解释一下B，好我解释。不接受，我不要你觉得，我要我觉得。我觉得你就是有问题。好，我不解释了。你为啥捂嘴，你捂嘴了，你有问题！反正我不管，你就是有问题。A有问题，26个字母就都是坏人。打倒坏人……现在是这样吗？这个社会是这样的吗？还是那句话，谁主张谁举证！',
#  '吓死我了 Cannahuang0711',
#  '明天是个特殊的日子！',
#  '我的个亲娘啊，见证历史了……',
#  '这两天的wb过看得迷惑，有种大家都是表演专业毕业生，被抢了饭碗的错觉。可以理解经济不景气，才会都想考公考编求稳，也实属无奈。但是作为普通人，与其骂这不公，怪那不平，蹉跎岁月，不如努力提升自己，多点技能傍身。成为别人选择的plan A，不好吗？之前就说过，疫情居家两个月，我是部门里唯数不多拿到居家办公工作的，也是唯一加薪的一个。为啥？说到底无外乎我技能点比别人多一点。关于国话，我仅代表我个人，支持公开所有面试者的资料和面试视频，让广大网友来选你觉得谁演话剧你会买票。大家一起参与，也给普通表演人一个基于市场的公平竞争的机会。艺考中戏男生前三，谁能PK掉他们，你就是2023明日巨星！',
#  '发完这条，空气化。经过一夜，想到了一些事，分享一下。我以前很喜欢和别人聊天，很喜欢分享家里那些鸡毛蒜皮的事，爸爸妈妈，老公孩子，没事也吐槽一下他们。我一直不觉得有问题，直到有一天，一个同事很直接地和我说，你能不能不要一直说家里的事。我当时愣了一下……他说，你的幸福让我感觉是在炫耀，非常不舒服。从那以后，我很克制自己，慢慢很少再说到家里人……怎么说那，有时候你所拥有的一些平凡的幸福，一些荣耀，很可能是有些人穷极一生都不能达到或得到的。我也是有了孩子以后，经常遇到一些很优秀的家长和很优秀的孩子，才懂为啥说，寒门再难出贵子。因为这一代真的，比你优秀的人还比努力啊。各位，加油吧！有些事情不需要解释，让时间证明一切。空气化！',
#  '我想得从来没有要求过你，可你都在一一实现。共脑真好！宝子，你太优秀啦！么么哒😘继续跟随你的步伐前进！',
#  '我想得，从来没有要求过你，但你都一一做到了，这就是共脑吧！这就是双向奔赴吧！你真的太棒了！',
#  '笑死，突然觉得有一天会有一家店叫什么“小船的重庆小面馆”',
#  '微博为你而开！',
#  '耀耀早！最近追剧，有感而发。一部剧能不能吸引人看下去，整体节奏以及第一集是否有戏剧性冲突非常重要。比如今年，开端就是很好的例子。这是唯一一部第一集就能吸引我，还越看越想知道后续的片子。希望后浪的后期工作人员能好好的剪辑，认真思考观众的需求，仔细复核，并确保无争议镜头。至于台词，我肯定支持原声的，但如果确实不太行或不符合人物设定，选用配音也是为了能有更好的追剧体验。希望你们用心做剧！',
#  '舟舟来看猫猫，今天带妹妹rua猫猫。',
#  '你什么时候能给我鹅弄个行程图？没事我就不上线了。最近看他在休假，开始忙现生，补各种剧。抽空上线，今天去杭州？为啥我鹅的行程我每次都是是从🐂那里知道的？我，是个有计划的人，能不能让我有计划的追星？',
#  '#罗一舟 中戏优秀毕业生#就真的很喜欢他不骄不躁，踏实的性格。娱乐圈是什么地方，他们班又卷成那样，可他好像很特别的存在，永远知道什么时候该坐什么事情！我鹅好棒！年轻人都好好学这样的艺人，向下扎根，匠人精神！内娱的偶像们，多修内在，卷起来！',
#  '舟舟，回看我最爱的纸片人的人物描写，才知道为啥我如此喜欢你。敦厚老实，心地善良，既有侠骨又有柔情，既不会计较个人恩怨又对民族大义泾渭分明。人生的轨迹也如此相像，大漠宁静，心不设防。闯荡江湖，才知人心险恶，仍心怀善良。最爱那句，无论他当时有没有绝世武功，他都有大侠风范！我心中的英雄，从来不是无情的。大情大义才是大侠！',
#  '我鹅在看射雕英雄传咩？你也喜欢郭大侠咩？你看到我说要看猫猫了是吗？我不管，我就当你看到啦！嗨森！好嗨森！我也喜欢郭靖，喜欢猫猫！',
#  '刚上线，这波操作完全在我意料之中。我仅代表我个人，向你表示。某部剧开播，我会去看，去看看那位非员工蒙得准不准。这演技，这编剧能力，绝对是个人才啊。你们考虑一下，招她进来吧，写写剧本什么的，估计能爆剧预定。就是，你，不要打自己的脸哦！',
#  '每次看我鹅的全身照，我都会忍不住拿出尺子去量一下头身比。腿怎么会，辣——么——长——啊！女娲娘娘捏你的时候真的好用心！',
#  '反正我也不太理会hyh，我不是啥秀芬，不是啥生粉，不是耀客粉，更不是hyh粉。我就是罗一舟一个人的粉丝。作为一名资深社畜，我无比希望我鹅的公司能好，上市小问题，你要是500强，我更骄傲，老母亲心理，你懂吧？你做的每一件事，作为社畜我理解。作为粉丝，不认同。好好管理你们的公司，好好做招聘，认真做背调！',
#  '啊，怎么办？我现在满脑子都是舟舟说他在有10只小猫咪🐱好想看！宝，你家开动物园的咩？',
#  '罗一舟 心怀感恩，幸福常在。快乐属于知足者，幸福属于感恩者。用平常心对待生命的每一天，用感恩心对待眼前的每一个人，幸福和快乐就会不请自来。',
#  '哎，你就是上帝派来治愈我的天使，听得眼泪止不住的流……Peter Pan，Neverland！很罗一舟啊！你说我们懂你，你也懂我们啊！宝宝，晚安！谢谢你！',
#  'tjc家的粉丝目前请在耀客gc闭麦，在帮YK清理门户中，介于该人自诩你家职粉，还泄露剧情，情况非常严重。你们可以说是冒充的，但目前你们已不安全，请速速闭麦！',
#  '你睡了吗？我睡不着！开会了吗？内鬼找到了吗？我很焦虑，这比和小学生吵架还让我接受不了！这是个成年人啊，心术不正啊！表面一套，背地里一套，太可怕了！没有接触核心工作吧？请保密协议了吗？可以赔钱了吧！',
#  '微博能实名年龄吗？如果年纪太小，我就不理会了。现在显得我也降智了',
#  '咱就说，微博能实名年龄吗？一想到我对线的是一群小学生，初中生，我就很烦！三观都没定性，怎么说理！他们听得懂吗？',
#  '其实挺有意思的，我们这群老婆妈妈们，懒的很懒，比如我。勤奋的很勤奋，比如我敬佩的数据螺们。然后100个人有100种思想，还都非凡人，偶尔意见不和还会宅斗，一地鸡毛。但要有人欺负罗一舟，所有人会一致对外。他永远是我的底线，你对他好，我就爱屋及乌。你欺负他，我就睚眦必报。经过多次被人上门挑衅，每一次都是忍无可忍做出反击，然后就有人yygq，他们家好会撕。埃克斯Q丝米？我妈妈从小和我说，能忍则忍，不能忍则无需再忍。我也这么教育我的孩子，你的拳头绝对不可以主动出击。但是要是有人伤害你或你爱的人，给我用力打回去！PS多元性有多元性的好处，互相制衡也能互相成就！',
#  '我受的教育不允许我骂你，但麻烦你看看，已经无下限到如此地步了！是疯了吗？说我们疯，我一个正经大学毕业，中级职称，十几年管理经验的人，我不允许自己胡言乱语。但不代表可以就这么算了！搞清楚今天是什么日子！是不是要继续发酵？乌烟瘴气！',
#  'tjc，恭喜你！你的粉丝成功把我惹毛了！曾经唯一的认识是，认识的一个四年级小朋友喜欢你，经过昨天，没想到你的粉丝真的是小学生多！先搞清楚什么是985，什么是211，再决定要不要看不起中戏！你是不是好演员我不评价，猎罪我get的是jsj，人家低调，但演技不差。但就你那些曾经的网络 ...全文',
#  '实体书已到，我打算代入我鹅子，再仔仔细细认认真真地看一遍。谁要再🐴我鹅子，我就甩实体书出来 等我repo',
#  '我再一次重申我的话，合作对象，请做背调，你不是第一次吃亏了！清醒一点！',
#  '怎么yxh那么偏心',
#  '吸引力法则优秀的人总会被优秀的人吸引，或被想成为优秀的人吸引。偶像的力量，就是成就更好的彼此！罗一舟很优秀，我也不赖，在现生也一直在持续努力。追着你的脚步继续前行！期待后浪，期待任天真！ 你相信光吗？我信！',
#  '某些人这是干嘛？虐粉吗？尊重是自己给的，面子是自己丢的不想扯上关系有时间多读点书好吗？门在那里，哥温gun！',
#  '这不值得rs?不够正能量？班三好我都不敢想。要是我们学校有个市三好，能载入校史！',
#  '一把年纪了，什么人没见过。这么多年，只喜欢这一个人。从来没有一个人，如此入我眼，更入我心。喜欢你，因为你是罗一舟！希望你达成你的梦想，希望你能被世界温柔相待！随手一截，都如此好看！',
#  '还有谁没去看扁桃仁直播？帅得我笑到现在',
#  '个人观点:娱乐圈没必要吹学霸，但不能太差。首先术业有专攻，娱乐圈，你唱得好，跳得好，演技好是关键。学霸如果唱跳演都废，那请你去需要学霸的公司，阿里，网易，字节需要你，不然你来干嘛？看你表演编程吗？你也干不过大厂普通员工，搁这田忌赛马来了吗？唱歌跳舞的，专业够强，长得好看，够用了。但演戏的，成绩不能太差。毕竟你要看剧本的，语文不好，怎么揣摩角色。数学不好，怎么理清剧本逻辑。英文发音不好，那估计台词也够呛。平淡点看，就是不用学霸，但不能太差，专业够强，就行了。',
#  '我是真的不支持童星和养成系的。太小的孩子，心智还不太成熟，如果没有人时刻守护，有时候一个打击都可以改变人生。童星能一路长红的，几乎没几个。那是智商情商都够，食物链顶端的存在，没有参考性。给孩子们一个健康安全的成长环境吧，等三观稳定，心智成熟，成年了再角逐娱乐圈不行吗？说到底都是资本的工具人……',
#  '鼻子有酸了',
#  '我是不是该庆幸刚刚pf大哭了一场，没有把最后一句话发出去……',
#  '是从现在开始你要不回，私信我就只能发一条了是吗？容我好好想想，最后一句说点啥……妈呀，竟然流泪了，不要啊，像在告别……救命，好难过……',
#  '今天上班遇到两个疯子，一个直接和我说，我被关了两个月，我是有点无聊，直接把我无语到翻白眼🙄。然后再想想网络上的喷子，嘿子，键盘侠。嗯，疯子永远是疯子，你试图和他讲道理，他永远不会和你在一个频道。建议精神病院扩张，有些人放出来，真的就是祸害……',
#  '我真的真的很想看到罗一舟穿学士服没有的话，能单独拍一拍吗？',
#  '我一直觉得，只有我可以骂你，只有我可以没事来和你尬聊。因为爱之深，责之切。耀耀，你说对吧？我最近挺忙的，我鹅最近好不好？',
#  '妹妹说，想念青3的爱豆舟，于是今晚就带着她重温了一下节目。就是这娃实在是无语，好几次看着看着就狂笑不止……第一次，笑得喘不过气，我不得不暂停节目，问她你到底在笑啥？妹妹:如果你盯着一个人仔细看，你会发现很多东西……哈哈哈哈哈哈我:啥啊？妹妹:我刚仔细看了一下lrh的眼睛，然后我发现他的眼睛显得他的脸特别大……哈哈哈哈哈哈（李老师，dbq，童言无忌，她很喜欢你的李白）不能看了，只能跳过lrh，没一会儿，她又开始狂笑……我:你又怎么了？妹妹:ls，哈哈哈哈，ls的头在发光……哈哈哈哈(dbq，ls，她觉得你很酷）妹妹:这些话，哈哈哈哈哈，不能上网发，不然我会被人肉的！我:好的，我这就上网发！你保重！',
#  '上班和下班的表情怎么查那么多？宝子，你怎么啦？',
#  '我不知道在别人眼里舟舟是什么样子，可能每个人的看法各不相同。但是我经常会觉得，他除了是艺人是演员，很多时候我会更觉得他是一个员工。工作中，他会控场，会协助，会沟通，会去亲自动手干活。作为一个学管理，做招聘的社畜。他真的是我眼中那种即聪明，协作能力强，又领导力和判断力，可发展的好苗子。耀耀，让他除了演戏，多多接触公司各种部门的工作。你懂我的意思！',
#  '好不热闹，你要不把小黑🌸宣了，我好及时思考一下我的立场……',
#  '又是什么乱七八糟的rs，我从小对甜妹无感，我喜欢御姐，喜欢李孝利，喜欢coco，萧亚轩，那种性感健康的。95花为啥都是甜妹，没有我菜……',
#  '去年520北影毕业照，我鹅拿着饭卡混迹其中。今年麻烦中戏毕业照晒出来，上rs！ 罗一舟，毕业快乐！',
#  '射雕，郭靖，谢谢！',
#  '最近很忙，终于有空了，来和你聊聊。我鹅下一部剧是什么，什么ip不ip的都是浮云，我最关心的是一起合作的，编剧是谁，导演是谁。看到你们最近在招编剧和导演，扶持新人，这点很合我意，非常好。内娱需要新鲜的血液，更需要新鲜的思想。一部剧口碑好不好，编剧是骨，导演是肉，演员是让他或她活起来的血液。虽说缺一不可，但骨和肉一定要先搭好。看到网传的我鹅的饼，说句心里话 ，如果是真的，请一定忠于原著，然后强化事业线，好好润色，让它丰满起来。我目前仍然不感兴趣的原因，真的就是剧情不够精彩……年纪大了，光有人设很难吸引我！请一定好好加油！希望你努力的方向和我想得一样！',
#  '我在小红书发现了一篇有意思的笔记，快一起来看看',
#  '人类的一切智慧是包含在这四个字里面的：“等待”和“希望”！—《基督山伯爵》',
#  '发言的单位没有一家能去现场的',
#  '唯有爱❤️，能帮我们跨越一切障碍 ·展览中心友谊会堂',
#  '让更多人了解民主党派',
#  '看过了午夜零点的单位，清晨五点的延安路高架，终于回到了阔别几天的家',
#  '今天又创一纪录，一天里做了2次核酸，其中一次还是单管，用健康云扫码的',
#  '人民群众对美好生活的向往 双鱼小文文',
#  '0:30才入住酒店，又创纪录了',
#  '历史会铭记这个非比寻常的春天',
#  '疫情期间有物资，疫情过后涨工资，这是2022年人生赢家该有的样子吧',
#  '我的灵魂好像还没有复工',
#  '今天打了个出租车，司机告诉我他跑了10km才接了这么一单，现在除了早高峰时段以外，都没什么生意，晚高峰基本也是没有的。',
#  '疫情大浪过后，我们会发现什么才是这个社会真正需要的『董宇辉爆红7天后，不堪往事曝光：原来，他隐藏得这么深』董宇辉爆红7天后，不堪往事曝光：原来，他隐藏得这么深',
#  '受疫情影响最严重的三个行业：1.旅游业2.演艺业3.教育培训业',
#  'Once again',
#  '雨大到什么程度呢？我感觉我的雨刷器要飞起来了',
#  '我在 抽到了上上签 大开视界游园会',
#  '聚力·焕新！耀视界！2022我推荐《我们曾经在一起》，和《我们曾经在一起》一起见证荣耀时刻！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！参与2022我推荐《余生，请多指教》，和《余生，请多指教》一起见证微光盛典“观众喜爱”荣耀的诞生！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！2022参与线上微光荣耀影视音乐推荐，我推荐了《冬梦》，《冬梦》就是我心中的Top1！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！2022我推荐我心中的的荣耀人物肖战，和肖战一起见证荣耀时刻！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！2022我推荐王牌部队，和王牌部队共同点亮荣耀时刻！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！微光荣耀五大类别推荐重磅开启，我推荐余生请多指教，助余生请多指教赢取微光盛典“观众喜爱”荣耀！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！2022我推荐斗罗大陆！和斗罗大陆一起见证荣耀时刻！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！快来参与2022我推荐斗罗大陆，和斗罗大陆一起见证微光盛典“观众喜爱”荣耀的诞生！ 2022微博视界大会微光荣耀推荐',
#  '我真是太倒霉了，我是那种会通宵追剧喜欢一口气看完的人，那天看星汉灿烂播到24集了，就去网上搜了一下一共几集，度娘给的答案是27集，再看了一下追剧日历，就很满意的开始看了。结果看到一半弹幕说分上下两部，我震惊了，太难受了啊，这得要追到何年何月啊，急性子太难了，现在又说中间还要隔一周，简直是要命啊！',
#  '我就希望能有很多很多很多花絮，我发现现在的剧花絮都好少，而且都是设计过的那种花絮，只想看原生态的。',
#  '没看过1，也不知道人设，就看你们发的视频，感觉换了的这个小姐姐长得也很美，是非常美的那种，但是没有王玉雯那种自信张扬全场最美的感觉，光看视频里几个镜头感觉还有点气场不足。',
#  '不懂就问，是宇文玥捞上来了吗？',
#  '我正在使用 粉丝认证号专属卡片背景，粉籍认证，你值得拥有！快来试试吧！粉丝认证号：肖战',
#  '的宠粉卡已发放！我领到了TA的专属宠粉福利，快来和我一起成为TA的认证粉丝，宠粉福利领不停！粉丝认证号：肖战',
#  '#贾乃亮 今后也应尽量远离投资#其实吧，我还是很喜欢李小璐的哎，也很喜欢甜馨，好希望他们复合啊。另外他说自己投资那么多年没有收益我是真信，可能是我天真，也可能是我见太多投资不仅没收益还年年亏本的。',
#  '聚力·焕新！耀视界！参与2022我推荐《冬梦》，和《冬梦》一起见证微光盛典“观众喜爱”荣耀的诞生！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！2022我心中独一无二的影视音乐是《余生，请多指教》，快来参与推荐，和《余生，请多指教》共同点亮荣耀时刻！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！微光荣耀五大类别推荐重磅开启，我推荐《冬梦》，助《冬梦》赢取微光盛典“观众喜爱”荣耀！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！2022我推荐王牌部队，快来跟我一起让更多人看到王牌部队！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！2022我推荐余生请多指教，快来跟我一起让更多人看到余生请多指教！ 2022微博视界大会微光荣耀推荐',
#  '个性图标：清凉泳池',
#  '分享图片',
#  '下班把该带回去的资料电脑都带回去了，不晓得这样的日子尽头在哪里，今天的36度，大白这身衣服穿着真的不容易。坚持做好防护，尽量少去人员聚集的地方。',
#  '今天出梅了，5点多的办公室望出去天空特别美～又一个周末来了，上了五天班，可以歇一歇了～',
#  '一晃2022年半年就这样过去了，这个半年对于我们来说，需要收藏的实在太多了。复工1个月，慢慢在重回那些热闹的时光，虽然我们还是在不停地核酸中～ 生活身旁的那些改变，一直觉得没有感同身受，是无法去安慰的～～ 这个季也在不停地在调整，让自己有最舒服的状态，加油吧，愿七月能更好。',
#  '世界上依然有童话，小王子会永远爱着他的玫瑰花。我正在使用 “小王子”会员专属卡片背景，一起来拥有小王子的暖心陪伴吧！ 卡片背景：小王子',
#  '为白血病儿童献一份微薄的力量今天完成了自己几年来的一个心愿，把长发捐给需要他们的小朋友，愿每一个孩子都平平安安顺顺利利健健康康的长大🙏',
#  '小善意，大温暖。我在“孙子重病七旬爷爷病房陪护馒头咸菜充饥”项目捐款成功！愿点滴之举温暖更多心灵。',
#  '又来了，每次这种都会从假的变成真的，狼来了的故事',
#  '在最美好的年纪嫁给最稳妥的人，让我们红尘作伴吃的白白胖胖',
#  '倒计时🙈 Jialin努力碳中和',
#  '😂喜获嫁妆➕2',
#  '感谢boncake送来的新品蛋糕，美味与颜值并存～欢喜粉粉的一切～',
#  '一顿下来，彬彬终于会剥山竹了',
#  '永远幸福～我的女孩',
#  '美丽的双彩虹🌈是庆祝摘星吧 ·白玉兰广场',
#  '除了不能旅行 一切都很美好鸭',
#  '一周菜谱合集，被吴大厨投喂的第2周',
#  '网民还是善良这女孩油盐不进，没救了',
#  '想想就害怕😱',
#  '脾气暴躁，不配当爹',
#  '别推了，根本不认识的人别占咱们的版面行吗',
#  '好好地翻啥围栏呀，这么大人了也没个谱？幸好被救回来，不然悲剧了',
#  '律师也能失业？我还以为律师行业没有年龄的坎呢',
#  '唉，悲剧',
#  '不是化工污染？',
#  '每个高考生不都是的吗？',
#  '大热的天，伤者可怜呀🙏🙏',
#  '又是精神病人？',
#  '哪个学校呀？',
#  '不应该去医院看他老公吗',
#  '所以看猫饿着也不要管，任它饿死才是正确的吗？',
#  '人没事就好。还是很可怕😱',
#  '都是被逼的啊！打工人可怜啊说开就开，熬不到退休',
#  '深井冰',
#  '广告文',
#  '深井冰',
#  '平安🙏',
#  '回应在哪儿？没看到',
#  '#华晨宇 张碧晨#这两人一起退圈吧，负面新闻一直炒作，带坏了青少年的三观。',
#  '#五十公里桃花坞 尴尬#第一季都看不下去，还出第二季，无语😓',
#  '对外经贸不是全英文的国贸和金融学建议报考吗',
#  '想通了，只要我活的久一点，怎么样都可以忘记今年的高考数学',
#  '哈哈你说呢',
#  '现在只想考数学的时候我的脑子正常一点',
#  '🙏🙏🙏',
#  '听我说谢谢你',
#  '🌕or💰？ 做个有想法的普通人就好，别让他人的意见左右自己内心的声音，最重要的是开心，别留遗憾🧗♀️',
#  '微博会员日活动可以走点心吗？',
#  '甜口脑袋🍦🍰🍫',
#  '周⑥周⑥，出来溜溜🍵~大暑🈶好好过，照片🈶好好拍！',
#  '嚯，今天可是42℃化了妆坐地铁出门的！一句话里三件稀罕事儿👆🏻 ·隐溪茶馆(陆家嘴店)',
#  '洗头不出门，出门不洗头👩❤️👩车流稀少的外环油门踩100的快乐谁不爱啊⛽',
#  '如果要自己动手的话，还是不要爱吃菠萝蜜了',
#  '来自夏日酷暑的弥补🧡💜',
#  '留住柔和又梦幻的浪漫粉紫色☁️🦄',
#  '如果不是今天的落日怼在东方明珠上，我都发现不了从家里也能看到三件套🌇🏙️',
#  '·米禾良日料 今天的鳌虾和甜虾到位了🦐🍣🍹🥘难般有一天我在外面浪，老公在家待着等我回去。回家收拾完洗好澡他又出去了，突出一个互相等。',
#  '加完班回家又被拖出来开迷糊的妈去做核酸🥀',
#  '几年前的照片今年还在p，是哪个喝了奶茶睡不着常常懒得修图又异地恋的可怜鬼我不说',
#  'emm被夕阳猛晒应该也会黑叭…？🌇',
#  '记录和干儿子的初次见面❤️碰拳拳👊🏻',
#  '三个多月了第一次出去上班班么上了半天，口红倒是掉了一根',
#  '爱的最初是两个不同的人因为那份悸动，而走到一起一起吃饭，从吃不到一起到共同的口味一起逛街，从普通的压马路变成了甜蜜的牵手之路，每一步都是那么美一起看电影，这是每一队情侣曾经最朦胧的亲密空间，在昏暗的微光下，除了精彩的剧情只有浓浓暧昧的气氛。辗转进入第二个阶段，两个会期待更多 ...全文',
#  '祝自己生日快乐！随手拍',
#  '我在小红书记录了一次心情，快一起来看看（分享自',
#  '今天又有了做设计师的既视感.....1.黄一点红一点，换个颜色2.大一点小一点3.透明一点再黑一点再淡一点4.用原来那个图案5.用原来那个黄色6.再加个红色7.高一点再高一点...........这种感觉谁懂....',
#  '这个季节，风扇的风也温柔起来了~因为心里照进一束温暖的光~随手拍',
#  '第二天，准备迎战，fighting！ 徐翌雯',
#  '中考第一天，暴晒+无线等待晒脱皮了',
#  'emo，不想说话💬。 直接影响到了，不想工作.........',
#  '孩子都是很好动的，但同时也是自尊心很强的小宝贝，我们可以拍照的时候🎥给她塑造各种角色; 比如第一张，手指镜头，化身领导者，代入感也很强。第二张，打电话，模仿一个上班族，小人办大事的感觉，孩子会比较喜欢，因为他们心理爸爸妈妈都是他们模仿的榜样。第三张，手指着道具，又变成了小小销售员，孩子会觉得很好玩，说话也会模仿各大带货波波间，角色带入是很有意思的。第四张，吃东西或手里拿道具，有时候抓拍，很惊喜，不过好动的孩子就让他拿各种喜欢的道具吧，会更愿意配合，可以告诉他，现在，他是商品展示的小模特😁第五张，其实考验一点技巧的，孩子在玩的时候，侧拍，或者突然叫他，抬头一瞬间的小表情很可爱哦~大家可以去试试。 🌸宝贝们长的很快很快，能留在我们身边的时间其实不长，也就10年读了初中后，也基本上休想她像小时候那样能再对你腻腻歪歪，依赖你了。这是一个毋庸置疑的过程，这也是他们长大的表现。近期居家生活，天天在一起，📷行动起来吧~捕捉宝贝成长的每一个瞬间，也是自我成长的必要过程，细品，你细品。💡下次为大家分享微单拍宝贝系列。这次用的是OPPO Reno5手机。oppo reno5随手拍',
#  '尽然有这个节日姑且亲一口😚冰淇淋🍦吧单身狗不配有毒 大麦茶+冰淇淋，完美组合！透心凉，幸福啊~',
#  '倒计时5天，中考在即，那么热的天，回想当年我没有参加大考是提早分流的艺术生，天天睡觉吃零食的日子，有点过度美好了希望凭我一己之力能陪伴大娃安然度过第一个关键性考试: 中考',
#  '又是热爆的一天，阳光晒身上太炽热了刚刚七月，后面的日子怎么办，哎~还有那迫在眉睫的中考日，准备好暴晒了',
#  '最细腻的爱，是默默的关注，默默的守护。每一次静静的等待都是爱意在蔓延~能持久的爱，不是热情的快闪，更不是风风火火的表达，是细水长流~是心灵的碰撞！在这个时代，纯粹又耐心的爱即将归零吧~剩下的只是各方面的各取所需和互相牵制...情感',
#  '爱与不爱，真的很明显。反之男生，同样！爱在的时候，各种寻求关注。爱渐渐逝去，就成了想看两生厌，避之而不及。而这个周期真的太短太短，往往转瞬即逝~更多的长久，便只能用互相牵制来维系了。但不可否认，初爱，真的甜。 徐翌雯',
#  '这熟悉的节奏，又来了',
#  '肖战 我真的好爱走盲道……',
#  '17年的香香真是爆可爱对不起真的不好找物料，我好想多看看奶翔的视频和表情包啊！最爱顺毛奶翔看之前的视频还会发现一直很温暖的丁哥，一直乖巧的张哥，一直可爱的霖霖～下午找到#严浩翔single ladies# 的视频后反复观赏哈哈哈哈真的笑死了～',
#  '体表温度绝对不止啊，出来五分钟汗如雨下',
#  '你为迎接新生活做足了准备，新生活上来就给你一拳还带个惩戒。生活真他妈让人窒息啊！',
#  '没带钥匙没骑车没背包，买东西做核酸拿快递就是个人形搬运工具……《我有事》',
#  '无论是帅气拽哥，还是撒娇甜豆，都值得喜欢',
#  '一晚上分别梦到亚轩小甜豆 严王好拽我好爱 都是很好的朋友一起玩耍一起闹，还有很多奇幻情节（类似仙剑1里面的，因为看到了神仙姐姐～），好嗨森啊少年们要越来越好啊！！',
#  '肖战 欢喜一刻',
#  '肖战 又做梦了，先去做核酸复印其他资料。等我回来再记录吧～真是我这几天奔波劳累唯一的慰藉。爱你呀战哥',
#  '唯有音乐最治愈人。BIGBANG (빅뱅)《봄여름가을겨울 (Still Life)》봄여름가을겨울 (Still Life)',
#  '刚开始没有沉迷，但几年了后劲很大。不愧是你，铁肺公主邓紫棋 作词人：张赢作曲人：罗锟这两位制作人好厉害啊，好多热门电视剧热门歌曲都是这两位参与的，太牛了G.E.M. 邓紫棋《桃花诺》（《上古情歌》电视剧片尾曲）桃花诺',
#  '噩耗接踵而来🙅🙅',
#  '《什么破梗》《以牙还牙》',
#  '肖战 偷偷恋爱吧',
#  '肖战 每次长时间通话之后好像彼此的心能更亲近一点了，希望这不是错觉。希望以后大家都是有效➕良性的沟通。',
#  '🧊🧊🧊🧊🧊是谁在人间热得快要蒸发了？啊啊啊是我！',
#  '今天看完梦华录的结局啦！“星辰为你荡漾，风月为你痴狂，谁为你不惜时光，等地老等天荒。”！主题曲真的太好听了吧！！印象中靓颖姐上一次给神仙姐姐唱的OST就是 的《不惜时光》，只能说靓颖姐的歌声跟刘亦菲的剧适配度也太高了吧！无限循环，好听醉了啊！服了服了！ 梦华录再见啦！上一次看国产古装剧还是去年补看的《知否知否应是绿肥红瘦》，喜欢明兰，这次喜欢盼儿姐！顾盼生辉yyds！晓哥眼神拉丝太绝了！ 最后一集向官家行拜跪之力礼都那么有文人雅士的气质（明明咱是个武官hhh）。我也爱三娘姐 、引章妹子 、池衙内 、《知否》里的长枫哥饰演的杜夫子 、招娣和陈廉、因为本人是刘亦菲迷弟而避免角色被骂的“前夫哥”欧阳旭 、花魁张好好、高慧小仙女、还有可爱的何四，让人又爱又恨的萧相公……这些配角戏份也很出彩！不抢主角戏、毫无违和感，符合剧情主题。感谢各位演员及幕后工作人员，是你们让我们看到了这么好的作品，感谢你们让大放异彩！',
#  '知识真的可以改变命运。',
#  '肖战 原来相见真是那么难',
#  '肖战 快快开始自动回复吧！！求求了！！ 小室，快给你老板提意见',
#  '肖战 快快开始自动回复吧！！求求了！！ 小室，快给你老板提意见',
#  '肖战 再也不能发私信说想你了心碎2022',
#  '微博私信只能发一条了？今晚哭得最大声的是我请问那我用微博干嘛？？？？除了超话签到，已没有任何用处！我追星的通道（唯一）已经灭了！ 为什么不早点实名制呢？！',
#  '看17年的节目 想吃爆米花🍿想吃鸡公煲➕剁椒皮蛋',
#  '肖战 开屏就是一个大帅哥咱就是说，点进微博的心情都变好很多耶',
#  '肖战 恭候时影大人（求师父轻虐）',
#  '宇宙的尽头是直播带货……吧？！',
#  '卡其嘛，祝你天天快乐，不止今天。',
#  '不想再看到社会新闻了，我想吐',
#  '应该已经没人看了吧昊然、腾哥和马丽yyds奥运冠军武大靖、任子威okk尹昉这个舞蹈家➕演员我也挺喜欢的但真的无心看这个综艺了，拜拜👋🏻',
#  '真是笑死了！真不怕被骂？？（有多少人忍得住不爆粗口呀？）',
#  '#青岛啤酒 畅享欢聚时刻# 代言人开屏这不就来了嘛感谢品牌爸爸信任 夏天就是吃烧烤、哈啤酒🍺🍺',
#  '可爱的波妞',
#  '肖战 跟不上时间滚动的齿轮就会卡死在齿缝中',
#  '越听越懂杰伦的词，我要哭死了。周杰伦《半岛铁盒》半岛铁盒',
#  '终于爆了？你觉得大家信吗？如果这次事件不全部公开透明、严惩罪犯的话，试问某些部门的公信力还能提升回来吗？？',
#  '第一天发酵 第二天9人全部落网 第三天从热搜撤下来换别的举报热搜 第四天无后续进展，官方玩文字游戏只通报两个女生无生命危险……监控没有全放出来，那个监控死角黑暗的巷子里发生了什么，有没有出人命我们不知道。明明是四个受害者，医院的照片只流出来一位受害者的。受害者家属及官方通报的无生命危险的两名女子并未露面澄清，网友怎么可能会相信啊！！！我们需要监督、需要真相、更需要公正的判决！也怕有一天我们自己变成受害者时没有人帮我们说话……',
#  '预判的没错，果然第三天就不在热搜上了。要么因为影响太恶劣，要么因为已经在处理，又或者是因为其他新闻爆得太多了……唐山 打人',
#  '肖战 网络不是没有法律的地方哦终于做一回事了，谢谢你。',
#  '如果真的只能靠实名举报，靠上微博热搜才能曝光存在的问题，相关部门才去解决问题。那这个GJ和社会还有希望吗？几代人的努力都白费了！',
#  '这个博主提供的第二个视频已经没了，不知道是不是这次社会事件影响较大，为避免再扩大影响范围，被强制下掉了……而且！！！第二段监控视频结束了但他们的暴行没有结束！因为后面他们还追着两个另外女生打，被打最狠的倒地的也站起来冲过去了。是在监控死角拍不到了，光线也很黑暗！但惨叫声和辱骂声还是听得到呀！所以第二段视频也不完整！！也求求大家不要再说什么性别了，只要是施暴者就该严惩！！ 唐山 打人',
#  '求求别再搞受害者性别是女性的话题了！我们该关注的是施暴者该受到法律的严惩！而不是一直在说“girls help girls”！这样只会让人偏移这场恶劣社会事件的关注点！我们是要为受害者发声，不只是为女性发声啊……唐山 打人',
#  '唐山 打人社会要闻，必须严惩施暴者！！！不能让人民群众受到伤害！让我们清醒的人伤心！',
#  '七月，威海摆烂之旅🌊找到了看镜头就尴尬不自然的补救！iphone电影模式录视频—然后截图 虽然模糊但莫名感jio更生动有故事感？-感谢📷的可爱们和自力更生的我自己 威海',
#  '真正的“生活”大概是不用动太多脑子简单而快乐的平凡小事—【忍不住记录的一些美好库存📷】 威海',
#  '大海是通往夏天的路口🌊 威海',
#  '撸着串抬头看到一家超级猩猩手里的肉串鱿鱼牛蛙…瞬间就更香了第一餐堂食伴随着路边广场舞阿姨的音乐交待给充斥着毒蚊子的晚风🍻',
#  '我永远爱周五晚上🌃🌃🌃',
#  '【热量爆炸日VLOG】听说马上要恢复堂食了？！这是真的吗 一只蛋Demi',
#  '无法堂食就把堂食搬回家！两点多吃到八点多一刻也没有停歇点的宅烤兄弟，连烤盘一起安排上 ·月星环球港',
#  '夏日么么茶🍹',
#  '七月的炙热叫嚣着诗与盛夏，一半是阳光，一半是蝉鸣。',
#  '大暑，又做了一回勇士。',
#  'BLUE BUBBLE',
#  '今天天气真好啊！',
#  '夏日香气',
#  '赶上最后一眼',
#  '堂食的快乐！',
#  '热得冒油(~Q~;)',
#  'ZIMOMO',
#  '今日份甜甜碎片已加载完毕～',
#  '解封了？',
#  '军人的生活就像一杯酒，初饮时味苦而且辣，随着时间的积蕴，会慢慢品出它的醇香与甘洌，有时一辈子饮不醉，有时沾一滴就热血沸腾。',
#  '这…啥…天地难容',
#  '想看赵丽颖，想看罗晋，但是还没看是怕看了把自己气死🙃',
#  '想知道这个KTV小姐哪里来的？MB，真是谢谢她',
#  '一个人住浦东，在市中心上班能理解，可是去普陀区的一个不知名的ktv，不明白是怎么想的，难道这个ktv是有多出名吗？哦，对，拜她所赐，现在是出名了🙃',
#  '真的谢谢这位ktv小姐🙃',
#  '阳光总在风雨后，请相信有彩虹🌈',
#  '希望不要层层加码才是真摘星🙃',
#  '逻辑力会把你从A带到B而想象力则带你云游四方OOTD',
#  '退休后楼下广场舞领舞第一候选人',
#  '总是改不了遇到好的车牌号就想要念出来的毛病～ sherry48692015',
#  '外面风轻云淡出门玩个西海岸～ sherry48692015',
#  '郭敬明一辈子都想达到的高度',
#  '这么热的天早饭还买烤红薯的人已经不多了….',
#  '按照这个成色，我估计只能去应聘保安了唉….服务行业也这么卷了嘛 sherry48692015',
#  '瓜摊老板瓜我只有我受伤的世界完成了',
#  '女盆友说留胡子就像个gay',
#  '今天一点都不热，也就是刚洗完的裤衩，出去走十分钟就干了的水平',
#  '日本自卫队射击准度VS日本先进的医疗技术哪一个输了都丢脸的事情',
#  '用生命上个热搜，真是为难你了，我喝酒不行，我坐小孩那桌',
#  '平时爱去靖国神社的人运气都不会太差',
#  '美国：背后连中数枪，自杀安倍：是的，爸爸',
#  '靖国神社喜提一个牌位',
#  '确实“雄壮”把我凡哥的热搜第一都给抢了唐山 打人 sherry48692015',
#  '流量好好拍戏赚你的钱就好了，考编又是为哪般，为给粉丝吹b嘛，大可不必，普罗大众真是越发难了，旱的旱，涝的涝',
#  '我们周周一如既往喜欢华丽丽的风格',
#  '有没有彩虹告诉我，能不能把我的愿望还给我～希望是好运的开始',
#  '我实在不懂这些主创有什么资格抵制罗琳，饭吃饱了就把碗砸了嘛？离谱！',
#  '如月的题材是我感兴趣的，但选角。。。我真的好爱都市奇幻剧啊，还有没有好看的，司藤烂尾真的恨！',
#  '看了一下鹅今天发的大剧片单，好饼大饼都牢牢攥在中生手里，可别再哭丧没好饼了，女演员抱怨就算了，中生真是没资格！',
#  '是专辑，不是单曲诶周周gkd我可太期待了，啥时候再开演唱会吧周杰伦',
#  '星落这原声是认真的嘛，男女主都不太行配音吧，太奇怪了电视剧星落凝成糖',
#  'ab和小赖的新剧是翻拍那个韩剧《经常请吃饭的姐姐》嘛？那部韩剧前期真的巨甜，小奶狗天花板，不过我好像没看完，中后期麻烦事儿一多就不想看了就想看纯纯纯甜甜的恋爱星姐微博',
#  '最爱的浪姐舞台没有之一！永远为大vocal疯狂心动。那英嗓音一出来就立马沉浸其中了，这个舞台也是让我第一次get到周笔畅的唱功，嗓音也非常有故事感，后面的和声唱的真的很绝，和那姐和吉克和得都非常和谐，还有最最最后的清唱真的太好听了，那姐和笔笔和在一块完美收尾，余音绕梁了属于是微博综艺',
#  '做一杯冷萃咖啡，器具极简单，萃取需要12小时以上，不存在失败的可能；做一杯Espresso浓缩咖啡，器具繁杂，萃取不超过30秒，制作过程稍有偏差就翻车……复杂的事情可以慢慢掌握，复杂的人就得远离……',
#  '酷暑难耐的周末，用一杯冷萃咖啡唤醒自己…',
#  '一早去加油，中石化APP剩下100多元余额，充500，余额没变，再充500，还是没变。遇到“吃币老虎机”啊！油站人员说“系统故障”，只能加100多元余额了。之后油站人员说“先生，给个评论吧！”，我说：你们吞我钱了还要好评吗？对方说：那你就不用评论了……下次我送锦旗吧！',
#  '绿植都进室内，人更没法出门了。下一周还是高温……',
#  '一个经常在网络平台上“辟谣”的记者，突然发短文造了“夏蝉”的谣言，学了一把鲁迅的文风。之后又立马删除，再来一通“自我批评”……这何必呢，节操和忠诚都被你玩丢了！',
#  '核酸大筛是每周日必做的功课。查看自己绿码是5天前的核酸，啥地方都去不成了。小区里的9号楼又被封闭了……新冠病毒一直在演化，而抗疫手段仍然似“唐吉柯德大战风车”般的执着……',
#  '怎么会有这么难看的尾灯设计，跟车在后面感受万丈光芒的照耀……',
#  '昨晚下楼倒垃圾，电梯下到一楼发现口罩忘戴，趁着夜色匆匆倒完，回家不敢坐电梯了，爬16层楼梯；想做糟毛豆，发现糟卤用完，去隔壁超市，扫码显示核酸超72小时禁止进入……没残疾，却寸步难行！',
#  '5月初下的订单，今天总算把空调给安装了，明天是核酸大筛肯定装不成。如今，还有什么事能比核酸更重要？',
#  '每隔两天掏一次口水，还不用花钱，国富民强！偷着乐…',
#  '江宁街道的通知7:00-10:00核酸，没说封闭，居委通知加码“7:00-10:00核酸期间封闭管理”，到了保安那里，我6:40出小区，说封闭不给出……媚上，是全民推广的品质！',
#  '某人出差，必须自力更生了。早餐：黑米大米粥，鲜虾饼（半成品，平底锅煎熟）。午餐：绿豆米糊；粢饭团绿豆米糊：——绿豆，大米，牛奶，冰糖，豆浆机米糊模式。粢饭团：用料：糯米（电饭锅煮成饭） 咸蛋黄（压碎） 肉松 咸菜笋丝（辣味） 萝卜干（辣味）保鲜膜上铺糯米饭，摊平，逐一铺上自己爱好的食材，捏起来。茶：金丝菊＋柠檬————————',
#  '又是一个超高温日！早饭吃完收拾好，已经出汗了。这种天气外出，戴着口罩捂一脸的汗水，又狼狈、又不舒服。果断放弃外出计划，还是家里蹲空调吧。从周三开始到今天周六，小区每晚18：00开始封闭，全员核酸。周三之前是核酸采样结束就解封。周三起改为晚上六点封到次日上午，凭24H核酸阴性绿码出小区大门。封闭期间只进不出，九点前进来的人在小区门口当场核酸采样，当晚不得外出。过了晚上九点回小区的人，必须在外做好核酸检测再回来。某人周五周六又出差了。昨晚吃饭时就在考虑明天的早饭和午饭吃啥。想着要不然收拾好去门口“钱大妈”看看买点回来。转念一想，今晚出不去了。忽然就对自由有了很明晰的了解：你可以不用，却不能没有。——————',
#  '今天某人出差苏州，当天回。这是继四月份以来某人第一次出市。晚饭后无意间发现小区门口怎么排了一排人和车，还闹哄哄的。一看楼群，原来今天突然增加了一次核酸大筛。按惯例，六点半封闭小区，七点开始检测。昨天刚刚大筛过，怎么又筛？有邻居说，因为八村爆了一个阳性。某人九点钟到家，感慨的告诉我：今天小区特别严格，大门口还设了一个核酸检测点，进小区的人必须做了核酸才能进。而且只进不出，要离开，必须等明早结果出来。本来司机还打算送他到家，顺便进来“泄洪”，这下只能在门口放下他就离开了。今天(20日)下午举行的市疫情防控新闻发布会通报：市常态化核酸检测点继续提供免费检测服务至2022年8月31日。看来，今年的抗疫任重道远，大家还需继续忍耐和配合。————————————————',
#  '高温记录。',
#  '前两年新冠病毒到夏天就销声匿迹了。今年的抗疫行动延伸到七月，变成升级打怪版了。早上出门显示32度，下班时显示42度。晚上七点多出门，去小区对面买咖啡，感觉室外就是一个大烤炉，而我是一块行走的五花肉，撒一把孜然和香辣粉就能吃了。————————————',
#  '连着三天都是40度的高温，也不知道是不是太热了，茉莉花都开不长久，只一天，就从花托上自由落体了。',
#  '下班到家时，茉莉花还是含苞待放的状态，刚刚去晾衣服，惊喜的发现她静悄悄的开了。小小的茉莉花，既没有牡丹芍药的雍容华贵，也没有玫瑰月季的艳丽色彩，她冰清玉洁，馥郁芬芳，独自幽幽散发着独特的香味，默默提醒人们她的存在。喝过无数次茉莉花茶，却是第一次种茉莉花。开花的惊喜，冲淡了这几天疫情带来的紧张感。由KTV传播扩散的这波疫情，数字一天天的在增长。身边的话题从高考、中考到又开始讨论是否囤货，是不是会封控。反正再怎么样，也不可能像四五月份那样。——————————————',
#  '平凡的今天，在两声枪响后，成为了不平凡的日子——日本首相安倍晋三发表演讲时被枪杀。而平凡的今天，是某人的生日。前几天和他商量生日蛋糕买哪家的，他说不要买，把冰箱里冻的榴莲蛋糕拿出来凑数就行。大热天过生日，某人每年都不愿意买蛋糕。下班上车时一看，副驾驶座上一个蛋糕，立马反应过来，是某人的徒弟又给买了。今晚七点，街道又追加一次核酸大筛查。除了周日的常态化核酸大筛，本周二、三、五，因为KTV疫情的传播，追加了三次核酸大筛。算了算，本周得做5次核酸检测。距离妈妈的八十大寿还有两个多月，疫情如此反复无常，嫂子担心到时候我们无法回家给妈妈做寿。这个也只能看运气了。——————————————',
#  '今天下班后，和某人一起参加老友聚会。上周定下今天的聚会后，这两天疫情又爆发了一波，我一直在想会不会因此取消，直到下班某人过来接我去饭店，才安心。四五个月未见，又是经历了两个月的封控，老友们再次相聚，大家都有许多感慨。很庆幸，大家都平安的度过非常时期了，此刻，没有什么比“如常”更让人觉得珍贵的了。',
#  '红玫瑰刚刚淡出记忆，第三季“我为歌狂”拉开序幕。此时此刻，张国荣的“风再起”响起。。。。。。',
#  '某人三月份买的茉莉花，光秃秃的没有叶子没有芽。慢慢萌出第一颗新芽，长出枝叶，修剪下来的枝叶随手插在一边，没想到也能成活，而且花苞比枝干上的打得还快。真是出乎我的意料。',
#  '曾经惊艳了我枯燥的青春，开阔并影响了我整个人生视野的作家——倪匡先生，愿你以另一种生命形式继续存在！',
#  '今天根据空气炸锅提供的食谱配方，尝试了一下酸奶蛋糕。两个鸡蛋打匀，加入20克玉米淀粉再打匀，再加入一罐200克的莫斯利安酸奶、一勺糖，一起打匀。蛋糕糊倒入模具，敦出气泡，放入空气炸锅，启动蛋糕模式（160°/20分钟）。最终成品烂了一点，要调整玉米淀粉的量，下次再试试。',
#  '《后娘》，作者：元月月半，题材：穿越。女主前生是个服装设计师，不婚不育主义者，一朝醒来成了六十年代一个农村姑娘，只能嫁给一个丧偶、有三个儿子的军官，打算过几年就离婚。谁知，过着过着，又多了四个儿子。婚后的生活，每天就是和丈夫、7个儿子、邻居、各色亲戚斗智斗勇，想方设法利用各种有限的粮票布票食物把日子尽量过得好一点。文中人物个性鲜明，文风轻松欢乐，诙谐幽默，故事情节紧凑不拖沓，画面感很强，让人读来欲罢不能。并且边读边幻想哪些演员适合出演，拍成电视剧的话一定会大火。',
#  '封城期间看到八零后表妹用空气炸锅做了好多菜，忽然就心动了。对比了几家，选择了西兰普的4.5升款可视空气炸锅，颜值合意，价格更低，网评不错。前后多次咨询客服，响应及时，回答到位。今天开锅后，第一次烤了从钱大妈买的新奥尔良半成品鸡翅，体验不错，大热天的又节约人工、又节约了油。有空再逐一尝试蛋糕等其它模式。',
#  '今天又是小区常态化核酸大筛查的日子。因为要推轮椅不能打伞，出门前全副武装：鸭舌帽，长袖防晒衣。8：30核酸采样回到家时，口罩捂了一脸的汗水。九点半，敲门声响起，是某大白回家了。一进门，我惊呆了：几乎整件汗衫都汗湿了。今天最高温度36度，8：30时室外温度已经31度了。想到上周二下班回小区做核酸时，两个点位，其中一个点位的采样女孩中暑了。室外37度左右的天气，大白服从头包到脚，下午16：00开始，积蓄了一天的热气包裹着人们。中暑，实在是意料之中。已经连续两天没有新增了，希望能继续保持下去，七月份结束后，是不是就有望取消常态化核酸大筛查了。我们也就拥有能自由支配的两个双休日了。',
#  '封控期过的生日，朋友们的礼物由于快递停了就延误了。今天收到了千里之外的知己好友送的生日礼物——一枚古色古香的花丝工艺香挂。生日那天，好友就说，今年的礼物你肯定会喜欢。确实令人一见心喜。香挂配了三味香片：桂花，柠檬，海洋。都是我喜欢的香味，尤其是海洋味。记得好多年前花王出了一款走珠香水，夏日里我就最爱海洋味那款。一直用了好多年才换了其它的香水。刚刚取了一片海洋味的香片放入，办公桌没地方挂放，索性就放入工作服胸口口袋，动作间就会传来久违了的熟悉的味道，清新辽远，让人闻之忘忧。这款很适合做车挂，不知道某人肯不肯，他刚开车时嫌弃车挂晃来晃去干扰视线就拿开了，一直到现在都没放。而且，香片一直在车上，又是夏季，消耗也太快了，有点舍不得。礼物很喜欢，更喜欢的是送礼物的人。',
#  '同学今天发朋友圈说了一件事：疫情期间学校限制学生上学的交通方式，亲戚家孩子骑车上学的第三天自行车就失窃了，报案后五天警察说找到了已经被改装的自行车。已经被改装了的自行车没几天就被警察找到了，我想起自己的两次遭遇，很想说，那孩子真幸运。十多年前我家一辆刚买来三个月的轻骑摩托车失窃，当时停在我爸妈楼下，一顿饭的功夫就没了，110接警后，警察说别指望找到了，小偷一到手可能立马改装了，然后就挂上淘宝给卖了。报案后，杳无声息，石沉大海。去年，某人在市一医院体检时，把才买了三个月的手机落在厕所隔间了，当时整个大厅只有他们单位的人在体检。厕所的位置很好，正对着监控摄像头。鉴于之前轻骑失窃的经验，又计划体检后即刻去外地，某人本不打算报警，同事们硬是帮他打了110。医院保安说我们无权看监控，警察说他也没权限看，做完登记后就让我们去派出所备案。我们当时急于去外地，根本不想去，因为就不指望能找回。但是110民警说必须去，这是流程，我们只能配合。备案时，医院保安来电说监控调出来了，看到在他出来后有两个人进出过。让我们跟民警说，可以去看监控。走出派出所大门后，我们再一次收获了报警后的杳无声息。医院也不是什么机密单位，某人一直和我很不理解为什么医院不给看监控，只进去过两个人，他很容易就能判断出是同事还是外人，如果是同事就更简单了。这种报案后的杳无声息，也让我们无法理解。现成的监控记录，警察调查了没有，调查到什么情况，什么原因导致找不到顺手牵羊者，起码打个电话给个说法。如果是案件过多未能及时处理，我们也能理解。但是杳无声息，如果再有下次，我报不报呢？',
#  '5.20给某人理的发，上周就看不顺眼了。今天小区封闭核酸检测，他做了志愿者回到家，索性就先理发、后洗澡了。有了电推剪的加持，果然事半功倍。集齐一套理发工具，家有托尼，随时随地。喜欢这种随心所欲、自己掌握的感觉。某人说，你练练手，等退休了，可以开启第二职业了。',
#  '上午开车去超市，停好车准备下车时，某人忽然发现手机没带。匆忙间我只想到可以申请亲属随申码，没想到操作到后面遇上了熟悉的老问题：未查询到您亲属的相关信息。仔细阅读说明才知道，亲属随申码只能给16岁以内、60岁以上的人申请。超市入口处的工作人员表示不能放行，为了防止 ...全文',
#  '今天小区增加了一次封闭式核酸筛查。比往常提前一小时，7：00开始。楼组长预测轮到我们楼大概八点半了。工作日还多睡了半小时，起床后发现床单上有一滩蚊子血，原打算下班回家换洗的。一算时间，绰绰有余，就换下来和枕套一起开洗衣机洗了。一举多得，今天这核酸做的太值了。昨天预报今天最高温度34度，黄梅天里难得的晴好天气，晚上抓紧时间洗了一大堆被遗忘的客用棉拖鞋，今天又意外的洗了床单，也算充分利用了时间和天气了。八点半核酸采样结束回到家，就等着小区解封出门上班。九点时，无意间往窗外一看，惊了！小区大门口排了一溜的私家车，等着开门。没多久还听到车主和保安吵架的声音：核酸做好了为什么还不让出去？问题是，你做好了，别人还没做好呐。三十几度的高温暴晒下，硬是坐在车里等到十点钟小区开放。油价这么贵，你这么赶时间吗？魔都人民太不容易了。上班路上收到单位微信群信息，隔壁园区设了一个核酸采样亭，每周一三五开放。这可太好了，天热了，外出做核酸可以少走不少路了。',
#  '早上刚起床，就接到外地朋友的微信，问：为什么解封半个月了，还不能给你发快递。估计是因为近期疫情又有点严峻了吧。这两天家对面小区被封了。我们镇同时有两个小区上榜了，而宝山区差不多有10例。今天我们楼里邻居，还有与我相隔一条马路的另一小区的同事，都收到了防控办的短信，根据大数据排查，近期可能与新冠感染者存在直接或间接接触的风险。。。。。。同楼邻居发了小区在进行物理隔断的施工照片。忽然就觉得心里有点堵——尽管昨天我还说了能理解、可以接受。下午接到通知，明日小区再次进行封闭式核酸筛查。而社区将每周末安排一次核酸筛查，持续到七月底。这样的形势让人仿佛又回到了三月中旬时的，好似又一个轮回的开始。莫名有点心慌慌。',
#  '今天同事们都说我剪得挺好，赞我能给自己理发，好厉害。然后本Tony 就接了人生第一单。某女同事嫌辫子长，要剪短一点，再扎起来。剪完了，同事挺满意，我自己不太满意。她头发又多又厚，最好有夹子，一层层的修剪。她自己倒说，头发扎起来的，没人看到好不好，不用那么讲究。午饭后时间有限，实在没时间精修。总觉得结束时还有点粗糙，完美主义者内心有点不爽。有时间再去多看点理发视频，提高提高。',
#  'Mark一下：人生中第一次，用一把剪刀，给自己理了发。自我评价：还能见人。自我感觉：太爽了！又一次战胜了自己的胆怯，又一次解锁新技能。给自己点个赞！',
#  '昨晚听说对面三村22：00封闭小区，今早上班路过时忘了看，问邻居三村封控没有？有回复说，就封了两个小时，是不是封错了？下午有邻居发了三村被蓝铁皮封闭的大门照片，和另一个出口的视频，确实是封了。感觉三村真是命运多舛，三月份就被封过，现在又封。楼组长发了一份文件，明显感觉自己有需要去进修一下语文阅读理解，看个文件咋这么费劲呢？大家揣摩了一下总结出大意：小区要分块隔断。这样万一有阳，也能减少传染范围，降低封控区域，最大限度减少损失和影响。这个物理隔断的做法，可能比较费铁皮，我个人表示理解和接受。也不知道奥密克戎啥时候能消停，还给我们正常的生活状态。',
#  '今天上午，小区做完封闭式核酸大筛查后，妈妈来电说，药收到了。11：30左右，小区解封了。至此，我安心的吐出一口气。今天入梅了，又到了一年里我最讨厌的时节。晚饭前，楼栋群里有邻居说，对面小区中招了，晚上要封小区，放居民出去买菜了。感觉奥密克戎像个神出鬼没的杀手，你以为它消停了，它就出来博个存在感。忽然就觉得同事们在单位囤方便面，备睡袋、洗漱用品很有必要。晚上也收拾一点吧，有备无患。',
#  '这个双休日，很多小区进行封闭式核酸大筛查，我们小区定在明天上午。除了前几天刚爆出来的红玫瑰美容院，又陆续有几个小区、和一家苏宁被爆出阳性。我一个表弟家小区也出了一个阳性。原本他已经接到复工通知了，这下只好继续家里蹲。到明天，他在家就蹲满三个月了。表妹开玩笑：3－4个月，你这是休产假呐！对于这次封闭筛查，大家都有点惶恐不安，害怕一夜回到解放前，又被关起来了。在这种心态下，只能继续囤货不松懈，包括药。妈妈的四种常用药，五月份由我们居委代配了三种，只是因为没有交代，有的医生不敢把量开足。复工后，6/07，同事的老公又帮忙去配了一次，把第四种空缺的药给配到了。这个药只在杨浦区的市东医院有配，目前该医院对外停诊中。四种药攒齐了，但是量不足。赶着今日再去配一次，下午一起发快递。今天医生很好，三种药都给我开足了。我还顺带给一位核酸报告没出来、进不了医院、急得直跺脚的陌生大姐代配药了。全程耗费一个多小时，还算快。和买菜的某人汇合后，某人说今天买菜像抢的，他也排了好几次队。到家预约顺丰上门取件，谁知还是因疫情地区无法寄递。最后还是把寄件地址改到单位才顺利下单了。午饭后把药送到了单位门卫室，顺便洗了车又加了油，6/14油价又上涨了。刚刚看到“发布”又发布了新内容，息息相关的两条是：一，七日内没有核酸检测就赋黄码。二，七月份依然免费核酸检测。昨天通知上说采样结束即刻解封，我当时还琢磨着为什么不等核酸检测报告出来再决定？万一发现阳性呢？刚刚某人又接通知：明天核酸筛查由镇防控办下令后全镇统一解封！瞧这补丁打的！！今天菜也买了，药也寄了，明天小区无论阴阳，我都可以高枕无忧了。',
#  '#mini vlog# kuku_guo',
#  '每天都在找猫猫',
#  '不怕生的小黑豆，睡姿都这么肆意',
#  '这个睡姿是几个意思',
#  '李佳琦为啥不直播了，这个618都不知道买啥了',
#  '疫情，金山事件，唐山事件，社会越来越可怕，资本化越来越严重，负面消息压得人喘不气',
#  '酷夏来吓唬小鸟的猫',
#  '高薪的行业，以前薪资更高，里面不乏清北复交，世界前50强的高材生。现在要均富，看不得这些。',
#  '现在的工作就是稳定的不能再稳定的状态，固定的收入，固定的时间，相似的事情。没有任何波澜的时候，人反而会躁动，像我，现在总在想工作之外的事情。不满足才能进步，也可能退步。',
#  '38岁，已然成了部门的老人家。新来的90.93，92，大厂背景，来养老了，😂',
#  '餐饮是出现了一个品牌，然后你就会在各个商场，快速的见到这些品牌，现在吃个午饭，商场-1F - 5F的餐饮都是雷同，每个商场都类似，我们不需要雷同啊，我们想要体验不一样的店，不一样的口味，同样的川菜，不同的厨子都是不同的味道。现在一个品牌一个味道。',
#  '小区里组织募捐，加了微信，发现朋友圈是卖东西，不过也有个专业对口号，捐赠衣物玩具的。又加两个退休阿姨，也是朋友圈疯狂卖东西。我觉得真的卖不出去多少，退休了就不能清净吗？',
#  '凌霄花也美我不愿中的原因，太好养，一颗种下，方圆10米地下都是它的根系',
#  '来了15年了，鲜肉月饼还是爱不了。吃不下😂',
#  '副业的尽头就是卖货？不想卖货。',
#  '身边都是辛苦的打工族，国企事业单位还是不允许离沪。目前看玩的High的有幼儿园老师，法式点心师，退休年轻姥姥，保险员工。',
#  '现在的半成品食材太多了，以至于不知道出去能吃点啥。',
#  '看了身边很多生活方式，大家还没有去郊区租院子，上周去了青浦，发现院子，农村比嘉定面积大很多。大面积的农田，院子，真不错。比崇明岛近。',
#  '看到那个骂北海隔离环境差的，当初骂的那批人又上了。',
#  '疫情打乱了所有的节奏，无法探亲，无法旅游，甚至无地释放压抑的情绪。反复的疫情，让本来已经开放堂食的餐饮雪上加霜，能全身而退关店都是好事，就是退了也没有好干的职业。看着小区餐饮店老板还在继续搞团购，也是散淡的生意，真是压抑～有人真的是在努力的活着吧。',
#  '现在买理财都这么刺激了。半年了，收益1%不到，不如活期理财。低息接受不了，其他银行也不敢买。',
#  '有房，有车，有娃，无贷款。存款200万在什么水平，现在身边好像一抓一大把的水平，主要是200万也买不起2套房。',
#  '一二四公司核酸必做六日二四小区核酸必做一周桶7次另加工作日抗原5次比封闭期是桶的多',
#  '闹心。我老家，亲戚都在宿州，淮北，徐州，都有病例，家族群里都是讨论。',
#  '最近的大蓝天',
#  '夏天吃茶去',
#  '除了地铁，最拥挤的就是医院了',
#  '今天好兆头7-1公司全员复工雨后看到彩虹🌈',
#  '昨天去逛了下家旁边的商场，原来运营的不太行，不少店面死气沉沉没有生意，现在真是各种小店满满，像夜市的感觉，灯火通明，冷气十足，就连厕所也舍得给卫生纸了。要不行的店换成新店很快，大家活力十足要赚回来的样子。中午去逛了公司楼下那个高端商场，嗯，没人，真的没人，一个人都没的那种。 ...全文',
#  '南汇赶海，人山人海。😂大家这是怎么啦，疫情后的释放？带娃去商场，家人都不同意说是密闭空间',
#  '检验一个家庭运作、子女教育的能力，高考成绩真是人生很重要的一部分。',
#  '6.1日解封，旁边的美丽的湖泊就开始跃跃欲动。跑步的，游泳的，还有带着皮划艇的。这里不是机构办学培训地址，就每天看到有不少人去游泳，去滑皮划艇。这两年各个机构教小孩子皮划艇的特别多。总感觉不安全，但孩子都有大人陪着的吧，为何政府不管管，都是野游的人，皮划艇的人。持续了20来天，昨天几个大小伙子带着皮划艇。。。然后就真的发生了悲剧，一人溺亡。野泳不安全，学校不是每学期都教育吗？家长也懂的啊，但就是发生了。。。可悲的是人在搜救的时候，湖面上还有继续野泳皮划艇的人，这是憋疯了，封久了？脑子也不正常了？疫情过后，休闲娱乐方式确实变了。大多数人不敢去商场，怕封在里面，大家在室外搭帐篷玩水。',
#  '今天溜达了一圈，1楼的小店铺俗称苍蝇馆子都还在，大家买了带走吃，甚至围满了人。那个商场地下的关了2家店，疫情前生意也不好，房租+员工，肯定都是负的，关了也是减少损失。',
#  '田里家里公司大概小时候生活在田园，去一下野外田地格外放松',
#  '上班了，地铁里还是一样的拥挤。清一色的年轻人，咋这么多年轻人，一点老人家都没有，因为又要扫码到处都还有疫情，老年人也不出来溜达了。中老年都很少，清一色20.30岁，要么大家都显得年轻，反正40以上也很少看到。',
#  '一朋友，42岁，也算遇到了中年危机，工作上领导不赏识，但也没有裁员如何，只是工作起来有些郁闷。但是他本人比较保守，目前看来无任何风险：本地人，郊区2套房，无房贷。没有换市区，没有买学区房。这些年兢兢业业工作，老婆不全职，手里无存款，有钱不买豪车。没有生2胎。一直同步发展副业，虽然没发展起来。就算是失业，他的资金也够撑到女儿工作。存款真是底气。',
#  '门口商业一家卖菜的，带着一个小娃不到1岁，每天睡在婴儿车里。满脸的蚊子包肿块。疫情前，对他们没印象。疫情，需要买菜才熟悉，看老板娘微信又是表，又是BM W车的，还老家买商铺之类的，老板一家赚的不少应该。但是这娃娃确实跟着受苦了，一家子扑在菜摊上，有时候就把娃娃放在围起来的纸壳子里，小区内租了个毛坯房住。就算是苦，他们估计也愿意在这里卖菜，毕竟能赚到钱。',
#  '今天是我的生日06月12日，来祝福我吧~',
#  '娃在身边觉得烦不在身边又觉得冷清',
#  '这眼神无敌了，找到同类了 杭州',
#  '猫咛',
#  '陪伴是最长情的告白',
#  '最近上下班都是国金地下穿梭到🚇陆家嘴6号口的，今年太难了，希望都平安吧',
#  '娃的快乐🦀️',
#  '陪娃模式开启🔛🚗🌊🏖️ 日照',
#  '隔离结束🔚顶着32度的大太阳出门 如皋市',
#  '其实你已经和很多人见完了这辈子最后一面爷爷一路走好 🙏你是为了去天堂陪我爸爸所以选择了今天吗',
#  '周末给娃做个早餐🥛',
#  '我既焦虑又期待未知',
#  '又在和朋友谈天说地胡吃海喝！呜呜呜每一次见面都要好好相聚',
#  '生活太苦了好期待元宇宙的到来',
#  '哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈哈狠狠共情',
#  '怎么会有这么多好看的衣服！！！这么多好看的鞋子！！这么多好看的美女穿的这么好看！！！我真的不想买忍不住',
#  '跳舞太快乐了',
#  '不想上班 就发照片',
#  '不瞒大家说：我的小梦想就是在高校开瑞幸咖啡',
#  'e大mo',
#  '大家好 我下班了 +新玩具',
#  '每天都好困🥱',
#  '如果可以不计后果做自己喜欢的事就好了',
#  '互相试探是真的不好玩',
#  '舒服工作室视角阿',
#  '杭州也很不错啊 我可太快乐了 想到马上要回打工了 悲从中来。和博姐沉浸杭州之旅真的快乐爆炸！！！我吃了好多好吃的！！！我立下flag 多旅游多旅游多旅游',
#  '美美做作！开心摆烂！ 杭州',
#  '人一旦进入舒适区…就是一整个松弛废物得状态',
#  '呜呜呜呜小学最好的朋友结婚了，想当初就是每天一起放学一路吃回来。今天终于不下雨了，天空也太好看了！！！ 福建的海鲜是真的不错子！！',
#  '快乐的秘密是㊙️美丽的秘密是㊙️',
#  '呜呜呜呜福州快乐老家',
#  '对不想做的事情直接说不，对恶意加价的机构说不，对不想回答的事情冷眼。太舒服了 今天又是突破讨好性格的一天',
#  '看了微博心情沉重，但我妈还是说：女生要保护好自己，晚上不要喝酒不要穿暴露。即使这些都是男的错，但惩罚在我们身上。真的好无奈',
#  '控制在30分钟内爬完十圈⭕用运动扫除疲惫 ·馨佳园七街坊',
#  '周末怎么过的这么快ppt还没写完最讨厌周日晚上还要熬夜忙工作好烦躁 ·馨佳园七街坊',
#  '错过广富林的落日🌇但夜景也是别有风情 ·广富林文化遗址',
#  '废了四天时间追完连续剧➕小说好多年没有追过剧的我差点磕死在剧里除了刘亦菲&陈晓实在想不出还有谁更适合演男女主',
#  '左后背忽然肌肉拉伤刺痛动不了了今天完结 ·馨佳园七街坊',
#  '计划全部打乱',
#  '晨起爬十圈⭕享受暴汗的感觉 ·馨佳园七街坊',
#  '只要在办公室就饿的特别厉害办公室才是我发月半的根源 ·龙阳广场',
#  '早起有早饭吃空气炸锅快手届的yyyds ·馨佳园七街坊',
#  '就是找不到一条合适的黑裙子 ·馨佳园七街坊',
#  '周末也要动起来 ·馨佳园七街坊',
#  '一天中难得安静一下下 ·高境二村',
#  '疫情后第一次见面各种女人间的八卦 ·合生汇',
#  '居家办公的好处就是可以有足够的时间进行锻炼 ·馨佳园七街坊',
#  '半小时爬了十圈⭕13层楼一扫今天疲惫 ·馨佳园七街坊',
#  '写PPT审PPT改PPT心脏病都要出来了 ·龙阳路(地铁站)',
#  '每次写集团报告＝熬夜 ·馨佳园七街坊',
#  '从医院骑回家坐垫晒爆了 ·龙湖宝山天街',
#  '每月一次的ppt总结报告比我大姨妈还要准时 又要熬夜写✍🏻了 ·馨佳园七街坊',
#  '好像是错过了很多很好玩的事情放弃了曾经让我小小骄傲一把的兴趣我对什么都索然无趣人生真的很无聊但我又赖着这样的生活 ·龙阳广场',
#  '今天终于把头发放下来了期待再次长发 ·麦德龙(浦东店)',
#  '我所闻星子深深日走月沉 ·馨佳园七街坊',
#  '饿的都坐不动了怎么会还没有开完 ·龙阳路(地铁站)',
#  '快要冻死在地铁上了 ·龙阳路(地铁站)',
#  '绿色棒棒糖🍭0糖0脂0美味准备下班 ·龙阳路(地铁站)',
#  '今天是我喜欢的配色',
#  '今日重游曾经工作服的地方空气中充满着熟悉的味道和回忆·海洋水族馆 ·海洋水族馆',
#  '纪念下让人难忘的三个月',
#  '爬楼真的是超级大的有氧运动爬了半个小时楼梯浑身湿透，汗水跟雨水一样往下滴 ·馨佳园七街坊',
#  '空气炸锅超级棒👍🏻懒人做菜极佳伴侣',
#  '我这把年纪熬个夜就跟要死过去一样',
#  '宜家直接变成游乐场 ·宜家家居 IKEA(宝山商场)',
#  '晚上逛到武康路，发现那里的人和我们好像是两个世界的，基本晚上出来的都不戴口罩，戴口罩的反而变成异类。不知道为什么。 ·淮海中路与武康路交叉口',
#  '很多人问我要ppt的模板其实他们不知道每次模板设计我都要花很多时间哪有天上掉下来的好看模板',
#  '0点30了我还一个字都没写 ·馨佳园七街坊',
#  '咖啡＝加班把夜熬起来 ·馨佳园七街坊',
#  '不欠天地终欠父母',
#  '明明有很多选择但总觉得没有一样属于我 ·馨佳园七街坊',
#  '很多时候人身上一些小毛病真的很莫名其妙 ·馨佳园七街坊',
#  '若能再多看一眼滚烫的心 炙热的眼你的泪滴落的瞬间滑过我的脸还没开始却道再见就算来不及相恋刹那之间 镌刻永远昨日的情景再浮现流荡在心底化一缕烟 飘散。。。我能想到一个人的苦有多苦但没想到一个人的苦竟然会这么苦有的人的人生像道流星璀璨而绚烂但很少有人知道在这道光的背后忍受了多少漫长的孤寂黑夜他们的出现仿佛就是为了完成一场人世间的救赎轰轰烈烈 20岁，应该是风一般的年纪，去爱，去歌唱，去拼搏但有人的20岁却已经走完了一生这些人，我们不该忘记',
#  '还是上班的感觉好 ·龙阳路(地铁站)',
#  '回头来看，所有的结果是早早种下的因，人生的十字路口是走过了才发现的。在过十字路口的时候，往往因为无人询问，无人帮扶而凭借直接过去。看不清路的前面到底是什么。走一步算一步看似贬义，但却是大部分普通人终身的人生状态。人生短短几十年，大部分都充斥着无奈和后悔。',
#  '线下涨价好厉害连丰巢都从5角直接涨到一块了 ·馨佳园七街坊',
#  '鹅嘴夺食。隔壁竟然把翠冠梨喂鹅，已经喂掉了一袋子，说剩下的这些太丑了送不出手',
#  '独自拥有的好景',
#  '村里一角',
#  '叫不出名字的桃子，但比白凤湖景好吃，甜度超高，水分也多',
#  '小岛风情 ·东风西沙水库 嘎嘎嘎梁',
#  '#黄健翔 男足除了不让巾帼其他国都让#让什么让，咱男足就是巾国队，下面没有滴',
#  '修油烟机的师傅一定没想到，请他来掏了个鸟窝',
#  '偶然看到卖蔬菜的老农在卖玫瑰香和醉金香，现在很少看到有人卖玫瑰香了，醉金香也大部分都是假货，浓郁的玫瑰味和茉莉味是它们特殊的标志。他们不像阳光玫瑰那样纯甜，但酸甜比恰恰好，清爽不腻。',
#  '微信响了好几下，打开没消息是怎么回事，会不会和刚才更新鸿蒙系统有关',
#  '百分百泄题了，正常的题目现在谁还去手写，掩盖一些不能被人知道的东西才会手抄。源头应该不是在这个人手里，而是有人不懂这题才会问他，其它会的那些都不问他了',
#  '感觉可以打爆',
#  '楼下阿姐说昙花开了，快来看',
#  '65w的笔记本充电器充40w的手机是30w',
#  '出息了 出息了 李肖娜Vivian',
#  '最近沸沸扬扬的四字事件，结果如何，国家话剧院尚未公布，拭目以待。流量时代，商业利益是否可以凌驾于规则之上？某些潜规则是否可以捅破？小镇做题家的努力和呐喊有用吗？别忘了，和谐是这个时代的主旋律。',
#  '第一位知道后面两位不认识。',
#  '玩文字游戏，都公示了！有人公示后没被录取的吗？',
#  '王一博 今日路过 ·全家便利店(西藏南路店)',
#  '我已为2022微博电影之夜《热烈》助力打卡， 好友 快来和我一起分享你的年度期待影片，为电影市场加薪助燃，还有机会获得由微博电影送出的惊喜奖励！2022微博电影之夜年度期待电影',
#  '聚力·焕新！耀视界！参与2022我推荐王一博，和王一博一起见证微光盛典“观众喜爱”荣耀的诞生！ 2022微博视界大会微光荣耀推荐',
#  '"满足你所有的少女心，来一场超现实的恋爱吧！"',
#  '所有不经意的风，其实都有迹可循。',
#  '在喧闹夏日，与他共享海边的一角沁凉。',
#  '圈内人的自嗨，不是我们这种圈外人能懂的。 内娱的电影哪里看得到百花齐放，明明就是易！家！独！大！',
#  '喜大普奔！○( ＾皿＾)っHiahiahia…我在王一博超话等级达到LV.13，获得人气粉丝头衔，快来 王一博夸我优秀！',
#  '享受不需要靠核酸证明健康的自由从容和谐 宁波',
#  '杨浦又怎么啦？每次一刀切的时候应该说封还是自愿静态？这年头玩死实体',
#  '六倍怎么统计的，是速度还是覆盖面，还是的方式，但凡有数字请负责一点，告知数字来源，给原始链接',
#  '太激进了，把喵喵工作落实到孩子头上，养老靠儿孙',
#  '如果图一不是在酒店大堂看到，一定以为是科幻片，穿的人心情怎么样？荒唐总会结束，会不会回忆起来很尴尬。这三个月的魔幻玩够就散吧。生病吃药，但居委这组织胆子真大，竟然给每户发药，有出来解释的吗 ·浦东假日酒店',
#  '打疫苗的推行已经到了无孔不入的地步，以自愿的原则，远离这些朋友亲人',
#  '这个政策下，没人能独善其身。',
#  '疫苗都能那么卷了么？谁能为生命负责',
#  '天桥下的公寓散发浓浓的市井气息，很真实的人家生活 ·沪西老弄堂面馆(雁荡路店)',
#  '曾经举报拿大奖的地方，这次要不要继续',
#  '走在告别四个月的淮海路，心里讲不出的失落，还是熟悉的装修，但感觉蒙上一层灰，曾经欣赏的精致、优雅因张贴了各种防疫告示和店门口查码的蓝衣服人，时刻提醒大家离解封和自由很远，生活也没正常。因为扫码，阻挡了购物的热情，因为没有堂食，歇脚的地方也没有，来去匆匆半小时就想往回走 ·淮海路商业街',
#  '华润时代门口的纳凉椅成了一道风景，所谓解封又要扫码，又不能堂食，难得还能找到一个可以坐下聊天的地方 ·华润时代广场',
#  '总想能恢复到 前的生活，但是每天看到的 诡异地出现在街头小区，提醒大家我们一直是数字码的奴隶，我们不被接纳，甚至脸上厕所都要时效。疫情',
#  '解封了，人心散了，就看图，不说话',
#  '周末·世纪大都会世纪大都会地下二楼，完全失去了往日的活力，还在囤货吗？来这里 一切都是最好最好',
#  '怀平常心 做眼前事 爱身边人',
#  '内在的良心和外部的信任，不是从天上掉下来的，是经年累月苦心经营的结果。',
#  '园区里一位六岁的小朋友对我说：“美女，我找到《孤勇者》的日文版”。我：“爱你孤身走暗巷。”她：“爱你不跪的模样，爱你对峙过绝望，不肯哭一场。”',
#  '昨夜炖了近三小时的“四果汤”，冷却后放入冰箱。早上一碗冰镇“四果汤”，炎热的夏季开胃健脾，安神补血，清心醒脾，清热祛湿🍵',
#  '想吃豆腐包了',
#  '所谓相由心生，人心还是善点儿好，否则一张脸都是透漏着丑陋。',
#  '一家有意思的小店',
#  '分享图片 杭州·千岛湖风景旅游区',
#  '晚上回小区需要扫场所码入内。扫了保安手中的场所码进去，他点头示意谢谢配合。炎热的夜晚，没有一丝风。站在门口的保安突然让我觉得特别不容易。回家后从冰箱里拿出一瓶冰芒果汁给他送去“给你送一瓶冰的芒果汁，解暑用。”他连忙说谢谢。走出一段距离后回头看看是否喝了，竟发现他望着我的方向。我想，在这个陌生的城市里我的一点小善举如果能给他带去一丝温暖便好。走在回去的路上我又想起多年前在环贸地铁口帮助的那对父子，是否还留在这座城市，是否生活的比当时好些。',
#  '昨晚梦见安安和他的爷爷奶奶。好奇怪的梦。',
#  '人为了自己利益，撒谎起来是真的可怕。可以扭曲事实，污蔑他人。',
#  '不负梦而来，不离梦而去。',
#  '顾千帆 请你吃雪糕',
#  'double rainbow🌈',
#  '今晚没有追赵盼儿和顾千帆，因为知道剧情开始虐了。实在受不了这样的剧情，所以没有心情看完两集后再等着明晚的八点。于是准备等到多更新几集后一口气看。哎，我真的接受不了这样不完美的感觉。',
#  '今天在咖啡馆，一位小朋友忽然坐在我面前“姐姐，我可以和你聊天吗？”我诧异的问道“嗯……为什么想和我聊天呢？”“因为你长得漂亮。”我不好意思的笑着说“谢谢你啊，你上几年级了呢？”“幼儿园大班，马上一年级了。”聊了几句后，小朋友一直盯着我看，我略显尴尬的笑着说，“你盯着姐姐看我都不好意思了呢。”她的妈妈在一旁也笑了起来。小朋友和我聊很多，聊了一个小时。我真的蛮享受这样的时光，以前到现在我的朋友总说你真有孩子缘。我想，当你保有一颗善良纯真的心时，孩子的眼睛不会说谎。我爱这些小确幸',
#  '有时候我真是一个较真的人 换句话就是有原则不喜欢虚伪',
#  '恭喜亲爱的堂弟今天大婚因疫情遗憾不能参加',
#  "We're going throug all the sudden things in life , unprepared , just like an actor in the first row . If the first rehearsal in life is life itself , what is the value of life ?——《The Unbearable Lightness of Being》Milan Kundera",
#  '盼儿和千帆太好磕了',
#  '✐. 𝟚𝟘𝟚𝟚.𝟜.𝟚𝟟—𝟟.𝟛𝟙🌤跳了𓀪三个多月一个礼拜吃重2斤关关难过关关过前路漫漫金灿灿✨✨好物推荐之沙棘汁👍🏻 姐妹们',
#  '#大署Major Heat#清风不肯来☀️烈日不肯暮夏日专场🎈水弹大战💦',
#  '太tm真实了',
#  '尽微薄之力，用一份热，发一份光。让我们与爱同行，不负青春，不留遗憾。ᵕ̈ 💖 ᵕ̈ 💖 ᵕ̈ 💖 ᵕ̈ 💖 ᵕ̈ 💖 ᵕ̈ 💖 ᵕ̈ 💖 ᵕ̈ 💖 ᵕ̈庆祝下🎉 小酒喝一口🍻爽到没朋友🤩🤩 绮绮小乖囡囡',
#  '疯批女人的天花板是“相爱相杀”You win！每天都跳了个寂寞ᵕ̈ ❤️🔥 ᵕ̈ ❤️🔥 ᵕ̈ ❤️🔥 ᵕ̈ ❤️🔥 ᵕ̈ ❤️🔥 ᵕ̈ ❤️🔥 ᵕ̈ 每天都作为对方减肥路上的绊脚石而开心塑料姐妹花💕👭🏻💕我们一起啊‼️',
#  '✐. 𝟚𝟘𝟚𝟚.𝟞.𝟚𝟙🌤',
#  '✨ꀿªᵖᵖᵞ🍉𖠚 ♡ ◡̈🍦ʚ☻ɞ 世界上有两个我 🍭 ʚ☻ɞ 一个吃货的我 🫕 ʚ☻ɞ 一个真心想减肥的我🍹',
#  '🤩ℍ𝕒𝕧𝕖 𝕒 𝕟𝕚𝕔𝕖 𝕕𝕒𝕪 𖤐 摘🍅番茄 摘🍑油桃 ·方圆生态农业观光园',
#  '™ 小 时 光 | 😎 💕专业！认真！负责！专zhuan捅tong不bu服fu',
#  '做个记录。随手百度了一下古斯塔夫勒庞这位作者的简介，瞬间让我汗颜。医学专业毕业，军医出身。不仅对社会心理学有很深的涉足，还出版过物理方面的相关研究著作。达芬奇转世啊。',
#  '引进一部美剧太不容易了，辛苦那些审片的人员了，又是删又是改的。但是现在都2022了，不能说的东西是越来越多~下面的部位，上面的部位……oh my god~干脆把那些字眼从字典里去除吧，大家都不要认识他们了，他们都是无耻下流见不得人的东西。',
#  '台风天的云。第一与第二张用了两个滤镜。有时候觉得华为的色彩增强简直是脱裤子放屁，多此一举。',
#  '每天30分钟雷打不动的有氧健身。似乎又回到了2014年年初的状态。那一年开始锻炼，断断续续直到2017年年底。2018-2020是人生中最黑暗最焦虑的时光。索性走过来了。虽然现在仍然没有迎来曙光，但至少自己学会调整心态，让自己进入一个良性循环里。不念过去，不想将来。过好当下的每一天，就这么简单。',
#  '周日晚间可以回家了，但我又不是那么期待回家了。人真矛盾唉。难得被抽离出来，清净了几天真好。',
#  '与我想象的泳衣不太一样，一点都不性感的。 萌萌哒Hannah迷失在时间的荒原里',
#  'Oh no, my bro…算了，债不用还了，知道你也还不起……',
#  '一直宣扬民主自由的国家，现在看似也不是嘴上说的那样。关注两党之争的后续吧。最高院的这项决议还存在被推翻的可能。',
#  '最近几天发生的事情又颠覆了我的认知我用几个标签来叙述一下发生在我身上的故事1、密接是什么？2、薯片薯片！3、时间的意义？4、弹丸之地可以做的事情？（供大家参考借鉴）---------------------------------------------1、密接是什么？7.24周日12：00，手机响了。“你好，我是黄浦区疾控中心的，根据我们的大数据分析，你被判定为密接人员。请问你是不是本周二去过淮海路的光明邨用过餐？”听完这句话之后，我整个人懵了一秒钟。“是的，我周二是去过……”随后一边冷静地与她核对着个人信息、同行者信息，一边盘算着是否可以侥幸在家里进行隔离。事实是我太天真了。在搬出生过大病不适宜酒店隔离的种种理由后，我还是被居委无情地电话通知，一定要去酒店进行隔离。没有例外。当天下午我和另两位同事就这样被陆续送到了维也纳酒店，开始了我们7天的隔离生活。密接是什么？被定性为密接，不是因为与你同桌吃饭的人阳了，而是因为你与某位在同一时空同一时段不期而遇，恰好坐在同一饭馆里，你就成为了密接。接我的师傅安慰我说，这两个月，前后几十万人被判定为密接，进来又出去。杨浦和虹口的密接人员住的地方条件不好。你们浦东的密接都是住酒店的，条件要比他们好呢。那这么说来，我是不是还要感谢区政府，给我安排在酒店隔离呢？被冠上“密接”二字，感觉公民身份瞬间降了一个维度。因为随性的一个决定，差强人意的一顿午饭，我们三个人就这样暂时失去了人身自由。2、薯片薯片！人总有个坏毛病，越得不到的，就越想得到。同理可用在吃上。我因为行李箱满了，所以没有急购薯片。这下好了，在房间里散步的时候，看电脑的时候，翻书的时候，总觉得嘴里缺了一片薯片。而左左是因为妈妈整的行李，给她带了好多薯片，有袋装有桶装的。换作平时结伴出游，我敲个门就可以问她讨来。可现在因为规章制度，我们都暂时出不了房门。翔住825，左左住623，而我离他们有点远，住728。左左说，你要同住6层，那我还可以把薯片给滚过来。我脑补了一下这个滑稽的场面，笑出了声。翔说我的操作难度太高，她可以近水楼台，先吊个篮子下去，再晃出一个弧度，方便左左的小爪子可以勾到。貌似这个实现起来还相对简单一点哦。搞什么？老娘火上来了，直接下楼去拿不就得了，至于嘛。大家这么配合演这出大戏，是为了什么？为了让老人孩子不要遭罪得病？这种冠冕堂皇的话不要再说了，恶心至极。但我仍然没有把脚踏出房门半步，不是因为没有胆子，而是觉得麻烦。这里的工作人员也挺辛苦的，就别给他们添乱了。3、时间的意义被“囚禁”后，时间失去了本有的意义。早上上门核酸一次，体温上午下午各量一次。一日三餐被准点投喂，不饿不好吃也得吃一点。凉了就一口都下不去了。你可以说，自己的时间很充沛很宽裕。但它不再具有现实里的意义。真空式的生活，让我暂时脱离了社会性的属性。我可以暂时什么都不想，什么都不做，等着被投喂，做着一切看似在娱乐的事情。但荒唐的是，因为防疫制定的规则，因为疫情衍生出的产业，正在形成一个新的社会模式，正逐步吞噬我们正常人的生活。我们现在有两个平行的空间，一个是与COVID-19有关的人，被剥夺一切社会属性，暂时处于真空隔离管控。而与COVID-19无关的人，照常生活在另一个空间里。但是这两者之间，角色经常互换，悄无声息。你都不知道，何时何地，因为哪些机缘巧合，你就被暂时吸入了时间的黑洞。那我们拼命工作，享受生活的意义在哪里？正常的社会交际，工作应酬，探望亲人朋友是不是都要因此暂停了？感觉我们身处一个到处是捕兽器与陷阱的世界，一脚迈错跌入谷底，那就摆烂躺平等着猎人来抓吧，别无他法。4、弹丸之地可以做的事情？我入住了一间既爱又恨的房间。 房间窗口正对武警部队的驻扎地。每天早上六点起，时不时听到整齐划一的操练声。一开始真的很生气，外面这么闹腾着实打扰人休息。但是慢慢的，我的心态发生了转变。因为无所事事，所以我变身为爱管闲事爱偷看的怪阿姨。捧着我的华为谍报手机，录像or拍照模式放大数倍观看小哥哥们的各种军事演练。装甲车、火箭筒齐上阵。扔手榴弹，战壕里伏击演练，体能训练，各种轮番，24小时不间断。录像模式比照片模式还清晰，有华为手机的可以体验一下。近距离观看武警部队训练，虽然没有看HBO的【兄弟连】和【太平洋战争】来得精彩，但我有种贱贱的满足感。居高临下，用手机悄咪咪地观看，满足了一个怪阿姨的偷窥欲。除此之外，就是常规的看书、看新闻和视频，跳跳操拉拉韧带，来填塞大把的时间。当然，还可以隔着猫眼看大白阿姨打扫卫生，看微信群里所有隔离人员的房间号（因此我知道我的上下左右全都是空房，可以放心大胆地在房间蹦跶跳跃了）。工作就别想了，一个平板也干不了啥。',
#  '等我回头一定要写个光明邨事件小作文。我现在脑袋有点卡，信息量有点大。',
#  'DAY 1 in quarantine hotel',
#  '一塘青红千秋色，半池倏鱼戏莲间。番鸭顾盼未知意，似觉蹉跎已经年。',
#  '办公室冷空调开得有点足，坐着有点发冷，脚也有点麻，遂起身去5楼的走廊走走。走廊到底，只见一女孩推门出去抽烟。才发现5楼的平台开放了。我也跟着走了出去，想透透气。站在风口处，温热的风阵阵涌入鼻腔，不用戴口罩的感觉真好。正觉得惬意无比，转眼望到大厦对过，蓝天白云下是密密麻麻的白色简易房，整齐划一刻板无趣。可能用了之后来不及拆，也可能是留作备用，他们就这样静静地矗立在那里。风呼呼地从耳边滑过，过去的两个多月并不是一场梦。',
#  '在再下去我也要去600号报到了。就因为一句可能不太得当的话，被我妈隔着听筒ABCABC循环训叨，不带停，不接受道歉。一个抑郁症病人如果歇斯底里起来有多可怕，我总算见识到了。',
#  '青空卷来一日秋，朱阁藏去三分愁。卧虹拢得五湖水，浮云掩尽七寸忧。',
#  '唐僧骑马咚咚咚，后面跟着孙悟空，孙悟空，跑得快，后面跟着猪八怪（戒），猪八怪鼻子长，后面跟着沙和尚，沙和尚，挑担箩，后面跟着老妖婆，老妖婆，长得丑，变法来吃唐僧肉，总被孙悟空打的逃着走。',
#  '小学时和同学吵架，相互拉扯着，一个说你再不放手我就动手了，一个说你先放，就这样僵持着半天，直到老师来了，双方才假装怒色放开了手。',
#  '管不住老婆孩子和女朋友发朋友圈，会不会以后就来管住自媒体或朋友圈呢？',
#  '二舅就是千千万万中国百姓的缩影！他们只是努力挣扎地活着，谈不上励志，更谈不上正能量，历经WG、改革开放以及扶贫攻坚，二舅的人生就是死水一潭，连一点微澜都没有，这是无奈，更是悲哀…',
#  '疫情下出个门真不容易！光是各自为战的各种码就让人疲于奔命。街面上行走的百姓倒是气定神闲，估计他们害怕的不是病毒，应该是封控。',
#  '小城市客流量不大，为什么高铁站都要建那么大那么豪华且造型基本雷同？',
#  '我国那些受环境、地理位置以及气候所限的旅游区，一年只能正常营业几个月，要想维持商户以及从业者正常的收入，涨价势在必行。加之现行的防疫政策，一年营业时间可能还会更短，这些景区以后真的会高攀不起了。',
#  '疫情三年，对我们国家的经济应该影响很大，建议在未来的五年甚至更久，国家应该停止举办一切国际运动会。',
#  '当国内汽车品牌和汽车人都在热衷新能源电动车时，有谁还会在传统燃油发动机上投入更多的研发和生产费用呢？在燃油发动机这块领域，我们国家应该还是落后欧美日等发达国家吧？',
#  '英语成为副科甚至退出学科之日，就是中华民族伟大复兴之时！',
#  '全国高校都巡视一遍吧。',
#  '如果这次公考过程一切合法合规，那为什么要选择放弃？',
#  '那些当初听信了全款买房可以享受优惠的业主，现在楼盘烂尾了怎么办？',
#  '很多家庭买房都透支了几代人的积蓄，一旦还贷的主体生意不顺利或失业，就有可能面临巨大的还贷压力。',
#  '虽然，一个退休的老年人，他的影响力已无关大局，但就像台独分子李登辉，吕秀莲，陈水扁之流，能少一个还是少一个吧。',
#  '西方国家会不会使用激将法让我们过度防疫呢？',
#  '对待这种婚闹，何幸福做的对！',
#  '拿到举办权是一种荣誉，以这种方式参加世界杯是一种（）。',
#  '疫情三年，防疫如同悲壮的战争。病毒就是敌人，当它们出现时，我们在封控区坚壁清野，在合围区围剿。',
#  '先进的武器装备和强大的国防力量能够抵御外敌侵入，如果外敌采取文化入侵和人种置换来瓦解国家怎么办？',
#  '精准赋红码。',
#  '为什么老一辈的艺术家能够留下很多经典的影视作品呢？因为他们大多数曾经有过从军、务农或是做工的经历。他们拍出来的影视剧更贴近实际，贴近生活，贴近群众，更能打动观众的心。',
#  '唐山烧烤店施暴的暴徒，作案后在明知是逃不掉的情况下仍然选择潜逃，估计按他们以前的经历，每次作案后，外出躲避风头一段时间，待托人摆平后再回来。这应该不是初犯，且之前犯事后什么惩罚都没有。#唐山 打人#',
#  '聚力·焕新！耀视界！2022我推荐周生如故，快来跟我一起让更多人看到周生如故！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！参与2022我推荐嗨放派，和嗨放派一起见证微光盛典“观众喜爱”荣耀的诞生！ 2022微博视界大会微光荣耀推荐',
#  '聚力·焕新！耀视界！2022快来安利你心中独一无二的剧集作品，共同点亮荣耀时刻！ 2022微博视界大会微光荣耀推荐',
#  '¨¨',
#  '「芒果味的海风少年🧡🌈☀️ 说实话‥我喜欢这个章」',
#  '安静的小粉丝 「七月 你好」「 你好」今日好心情久违的阳光开启盛夏的篇章🍉',
#  '安静的小粉丝 66更健康 ‥▲·修图失败...躺平摆烂ing·▼',
#  '有人给了我这个',
#  '「 " 做的是饭 吃的是心情 享受的是过程 " 」',
#  '真的很久没有和爸爸一起过父亲节了一年又一年，但是…我还是想说一句爸爸我很想念你~你是全世界最好的爸爸父亲节快乐',
#  '真是在家待久了… 吃啥都美味 不怎么喜欢吃面包 … 今天发现挺好吃的',
#  '我分享了文章 【读史明智】毛主席坦率评判《毛选》：不是空想，“是血的著作”',
#  '威海旅游一个热情好客的海滨城市，儿子都舍不得离开了。国际海水浴场和那香海海滩都不错，沙细水清。环海公路适合自驾，骑电动助力车的也不少，沿途风景颇佳。蓝天宾馆的菜品味鲜汁浓，炸里脊、白菜炒虾、白灼鲍鱼、乌鱼蛋汤都很赞，揉入鲁菜拔丝技法的锅包肉，片片坚挺，外脆里嫩，印象尤深。',
#  '威海旅游为明天回沪，今天去做核酸。在“爱山东”App里核酸检测点→“全部”选项“愿检尽检”，可以找到离你最近的检测点，采样工作时段也有显示。最好在结束时间前半小时到，有些检测点排队人多，会提前停止排队登记。我们就碰上一次这种情况：中午12点结束，11:45就截止登记了。',
#  '威海旅游请教当地人，说是威海本地人“应检尽检”，外省市游客“愿检尽检”但若不完成3天2检将被赋灰码、黄码，影响出行出游。',
#  '威海旅游今天去第二次核酸采样，问前台，要去外省人员的定点检测点，排队不算长。采样前登记要出示身份证，领个条形码再到采样窗口扫码登记后咽拭子采样，这就完成三天两检了。昨天出站核酸采样后山东健康码就一直绿码，不影响出行、吃饭和购物。',
#  '威海旅游低风险区到威海，出高铁站就按目的地分流引导做一次咽拭子，需时不长。会查看行程码，来的要单独登记，即使你出行前申请山东健康码已信息登记了。离站后在出租车上就收到目的地社区人员电话，确认人员信息，态度很亲和，提醒要三天两检。之后在宾馆就出示身份证等正常手续。',
#  '夏九九。',
#  '六十年代初 弹词开篇《美帝的寿命长不了》朱雪琴、薛惠君“和平阵营保和平，和平人民爱和平”。六十年一甲子，局势消长大变，却又好象轮回不变。 无魂可销主人的视频★评弹★朱雪琴 弹词开篇《美帝的寿命不长了》薛惠君伴奏 六十年代初黑胶唱片',
#  '杨澜采访郑强教授谈“双减”。 林戈是俺',
#  '“当明天强势时我们该怎么样”『张承志：《最后一次读保尔·柯察金》』张承志：《最后一次读保尔·柯察金》',
#  '1949~1997：二十二位马格南摄影师镜头中的香港 1949~1997：二十二位马格南摄影师镜头中的香港',
#  '我分享了文章 杨海鹏的政治观与历史观',
#  '小区内的常态化核酸采样点，今天早晨排队的人不多。有个老阿姨买菜回来，右手拎着一个马夹袋，左手在胸前环抱一个露出两大棵莴笋的大购物袋，慢慢走着经过这里时一声惊呼：“哦哟，要过期了！我等歇也要来做核酸了！”',
#  '小区内一新冠“阳愈人员”今天发现第三次复阳，已被大巴接走，所居住楼栋被封，小区没封。多次复阳，实在少见。',
#  '今天徐汇区例行周末大筛。早上七点开始逐楼喇叭呼叫：“×××弄××号全体人员出来做核酸，阳愈人员不要出来。”在“阳愈人员”这词发明并广泛使用之前很多小区微信群内称新冠阳性转阴人员为“阳性摘帽人员”',
#  '今天长宁区周末例行大筛。妻子接岳母电话，要求她看看核酸采样前做的抗原结果。老人紧张地问“怎么一片红色的？”妻子安慰说：这没关系，不是两条杠就行。实在担心今天别下楼去做了，你腿脚又不好走。等了会儿岳母说还是下去做了吧。否则过期黄码了居委又要不断打电话提醒，烦死了。',
#  '【国产老电影】 二十年后再相会（1984）_哔哩哔哩_bilibili',
#  '讲真，封控这几个月以来开始自己做饭，让我发现自己其实还蛮喜欢做饭的。难怪人家说事业型的白羊座其实是隐型\U0001fae5煮妇🥘👩🙈',
#  '🌳新月愉快这几天经常在树屋咖啡一树一人一狗一店好像这样的生活已经足够，不需要再多了吧',
#  '告别七月，迎接八月。希望新月会更好',
#  '假期过半没写作业，那父母早干嘛了啊？9岁的孩子还没那么自律，父母也要每天督促的。虽然生气了骂孩子也是有的，但做父母也要讲道理的，不能只是知道怪孩子也要找找自己的问题👪',
#  '修勾知道人家修勾值四万以后伤自尊了',
#  '🌻𝓗𝓪𝓹𝓹𝔂 𝓦𝓮𝓮𝓴𝓮𝓷𝓭山羊奶酪配饼干做小零食，咖啡鲜萃液配鲜奶做一杯冰拿铁。周 末是家庭日，大概率会吃一顿披萨。周 末愉快',
#  '。牙仙子🧚♀️晚上要给他二枚金币🏅🏅',
#  '🌳树屋咖啡这是一家开了一个多月的新店。其实老板3月份已经装修好，几个月封控耽误到6月才开业。门口有一棵大树故得此名吧。简朴的日式木质居家风格设计的挺温馨。咖啡风味在线但定价不高，使得性价比也不错。情商很高的柴犬Kary当班，让人撸🐶也撸的很开心。据说还有一个🐶弟弟，下次有机会也想撸一下。',
#  '这笑鸥的笑声也太魔性了吧',
#  '想看👀，又不太敢qu电影院🎬，纠结ing',
#  '🥚🥩🍲🍽自己做寿喜锅天热既然不想出门，那也可以把餐厅搬回家。寿喜锅做起来很容易，一瓶酱汁加水即可。像外面店里一样配无菌蛋做调料。某马家的M4牛肉品质也不错。再配许多豆制品和蔬菜，吃很多也不怕长肉，健康又美味。',
#  '混血宝宝的中文真是愁人。我跟他说你到梳妆台那里坐着写字我可以看着你，他问我梳妆台是啥',
#  '很多侧门都被关掉很久了，讲真这是很有消fang🧯隐患的。',
#  '水面上飘着小黄花晃晃悠悠的，还真是“参差荇菜”，诗经里写的好形象🍃',
#  '🌻🐠🍽自己做的菜烤鳗鱼煎一下酱汁配花卷味道很不错。马蹄肉丸的酱汁加点芝麻更香了。泰迪向日葵以前好像没见过，花瓣毛绒绒的还真有泰迪的质感，色彩明艳的花花也是“美”食的一部分吧。',
#  '某宝的腿被柜角擦破了，等我看到的时候他已经拿个小刀把家具柜角给切了。真是又好气又好笑当然又更心疼他的腿',
#  '我也特意问过物业，说是街道有文件他们也是按文件📃办事，快递不能送上门。也不知道什么时候才可以恢复正常',
#  '🥩🍳🥬🥞🍤\U0001fad8自己做的菜用空气炸锅炸猪排感觉干干的。海鲜饼本来也准备用空气炸锅炸，但也是看着不够熟的样子于是重新煎一下。浓油赤酱的小素鸡和凉拌皮蛋。豆瓣酥是大家都爱吃的一道菜了。菠菜二天没吃捡菜要扔掉一半，炒完了好小一盘看来以后要早点吃掉。',
#  '确实，🥗沙拉虽然健康但大部分都是冷的。中式轻食可以做热的，吃着感觉胃也比较适应。',
#  '这个问题可以由平台来调和吧。在选择车型的时候加一个“是否开空调”选项也可以解决这个问题。',
#  '🥗🍕🍗𝕳𝖆𝖕𝖕𝖞 𝖂𝖊𝖊𝖐𝖊𝖓𝖉队友周 末一般会希望吃披萨。Tube Station家的披萨和色拉都很不错。点了三个披萨，一个叫布鲁克林-口感偏辣，还有一个叫希腊花园-口感偏甜，第三个叫费城故事-肉比较多，三个披萨吃出了三个城市的不同感觉。',
#  '这是换了个沧桑大叔的形象了啊',
#  '这甘肃看着又严重起来了啊。宝山区昨天也增加十几例。这反反复复的疫情真烦人',
#  '肯尼亚水洗冷萃和巴拿马瑰夏冷萃。被肯尼亚这杯给惊艳到了，馥郁的🫐莓果果汁味',
#  '不应该歧视阳性康复者，没有人是自己愿意感染的😷',
#  '这让人情何以堪🚘',
#  '🥗🌶️🐟🍽𝗛𝗮𝗽𝗽𝘆 𝗪𝗲𝗲𝗸𝗲𝗻𝗱 迅速做好晚餐的办法有很多。昨天点的菜饭特意多叫了一份，土豆色拉苔条花生都是直接可以吃的，蔬菜色拉只需要装盘再浇上色拉酱即可，而且这三个菜都是某宝这个小帮手帮忙装盘的哦。麻麻只要把香辣靖江烤鱼加工一下，十几分钟晚餐便做好啦',
#  '太让人揪心了啊。怎么会自己撞上隔离岛的啊。看着车速也不快啊。而且他本人还是赛车手来的。',
#  '𝗛𝗮𝗽𝗽𝘆 𝗙𝗿𝗶𝗱𝗮𝘆路过SOHO一家新开了一周的WARMING，那必须得来一杯啊。冰拿铁做出了Dirty的层次感，可以给咖啡师加🍗。Sustainable主题选用可消解的纸浆圆筒做装饰挺有意思的。只是不知道是如何过🧯这关的👻 ·SOHO复兴广场',
#  '被罚八十亿不晓得公司还开的成吗。好像他们之前是把Uber給并了，现在一支独大了。',
#  '◾️LADY M竟然要把内地门店都关了🥀。好喜欢她家的千层蛋糕啊。这些照片是之前拍的IAPM店Shi频截图。以后想吃她家是不是要到纽约吃了啊',
#  '这个猫猫也太黏人太可爱了吧',
#  '真是啥样的父母都有啊',
#  '🐈🍃一杯BS冷萃咖啡消抵了一些暑气。咖啡师墙裂要求我欣赏这束干花，因为是她自己做的。鸡爪槭做插花也蛮特别的',
#  '找到父母对这个孩子来说不知道是幸还是不幸😮💨',
#  '宝贝学校有一个作业，是要采访家长问关于的历史。为了配合他，我临时抱佛脚也了解了一些有趣的历史。比方说：“大约在六千年前，西部即已成陆，东部地区成陆也有两千年之久。”意思是浦西是六千多年前形成的，然后两千年多之前浦东的陆地都还没形成，所以浦东那时还是一片汪洋大海🌊',
#  '很有道理。机票钥匙位置证 件老人小孩这些都不要晒。不过我现在也很少看PYQ，天天泡在WB里',
#  '🍞🌭️🍯🧈🍽𝕲𝖔𝖔𝖉 𝕸𝖔𝖗𝖓𝖎𝖓𝖌队友没有一起打卡“黄油与面包”，所以给他带了一堆那里的面包回来。包括惠林顿牛排面包、小碱水香肠，还有奶酪包以及碱水芝士包，当然还有他们的招牌黄油面包。这几天碳水吃太多了，需要好好反省一下',
#  '扔垃圾桶也太过分了。想起我家之前的一个邻居也是在福利院长大的。但是他人真的好好，真是很好的邻居。希望这个孩子也可以健康长大。',
#  '晓得了，确实忽略了。还是窗开个缝比较好，稍微可以换点气。',
#  '𝗕𝗨𝗧𝗧𝗘𝗥𝗙𝗨𝗟 & 𝗖𝗥𝗘𝗔𝗠𝗢𝗥𝗢𝗨𝗦 黄油与面包闺蜜心心念念了一年的店，终于和她一起打卡了。之前要排四个小时的队，这次完 全不要排队。吃到了🪓战斧牛排包和惠林顿牛排🥩面包。只是这么热的天空调不足属实让人意外。还好店里的冰拿铁味道还可以。他们的面包一如他们的店名，都有很浓郁的🧈黄油和奶油味。 ·Butterful & Creamorous',
#  '泥点子本泥。李荣浩是不是故意来黑井柏然的',
#  '🌰🍯🥖🍳🧀️☕️𝗛𝗮𝗽𝗽𝘆 𝗡𝗲𝘄 𝗪𝗲𝗲𝗸XJ蜂蜜坚果大列巴里面有葡萄干和核桃仁，一个有一斤，咬起来很坚实的口感。切片配山羊奶酪正好。再加上队友煎的香肠➕奶昔➕煎蛋➕咖啡',
#  '周杰伦新专辑里面的《还在流浪》还蛮好听的🎵',
#  '🍇XJ三拼葡萄：玻璃脆、绿珍珠、无核紫。玻璃脆还是the winner🥇',
#  '每天早上要做奶昔需要香蕉🍌，想说外面风声还是有点紧要不顺便多囤一串吧，没想到新来的那串比老的那串还要熟',
#  '哈哈哈我本人了。我的原则是可以用表情包jiu不要打字',
#  '能不能清零咱不知道，但是一直要处于被封控隔离的担心当中是大概率事件',
#  '🥗🍤🍈🥚🍴自己做的菜天热适合做一些很快能做好的凉菜。凉拌皮蛋只需几分钟即可。蔬菜色拉浇上黑胡椒汁再铺满山羊奶酪，用哈密瓜调和一下偏咸的口感。海鲜粉丝是预制菜炒一下即可。盐水鸭也是现成的只需要切一下，只是自己的刀工不行切的实在是太丑🙈。主食配大白馒头蘸各 种酱，其实馒头蘸腐Ru是很好吃的。',
#  '好吓人。哪也不敢跑了。',
#  '古典裙装真好看，不逊欧式宫廷裙装。只是现在穿都太繁琐了一些。',
#  '🥘🍯🍅🥞🫒🧈🍽𝓗𝓪𝓹𝓹𝔂 𝓦𝓮𝓮𝓴𝓮𝓷𝓭电影料理鼠王里面有一道菜，把Zui挑剔的美食家都给征服了，叫普罗旺斯杂菜，jiu是图六这道菜了。电影里的排列更整齐一些，但味道是差不多的。其实味道很接近地三鲜。香草烤鸡的配菜是烤土豆和酸甜奶油酱。拉发饼蘸鹰嘴豆泥和油浸番茄很有异域风味。还多配了橄榄番茄酱和罗勒叶酱。卷心菜色拉队友说以前经常野餐配汉堡热狗吃。很有异域风情的一餐。',
#  '下了一场雨🌧️，终于没那么热了',
#  '还是熟悉的典型的周氏风格，但客观的说主题曲不能说是Zui好听的。青花瓷夜曲都更好听。《等你下课》还不错，不过是之前的老歌了。',
#  '🥗🌶️🥚🍅𝓖𝓸𝓸𝓭 𝓜𝓸𝓻𝓷𝓲𝓷𝓰天气太热不想做饭，点了胡子大厨家的外送。这家其实味道还不错的，有宝贝喜欢的手撕包菜。小炒黄牛肉是他家的招牌。筱县豆干也很好吃。还有下饭菜番茄炒蛋。',
#  '挺好的，不用煮了，直接吃',
#  '一百四十九年里只有七年出过四十度以上的高温。昨天追平有气象记录以来的Zui高温四十点九度。前面在外面做核酸，排着队暴晒，感觉自己马上要热成热狗🐶♨️',
#  '🥗🌭️🍯🧂🧈🍽𝕲𝖔𝖔𝖉 𝕸𝖔𝖗𝖓𝖎𝖓𝖌宝贝说想吃热狗了，外面吃热狗好像是一件很简单的事情，但自己做需要准备很多酱料，比方说需要芥末酱、酸甜黄瓜酱、番茄酱等，还要有炸好的洋葱碎。香肠也需要和面包匹配要算好尺寸，否则会像我这一样需要二根香肠才行。但是自己做的热狗吃着还是很香的。',
#  '哎呀妈呀也太可爱了吧 都会说“玩儿”了',
#  '馋了馋了😋',
#  '🌹🌼🌭️🥛☕️🥚🍽𝕲𝖔𝖔𝖉 𝕸𝖔𝖗𝖓𝖎𝖓𝖌煎香肠➕红糖花卷➕鸡胸➕鸡蛋➕奶昔➕咖啡队友这次选的满天星、百合配玫瑰，热烈又清新，还蛮好看的，可以给他加鸡腿。',
#  '想入一个储物柜，逛🍑逛了三个半小时终于找到一个相对比较合 适的。太困了逛不动了。希望慢点送来不会让我失望吧。',
#  '宝贝在背古诗，背到“老夫聊发少年狂”，不知道老夫是什么意思，我说是老年男性的自称，他举一反三地问：“那老年女性的自称呢？老妈？老母？”',
#  '好想来个华山游啊，还没亲眼见过华山呢。',
#  '虽然但是因为所以总之还是某马一直显示运力不足。我是该囤菜呢，还是不该囤菜呢，这是个问题',
#  '早上和邻居们在群里进行了切柠檬🍋挑战赛。第 一 次Jiu切了十七片，和目前的第 一 名持平，但第 一 名说蒂蒂头不算，所以是十五片，还需要努力。别的邻居说现在切个柠檬都那么卷了吗',
#  '🌹💐🏺夏朵花园Chartres Garden环境篇这家意大利餐厅虽然开了好多年了，但因为是比较经 典的古典浪漫风格所以看着还是很优雅，没有觉得过时，反而有一种复古的美感。',
#  '刚才在某马上下单又显示“运力不足”下不了单。似曾相识的感觉让人慌的一批。看来大家不管消息真假都是稍有风吹草动马上开始囤菜。',
#  '🦞🥗🍨🍽夏朵花园Chartres Garden第二次来夏朵和队友过Anniversary啦。这家的M7牛排和鹅gan松露烩饭很好吃。餐前面包里面有一个带核桃仁的小面包很香。这家的松露薯条很有名，还有比较有名的是下午茶，舒芙蕾配咖啡是很好的搭配。餐后吃了甜甜的熔岩巧克力蛋糕配香草冰激凌。一热一凉的口感对比还挺特别的。',
#  '到处都在传，沸沸扬扬的，搞的人好紧张。',
#  '刚才出门拿送来的巧克力，好担心会被晒化掉。拿了赶紧回家，外面实在是太热了♨️。回来赶紧来一块光明冰 砖🧊切切降降温',
#  '十二个区几乎平均分布',
#  'Companion小伴咖啡几个月没来朱家角了，路上行人寥寥，好多店都关掉了，包括好几个之前喝过的咖啡店。还好放生桥边上的小伴还是开着的。天气很热，想喝一杯又冰又好看的咖啡，所以选了冰博克Dirty，冰杯的分层又好看又持 久。希望这家店可以一直坚持开下qu啊。 ·朱家角放生桥',
#  '哈哈哈哈哈哈😂',
#  '哎，这阵子怎么经常听到这种Kan人事件',
#  '🥗🌶️🐟🥢自己做的菜四喜烤麸忘记放花生了，还好也不影响味道。炒饭里放点芝麻还有胡椒粉，会有一种特别的风味。半成品的酸菜鱼自己再加工一下，味道和外面店里的好像也差不多。每次做干煸四季豆队友都会把它吃完。',
#  '见过那个车，我表示同意✅',
#  '二十一世纪还会发生这样的事情真是骇人听闻。',
#  '昨天增加五十个风险区今 天增加33个',
#  '💐🌸🌼🍽𝕲𝖔𝖔𝖉 𝕸𝖔𝖗𝖓𝖎𝖓𝖌又试了三种奶酪，贝拉维孔泰奶酪比另外二个黄波红波好吃。奶酪、红酒、咖啡包括现在的啤酒等，都是会蕴含许多其 他丰富风味的食材。每天试一些不同的食物，让生活也会更有意思一些。新入了一个巴洛克风格的小碟子，竟然和有中式风韵的小杯子有点搭。',
#  '看来还是要继续被嫌弃，今天一口气增加了四十几个风险区。',
#  '吃个冰激凌雪糕也不能让人放心吃啊。',
#  '真的可以看电影🎬了。蠢蠢欲动的心啊，但又有点怕怕的',
#  '🥗🧀️🥟🍈𝕲𝖔𝖔𝖉 𝕸𝖔𝖗𝖓𝖎𝖓𝖌墨墨黑的墨鱼水饺里面是白白的。蔬菜色拉我喜欢调油醋汁，再撒一点西班牙曼彻格干酪。切几块甜甜的哈密瓜，再用咖啡鲜萃液和鲜奶自己做一杯冰拿铁。简单又有点小特别的一餐。',
#  'OMG新增54例，2例还是社 会面的。还分散于十二个区。 这打地鼠🕳️🕳️🕳️到底打得完嘛？',
#  '昨天又是新增十几例。感觉身边一些朋友处于崩溃的边缘。然后很多人又润了。这没完没了隔几天来一波散发的疫情，然后到处又都是密接之类的封控，太磨人太考验人的心智了。真是抗疫常态化的节奏。肿么破？',
#  '🥗🌶️🐟🥢自己做的菜才堂食没几天餐饮娱乐场所jiu出风险区了。还是自己在家做饭吃吧。给爱吃辣的队友做了香辣烤清江鱼，皮蛋豆腐也加了点小米辣。海鲜蔬菜饼是预制的，煎一下然后蘸番茄酱吃。可以让不爱吃蔬菜的小孩子多吃一点蔬菜。',
#  '新增一个社 会面的。真是没完没了的疫情没完没了的核酸',
#  '再怎么说咖啡和奶茶一个里面基地是咖啡一个是茶叶，总归是不一样的。除非是鸳鸯奶茶那是咖啡和茶都有。加各 种配料的算特调咖啡吧。“粥化”了的，那得算甜品',
#  '🥦🦐🍜🥢自己做的菜夏天是吃冷面的时候，鸡丝凉面放在新来的玻璃晶碗里面，黄绿色系和小雏菊还挺配。西兰花炒虾仁以及鱼丸煮油麦菜，都是比较清爽适合夏天的菜。本来主食是糍饭糕，但准备好了以后宝贝又说要吃冷面，所以有了二个主食，碳水稍微多了一点。',
#  '附近有一家叫浅草的美容院员工阳了。还好据说员工都是24小时核酸的。但毕竟也接触了一些人了。周边好几个小区突然增加的密接都和这个美容院有关。我们隔壁一栋楼因为有人是密接封了，要封二天。目测我们也要来几轮全员核酸，这疫情实在是太磨人了😮💨',
#  '空气又开始有点紧张。我们小区有二栋楼有密接封掉了封二天。附近有三个小区也分别有密接有封掉的楼',
#  '看着有点严重的样子啊。希望可以控制住。昨天也新增三例。话说有一个朋友因为疫情跑回安徽了，现在安徽疫情又起来了。',
#  '🦀️🥗🍚🍴自己做的菜椒盐排条+海鲜粉丝+咸蛋黄梭子蟹说是自己做的菜，其实四个菜里面有三个都是预制的，稍微热一下或者加工一下马上可以吃。味道都还不错。再加一盘炒鸡毛菜还有加了辣酱的蛋炒饭。刚恢复堂食三四天昨天又出现二个涉及餐饮场所的风险区。感觉外食还是不够安 全啊。',
#  '金庸、黄霑、倪匡、蔡澜，前三位的书读过歌听过。蔡澜家的山楂叉shao包是真的好吃。',
#  '竟然要关门了吗，好遗憾啊。qu年九月份朋友来玩，我还特意带到保罗吃正宗的菜。每道菜都很好吃。发个博以资纪念吧。以后吃不上了。',
#  '前天还吃了一根一模一样的同款',
#  ...]

# %%
len(res)
# Out:
# 184093

# %%
list1=res
list2=[]
for i in list1:
    if i not in list2:
        list2.append(i)
print(list2)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
len(list2)
# Out:
# 181273

# %%
def cut(x):
    return [word for word, flag in pseg.cut(x)if flag in ['n','a']]
    #return [word for word, flag in pseg.cut(x) if flag in ['n','v','a']]#['n','v','a','r','i']]

texts = [cut(a) for a in list2]
#res = list ( filter ( None , count))

# %%
text = list ( filter ( None ,texts))

# %%
text
# Out:
# [['小朋友', '娘'],
#  ['朋友', '葡萄'],
#  ['T恤', '省钱', '能手', '同事'],
#  ['妈妈', '星', '环球'],
#  ['螺蛳', '同事', '茶'],
#  ['妈妈', '妈妈', '爸爸'],
#  ['春卷', '备菜'],
#  ['洋娃娃', '摊牌', '国际'],
#  ['会员', '气泡', '水', '省钱', '能手'],
#  ['爸爸'],
#  ['泥炉', '烤肉', '时代广场', '店'],
#  ['路'],
#  ['水果', '茶'],
#  ['带薪休假', '天'],
#  ['库存', '日子'],
#  ['疫情', '力', '朋友', '驱车'],
#  ['排队', '天地'],
#  ['小朋友', '会员', '商店'],
#  ['大学', '毕业典礼', '时光倒流', '读书'],
#  ['同事', '小', '礼物', '阔气', '人手'],
#  ['时隔', '新品', '老板', '办法'],
#  ['爸爸', '孩子', '爸爸', '全世界', '父亲'],
#  ['梦想'],
#  ['博', '记录'],
#  ['奶妈', '辣妈', '鲜花'],
#  ['工人'],
#  ['堂食'],
#  ['馒头'],
#  ['转基因', '菜籽油', '含税', '价'],
#  ['转基因', '菜籽油', '含税', '价'],
#  ['菜籽油', '都行', '总量', '价格', '转基因', '食用', '条件', '人'],
#  ['历史'],
#  ['姐妹'],
#  ['小朋友'],
#  ['老'],
#  ['肠胃炎', '医院', '感觉', '新冠', '医院'],
#  ['核酸', '猪肉'],
#  ['口罩', '病毒', '政策'],
#  ['歌舞升平', '日子'],
#  ['桌长', '经济', '障碍', '障碍', '经济'],
#  ['身体', '感觉', '节奏', '风向'],
#  ['商场', '商铺', '关门'],
#  ['方法'],
#  ['妈妈',
#   '新闻',
#   '视频',
#   '核酸',
#   '报告',
#   '怀胎',
#   '孩子',
#   '问问',
#   '新冠',
#   '病',
#   '病',
#   '新冠',
#   '肺炎',
#   '肺',
#   '病毒',
#   '后遗症',
#   '后遗症'],
#  ['花草', '钢笔水', '彩', '芳园', '照片'],
#  ['图片'],
#  ['鼻子', '天'],
#  ['恶心', '气死我', '公司'],
#  ['生气', '生气', '生气', '气', '人生', '公司'],
#  ['女生', '心', '朋友', '朋友'],
#  ['滴滴'],
#  ['小时', '感觉', '美式', '酸'],
#  ['堂食', '撸串'],
#  ['咖啡'],
#  ['心'],
#  ['咖啡', '大肚'],
#  ['咖啡', '用心', '脸', '用心', '点滴'],
#  ['咖啡', '心'],
#  ['咖啡', '空心'],
#  ['咖啡'],
#  ['重度', '奶油', '爱好者'],
#  ['重瓣', '咖啡', '油脂'],
#  ['抗原'],
#  ['人', '心态', '心理', '年龄'],
#  ['咖啡', '地盘', '肥猫'],
#  ['咖啡', '绣球'],
#  ['咖啡', '鲜奶'],
#  ['手冲豆', '盲盒', '双重', '果酒', '味'],
#  ['营业', '健身房', '闭馆'],
#  ['咖啡'],
#  ['咖啡', '雨', '声声', '核酸'],
#  ['咖啡'],
#  ['冰', '美式'],
#  ['重瓣'],
#  ['配色'],
#  ['红莓', '蓝莓', '早餐', '奶油'],
#  ['咖啡', '玫瑰'],
#  ['咖啡'],
#  ['咖啡', '柚子', '空心'],
#  ['咖啡', '双层', '空心', '光圈', '空心'],
#  ['风味', '咖啡豆'],
#  ['栀子花', '花瓣', '绿叶', '人', '香气'],
#  ['手冲',
#   '风味',
#   '咖啡豆',
#   '豆',
#   '能闻',
#   '茉莉',
#   '香味',
#   '口感',
#   '茉莉',
#   '味道',
#   '盐水',
#   '茉莉花',
#   '蜜桃',
#   '香气',
#   '整体',
#   '饮用',
#   '茉莉'],
#  ['咖啡'],
#  ['时光'],
#  ['荷香', '茶香'],
#  ['山', '海'],
#  ['咖啡', '手作', '咖啡杯'],
#  ['咖啡'],
#  ['咖啡'],
#  ['竹节', '手柄'],
#  ['钢铁', '混凝土'],
#  ['律师', '开庭', '地方', '大树', '空调', '公园', '高温', '嘴', '公园'],
#  ['晚霞', '重生'],
#  ['商量', '时间', '感觉', '伙伴'],
#  ['朋友'],
#  ['厕所'],
#  ['密室', '朋友'],
#  ['有点', '我心'],
#  ['蛋炒饭'],
#  ['白眼', '眼皮'],
#  ['感情'],
#  ['夢'],
#  ['后背', '对折'],
#  ['脊椎'],
#  ['节目'],
#  ['脑子'],
#  ['部分'],
#  ['衣服', '真理', '衣柜', '朋友圈', '面', '雪藏'],
#  ['梦', '理想', '电话号码'],
#  ['早饭', '面包'],
#  ['机关枪', '气死', '感觉'],
#  ['拉面', '血'],
#  ['朋友', '成绩'],
#  ['事情'],
#  ['空调', '房'],
#  ['梦想'],
#  ['时候'],
#  ['屁股', '舞台', '人生'],
#  ['奶奶'],
#  ['颜色'],
#  ['脸盲'],
#  ['讲话'],
#  ['听力'],
#  ['床上'],
#  ['苹果', '头戴式', '耳机', '人'],
#  ['心'],
#  ['妈妈', '不太想', '洞', '爸爸', '洞'],
#  ['封面', '歌曲'],
#  ['女朋友'],
#  ['朋友', '恋人', '事情', '答案', '备胎', '脾气', '事', '人生', '教会', '感觉', '饭菜'],
#  ['样子'],
#  ['狗'],
#  ['茶', '茶'],
#  ['香草', '铁', '早饭'],
#  ['女儿', '感觉'],
#  ['时候', '美女', '爱', '物料', '关键点', '夸金', '时候', '头', '时候', '眼睛', '方物', '人心'],
#  ['作业', '时候', '猫猫', '腿', '碘', '伤口'],
#  ['小时', '奇幻'],
#  ['橡胶'],
#  ['妹妹', '差'],
#  ['耳洞', '时'],
#  ['空调', '冰', '香草', '铁'],
#  ['脸', '肉体'],
#  ['梦会'],
#  ['空调', '房'],
#  ['朋友', '自行车'],
#  ['虚拟语气', '例子'],
#  ['感觉', '头'],
#  ['老师', '布置', '页码', '妈'],
#  ['朋友'],
#  ['头发'],
#  ['鱼', '冰', '香草', '铁', '问', '朋友', '海'],
#  ['心情', '晚饭'],
#  ['教育局', '事情', '屁', '学校'],
#  ['开学', '尸体'],
#  ['机关枪', '开口', '人', '弱智'],
#  ['五炽'],
#  ['作业', '看团'],
#  ['朋友'],
#  ['作业', '狗', '冰', '香草', '铁'],
#  ['条狗'],
#  ['狗'],
#  ['日料'],
#  ['歌'],
#  ['人名', '感觉', '房', '地震'],
#  ['电影', '甜品', '动漫', '真人', '电影'],
#  ['电脑', '死期'],
#  ['泥塑', '舞台'],
#  ['画面感', '歌', '冒险', '勇气'],
#  ['毕业'],
#  ['叉烧饭', '柠茶', '计划'],
#  ['感觉', '奶茶', '果茶', '茶', '有点', '软件'],
#  ['垃圾', '短信'],
#  ['梦'],
#  ['听力', '课'],
#  ['眼皮', '听力', '作业', '天气'],
#  ['照片', '尾巴'],
#  ['上衣', '黑色', '中裤'],
#  ['家人'],
#  ['噩梦'],
#  ['妈'],
#  ['时间', '睁眼'],
#  ['小时', '事情', '机关枪', '人', '网络', '材料'],
#  ['感觉'],
#  ['午饭'],
#  ['左脚', '鼻血', '倒霉蛋'],
#  ['电影', '客厅', '电影', '恐怖电影'],
#  ['猫', '名字'],
#  ['人', '幽灵', '手', '照明灯', '断翅', '肋骨', '机械', '壳'],
#  ['道理', '精神状态', '社交', '软件', '大家', '消息'],
#  ['阴天'],
#  ['手'],
#  ['蝙蝠侠',
#   '猫女',
#   '美女',
#   '寸头',
#   '时候',
#   '字幕',
#   '颜色',
#   '问题',
#   '视力',
#   '眼睛',
#   '时长',
#   '屏幕',
#   '色塞',
#   '厄题',
#   '朋友'],
#  ['事情'],
#  ['社交', '软件', '意思', '心脏'],
#  ['作文', '尾'],
#  ['部', '电影', '恐怖片', '心情', '恐怖片'],
#  ['消失'],
#  ['方式', '软糖', '前提', '牙齿', '腮帮子', '房间', '软糖'],
#  ['事情', '大学'],
#  ['背影', '腰'],
#  ['私信'],
#  ['大家', '课外', '班', '效率', '集体', '模式', '学校', '地方', '开学'],
#  ['人生'],
#  ['议论文', '议论文'],
#  ['世界'],
#  ['意思'],
#  ['蜡笔'],
#  ['传谣', '皮', '发菜', '地球', '人民', '空', '长舌'],
#  ['事'],
#  ['小道消息', '传谣', '人', '不力', '全世界', '好人'],
#  ['事实',
#   '人',
#   '人',
#   '利益',
#   '人',
#   '利益',
#   '事实',
#   '话',
#   '话',
#   '人',
#   '骗局',
#   '区别',
#   '人',
#   '晚一点',
#   '骗'],
#  ['精灵'],
#  ['围观', '问题', '价值', '围观', '围观', '博'],
#  ['真', '恶心'],
#  ['喜糖', '喜糖'],
#  ['梦', '文化', '编剧', '演员', '用心'],
#  ['老子', '钱', '版', '钱'],
#  ['集'],
#  ['材料', '时候', '热血', '时刻', '毕业典礼', '办法', '事', '妈', '意思'],
#  ['天'],
#  ['门', '吸尘器', '吸尘', '脑子', '毛病'],
#  ['风险', '月份', '计划', '计划', '衷心', '建议', '小朋友', '热', '海洋公园', '空间'],
#  ['浪琴', '视频', '表', '儿子', '浪琴'],
#  ['演戏', '体验', '演员', '舞台', '眼睛', '豆', '舞台', '黑子', '鹅', '时候', '姐姐'],
#  ['麻麻', '演员', '剧', '豆', '舞台', '中央'],
#  ['鹅子'],
#  ['门票'],
#  ['门票', '牛', '地方', '同源', '意思', '主页', '人', '屏蔽', '信息', '消息', '屏蔽'],
#  ['门票', '缺货', '票', '票', '演出成功'],
#  ['门票'],
#  ['水准', '脑子', '人们'],
#  ['烟火', '流星', '舟', '演出成功', '情歌', '乐园'],
#  ['饭'],
#  ['主持稿', '麻麻'],
#  ['儿', '员工', '大会', '主持稿'],
#  ['大暑', '有点', '上线'],
#  ['世界', '大家', '晚安', '姐姐'],
#  ['博'],
#  ['香蜜', '琉璃', '感觉'],
#  ['词条', '装路', '人', '大家', '骂人', '熟人', '小号', '热度', '事件', '旧事', '狐狸'],
#  ['词条', '限定版', '爱豆', '舟', '计划'],
#  ['人', '速度', '鹅', '公司', '员工', '手册'],
#  ['视频'],
#  ['粉丝', '粉丝'],
#  ['所有人',
#   '意义',
#   '年龄',
#   '交代',
#   '倒油',
#   '事',
#   '人',
#   '问题',
#   '拐点',
#   '拐点',
#   '人',
#   '能力',
#   '学识',
#   '时宜',
#   '男孩',
#   '事',
#   '人生',
#   '问题',
#   '鹅',
#   '性格',
#   '判断力',
#   '男人'],
#  ['世界', '样子'],
#  ['儿', '榜', '世界', '人', '思想'],
#  ['路', '人点'],
#  ['儿', '话', '主语', '经纪人', '感觉', '大家', '气'],
#  ['发文', '事', '网暴'],
#  ['天'],
#  ['黑子', '姐姐', '好歹', '智商', '小学', '中学', '粉丝', '先理', '逻辑'],
#  ['私人',
#   '行程',
#   '全程',
#   '国话',
#   '视频',
#   '事',
#   '国话',
#   '话剧',
#   '骨折',
#   '粉丝',
#   '国话',
#   '人',
#   '粉丝',
#   '心痛',
#   '网暴',
#   '无脑',
#   '节奏',
#   '人',
#   '眼瞎',
#   '节奏',
#   '合法',
#   '实力',
#   '国话',
#   '心肝',
#   '脾',
#   '肺',
#   '肾'],
#  ['瓜'],
#  ['正常人', '人'],
#  ['路人',
#   '网友',
#   '证据',
#   '舆论',
#   '额头',
#   '痘痘',
#   '疯子',
#   '粉丝',
#   '粉丝',
#   '无脑',
#   '右手',
#   '脚趾头',
#   '我会',
#   '所念',
#   '粉丝',
#   '妈',
#   '路',
#   '人',
#   '网络',
#   '暴力',
#   '刽子手',
#   '全家',
#   '视监者'],
#  ['舟', '舟', '冷饮', '老字号', '极品', '盐水', '棒冰', '钱'],
#  ['麻麻'],
#  ['问题', '问题', '问题', '嘴', '问题', '问题', '问题', '字母', '坏人', '坏人', '社会'],
#  ['日子'],
#  ['个', '亲娘', '历史'],
#  ['大家',
#   '专业',
#   '毕业生',
#   '饭碗',
#   '错觉',
#   '经济',
#   '普通人',
#   '不公',
#   '不平',
#   '技能',
#   '疫情',
#   '居家',
#   '部门',
#   '居家',
#   '办公',
#   '技能',
#   '国话',
#   '代表',
#   '个人',
#   '资料',
#   '视频',
#   '网友',
#   '话剧',
#   '买票',
#   '大家',
#   '人',
#   '市场',
#   '机会',
#   '艺考',
#   '戏',
#   '男生'],
#  ['空气',
#   '化',
#   '事',
#   '事',
#   '孩子',
#   '问题',
#   '同事',
#   '事',
#   '感觉',
#   '人',
#   '穷极',
#   '孩子',
#   '家长',
#   '孩子',
#   '寒门',
#   '贵子',
#   '人',
#   '事情',
#   '时间',
#   '证明',
#   '空气',
#   '化'],
#  ['共脑', '步伐'],
#  ['共脑', '双向'],
#  ['店', '小船', '面馆'],
#  ['剧能',
#   '人',
#   '整体',
#   '节奏',
#   '戏剧性',
#   '开端',
#   '例子',
#   '片子',
#   '后浪',
#   '工作人员',
#   '剪辑',
#   '认真思考',
#   '观众',
#   '争议',
#   '镜头',
#   '台词',
#   '原声',
#   '人物',
#   '配音',
#   '体验',
#   '用心',
#   '做剧'],
#  ['舟', '舟', '猫猫', '妹妹', '猫猫'],
#  ['时候', '鹅', '行程', '图', '上线', '剧', '上线', '鹅', '行程', '计划', '人', '计划', '追星'],
#  ['戏',
#   '毕业生',
#   '性格',
#   '娱乐圈',
#   '地方',
#   '班',
#   '时候',
#   '事情',
#   '鹅',
#   '年轻人',
#   '艺人',
#   '匠人',
#   '精神',
#   '内娱',
#   '偶像'],
#  ['舟',
#   '舟',
#   '纸片',
#   '人',
#   '人物描写',
#   '老实',
#   '侠骨',
#   '个人',
#   '恩怨',
#   '人生',
#   '轨迹',
#   '大漠',
#   '心',
#   '人心',
#   '心怀',
#   '风范',
#   '无情',
#   '大情',
#   '大义'],
#  ['鹅', '射雕', '猫猫', '猫猫'],
#  ['上线',
#   '波',
#   '代表',
#   '个人',
#   '剧',
#   '我会',
#   '员工',
#   '演技',
#   '编剧',
#   '能力',
#   '人才',
#   '考虑一下',
#   '招',
#   '剧本',
#   '脸'],
#  ['鹅', '全身', '照', '尺子', '量', '腿', '辣', '女娲', '娘娘', '时候', '用心'],
#  ['理会',
#   '生粉',
#   '客粉',
#   '粉',
#   '人',
#   '粉丝',
#   '资深',
#   '社畜',
#   '鹅',
#   '公司',
#   '问题',
#   '母亲',
#   '心理',
#   '事',
#   '社畜',
#   '粉丝',
#   '公司'],
#  ['舟', '舟', '动物园'],
#  ['心怀', '知足者', '平常心', '心', '人'],
#  ['上帝', '天使', '眼泪', '流', '晚安'],
#  ['粉丝', '耀客', '闭麦', '清理门户', '人', '职粉', '剧情', '情况', '速速', '闭麦'],
#  ['内', '鬼', '成年人', '表面', '背地里', '核心', '保密', '协议'],
#  ['年龄', '太小', '理会'],
#  ['年龄', '线', '定性'],
#  ['老婆',
#   '妈妈',
#   '数据',
#   '螺们',
#   '个人',
#   '思想',
#   '人',
#   '意见',
#   '地',
#   '鸡毛',
#   '所有人',
#   '底线',
#   '人',
#   '妈妈',
#   '孩子',
#   '拳头',
#   '人',
#   '用力',
#   '多元性',
#   '多元性',
#   '成就'],
#  ['地步', '大学毕业', '中级职称', '经验', '人', '代表', '日子'],
#  ['粉丝', '小朋友', '粉丝', '戏', '演员', '评价', '猎罪', '人家', '演技', '网络', '全文'],
#  ['实体书', '代入', '鹅子', '鹅子', '实体书'],
#  ['对象'],
#  ['偏心'],
#  ['吸引力',
#   '法则',
#   '人',
#   '总会',
#   '人',
#   '人',
#   '偶像',
#   '力量',
#   '成就',
#   '现生',
#   '脚步',
#   '后浪',
#   '光',
#   '信'],
#  ['人', '干嘛', '粉', '面子', '关系', '时间', '书', '门', '哥温'],
#  ['能量', '班', '学校', '市', '校史'],
#  ['人', '人', '人', '眼', '我心', '梦想', '世界'],
#  ['看扁', '桃仁'],
#  ['个人观点',
#   '娱乐圈',
#   '吹学',
#   '霸',
#   '术业',
#   '娱乐圈',
#   '演技',
#   '关键',
#   '学霸',
#   '学霸',
#   '公司',
#   '网易',
#   '字节',
#   '干嘛',
#   '编程',
#   '大厂',
#   '田忌赛马',
#   '专业',
#   '演戏',
#   '成绩',
#   '剧本',
#   '语文',
#   '角色',
#   '数学',
#   '剧本',
#   '逻辑',
#   '发音',
#   '台词',
#   '学霸',
#   '专业'],
#  ['太小',
#   '孩子',
#   '心智',
#   '人',
#   '时刻',
#   '人生',
#   '智商',
#   '情商',
#   '食物链',
#   '参考性',
#   '孩子',
#   '环境',
#   '心智',
#   '娱乐圈',
#   '资本',
#   '工具',
#   '人'],
#  ['鼻子', '酸'],
#  ['话'],
#  ['私信', '妈呀', '流泪'],
#  ['疯子',
#   '有点',
#   '网络',
#   '喷子',
#   '键盘',
#   '疯子',
#   '疯子',
#   '讲道理',
#   '频道',
#   '建议',
#   '精神病院',
#   '人',
#   '祸害'],
#  ['学士'],
#  ['鹅'],
#  ['妹妹',
#   '爱豆',
#   '舟',
#   '重温',
#   '节目',
#   '气',
#   '节目',
#   '妹妹',
#   '人',
#   '妹妹',
#   '眼睛',
#   '眼睛',
#   '脸',
#   '妹妹',
#   '头',
#   '妹妹',
#   '话',
#   '我会',
#   '人肉'],
#  ['表情'],
#  ['舟',
#   '舟',
#   '样子',
#   '人',
#   '艺人',
#   '演员',
#   '时候',
#   '我会',
#   '员工',
#   '控场',
#   '亲自动手',
#   '学',
#   '社畜',
#   '能力',
#   '领导力',
#   '判断力',
#   '演戏',
#   '公司',
#   '部门',
#   '意思'],
#  ['立场'],
#  ['甜妹', '无感', '御姐', '性感', '花', '甜妹', '菜'],
#  ['北影', '毕业', '照', '鹅', '饭卡', '混迹', '戏', '毕业', '毕业'],
#  ['射雕'],
#  ['鹅',
#   '剧是',
#   '浮云',
#   '关心',
#   '编剧',
#   '编剧',
#   '新人',
#   '意',
#   '血液',
#   '思想',
#   '剧',
#   '口碑',
#   '编剧',
#   '肉',
#   '演员',
#   '血液',
#   '肉',
#   '网传',
#   '我鹅',
#   '饼',
#   '心里话',
#   '原著',
#   '事业',
#   '线',
#   '润色',
#   '原因',
#   '剧情',
#   '精彩',
#   '光',
#   '方向'],
#  ['红书', '笔记'],
#  ['人类', '字'],
#  ['单位', '现场'],
#  ['障碍', '中心', '会堂'],
#  ['人', '民主党派'],
#  ['零点', '单位', '高架', '阔别', '家'],
#  ['纪录', '核酸', '单管', '云', '扫码'],
#  ['人民', '群众', '双鱼'],
#  ['酒店', '创纪录'],
#  ['历史', '铭记'],
#  ['疫情', '物资', '疫情', '涨工资', '人生', '赢家', '样子'],
#  ['灵魂'],
#  ['打了个', '出租车', '司机', '单', '时段', '基本'],
#  ['疫情', '社会'],
#  ['疫情', '行业', '旅游业', '演艺', '业', '业'],
#  ['雨', '程度', '感觉', '雨刷器'],
#  ['视界', '游园会'],
#  ['聚力', '视界', '时刻', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '指教', '指教', '微光', '观众', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '线', '微光', '影视音乐', '梦', '梦', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '人物', '时刻', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '王牌', '部队', '王牌', '部队', '时刻', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '微光', '类别', '重磅', '指教', '指教', '微光', '观众', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '大陆', '大陆', '时刻', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '大陆', '大陆', '微光', '观众', '博', '视界', '大会', '微光'],
#  ['通宵', '人', '娘', '答案', '集', '结果', '弹幕', '急性子'],
#  ['花絮', '剧', '花絮', '花絮', '原生态'],
#  ['人', '视频', '感觉', '全场', '感觉', '光', '视频', '镜头', '感觉', '有点', '气场'],
#  ['粉丝', '专属', '背景', '粉籍', '粉丝'],
#  ['宠粉', '卡', '专属', '宠粉', '粉丝', '宠粉', '粉丝'],
#  ['收益', '收益', '亏本'],
#  ['聚力', '视界', '梦', '梦', '微光', '观众', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '影视音乐', '指教', '指教', '时刻', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '微光', '类别', '重磅', '梦', '梦', '微光', '观众', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '王牌', '部队', '人', '王牌', '部队', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '指教', '人', '指教', '博', '视界', '大会', '微光'],
#  ['个性', '图标', '泳池'],
#  ['带回去', '资料', '电脑', '带回去', '日子', '大白', '衣服', '人员', '地方'],
#  ['办公室', '天空', '班'],
#  ['时光', '核酸', '无法', '状态'],
#  ['世界', '童话', '玫瑰花', '会员', '专属', '背景', '暖心', '陪伴', '背景'],
#  ['白血病', '儿童', '力量', '心愿', '小朋友', '孩子'],
#  ['重病', '爷爷', '病房', '馒头', '咸菜', '项目', '点滴', '心灵'],
#  ['故事'],
#  ['人', '红尘', '作伴'],
#  ['倒计时', '碳'],
#  ['新品', '蛋糕', '颜值', '粉粉'],
#  ['女孩'],
#  ['双', '摘星', '广场'],
#  ['菜谱'],
#  ['网民', '女孩', '油盐'],
#  ['脾气', '爹'],
#  ['人', '版面'],
#  ['围栏', '大人', '悲剧'],
#  ['律师', '失业', '律师', '行业', '年龄'],
#  ['悲剧'],
#  ['化工'],
#  ['天', '伤者'],
#  ['精神病人'],
#  ['学校'],
#  ['医院'],
#  ['猫'],
#  ['人'],
#  ['工人'],
#  ['冰'],
#  ['广告', '文'],
#  ['人', '负面新闻'],
#  ['对外经贸', '金融学', '建议'],
#  ['活', '数学'],
#  ['数学', '时候', '脑子'],
#  ['普通人', '意见', '内心', '声音'],
#  ['博', '会员'],
#  ['甜口', '脑袋'],
#  ['大暑', '照片'],
#  ['话', '事儿', '隐溪', '茶馆', '店'],
#  ['车流', '外环', '油门'],
#  ['动手', '菠萝蜜'],
#  ['梦幻', '粉', '紫色'],
#  ['落日'],
#  ['良日', '虾', '甜虾', '浪', '回家'],
#  ['班', '回家', '妈', '核酸'],
#  ['照片', '奶茶', '异地', '鬼'],
#  ['黑叭'],
#  ['记录', '干儿子', '拳拳'],
#  ['班', '口红'],
#  ['人', '口味', '压马路', '路', '电影', '情侣', '空间', '微光', '精彩', '剧情', '气氛', '阶段', '全文'],
#  ['红书', '记录', '心情'],
#  ['设计师', '感', '颜色', '图案', '黄色', '红色', '感觉'],
#  ['季节', '风扇', '风', '光'],
#  ['无线', '脱皮'],
#  ['孩子',
#   '时候',
#   '角色',
#   '手指',
#   '镜头',
#   '化身',
#   '领导者',
#   '代入',
#   '小人',
#   '大事',
#   '感觉',
#   '孩子',
#   '心理',
#   '榜样',
#   '手指',
#   '道具',
#   '销售员',
#   '孩子',
#   '大带',
#   '货',
#   '角色',
#   '道具',
#   '孩子',
#   '道具',
#   '商品',
#   '小',
#   '技巧',
#   '孩子',
#   '时候',
#   '小',
#   '表情',
#   '大家',
#   '时间',
#   '基本上',
#   '小时候',
#   '过程',
#   '居家',
#   '过程',
#   '细品',
#   '细品',
#   '大家',
#   '手机'],
#  ['单身', '狗'],
#  ['倒计时', '天', '天', '分流', '艺术', '日子', '有点', '过度', '力', '陪伴', '大娃', '关键性'],
#  ['日子'],
#  ['爱', '爱意', '爱', '热情', '细水长流', '心灵', '时代', '爱', '方面', '情感'],
#  ['男生', '时候', '太短', '太短', '维系'],
#  ['节奏'],
#  ['盲道'],
#  ['物料', '奶', '视频', '表情', '视频', '视频'],
#  ['体表', '温度'],
#  ['真他妈', '人'],
#  ['钥匙', '骑车', '背包', '核酸', '个人', '形', '工具'],
#  ['帅气', '哥', '甜豆'],
#  ['梦', '甜豆', '朋友', '奇幻', '情节', '仙剑'],
#  ['核酸', '资料', '记录', '战哥'],
#  ['音乐', '人'],
#  ['后劲',
#   '铁肺',
#   '公主',
#   '作词',
#   '人',
#   '作曲',
#   '人',
#   '人',
#   '热门',
#   '电视剧',
#   '热门',
#   '歌曲',
#   '太牛',
#   '桃花',
#   '情歌',
#   '电视剧',
#   '片尾曲',
#   '桃花'],
#  ['噩耗'],
#  ['通话', '心能', '错觉', '大家', '良性'],
#  ['人间'],
#  ['结局',
#   '星辰',
#   '风月',
#   '时光',
#   '荒',
#   '主题曲',
#   '印象',
#   '姐上',
#   '时光',
#   '姐',
#   '歌声',
#   '剧',
#   '国产',
#   '古装剧',
#   '眼神',
#   '官家',
#   '力',
#   '礼',
#   '文人雅士',
#   '气质',
#   '武官',
#   '娘姐',
#   '引章',
#   '妹子',
#   '衙内',
#   '枫哥',
#   '饰演',
#   '夫子',
#   '迷弟',
#   '角色',
#   '前夫',
#   '哥',
#   '花魁',
#   '仙女',
#   '人',
#   '配角',
#   '戏份',
#   '主角',
#   '戏',
#   '剧情',
#   '主题',
#   '演员',
#   '工作人员',
#   '作品'],
#  ['小室', '老板'],
#  ['私信'],
#  ['博', '私信', '干嘛', '用处', '追星', '实名制'],
#  ['节目', '爆米花', '鸡公', '皮蛋'],
#  ['开屏', '心情'],
#  ['恭候', '时影', '大人', '师父'],
#  ['宇宙', '货'],
#  ['社会', '新闻'],
#  ['人', '舞蹈家', '演员', '综艺'],
#  ['人', '爆粗'],
#  ['啤酒', '时刻', '代言人', '开屏', '品牌', '爸爸', '信任', '啤酒'],
#  ['波妞'],
#  ['时间', '齿轮', '齿缝'],
#  ['词', '半岛', '铁盒', '半岛', '铁盒'],
#  ['大家', '信', '事件', '全部', '罪犯', '部门', '公信力'],
#  ['人',
#   '全部',
#   '官方',
#   '文字游戏',
#   '通报',
#   '女生',
#   '全放',
#   '死角',
#   '巷子',
#   '受害者',
#   '医院',
#   '照片',
#   '受害者',
#   '受害者',
#   '家属',
#   '官方',
#   '通报',
#   '女子',
#   '露面',
#   '网友',
#   '受害者',
#   '时',
#   '人'],
#  ['新闻', '打人'],
#  ['网络', '法律', '地方'],
#  ['问题', '部门', '解决问题', '社会', '几代人', '白费'],
#  ['博主',
#   '视频',
#   '社会',
#   '事件',
#   '范围',
#   '视频',
#   '女生',
#   '倒地',
#   '死角',
#   '光线',
#   '惨叫声',
#   '声',
#   '视频',
#   '大家',
#   '性别',
#   '打人'],
#  ['受害者', '性别', '女性', '话题', '法律', '人', '社会', '事件', '关注点', '受害者', '女性', '打人'],
#  ['打人', '社会', '要闻', '人民', '群众', '人', '伤心'],
#  ['旅', '镜头', '电影', '模式', '视频', '故事'],
#  ['动太', '脑子', '小事', '记录', '库存'],
#  ['撸着串', '猩猩', '肉串', '鱿鱼', '牛蛙', '堂食', '广场', '音乐', '蚊子', '晚风'],
#  ['热量', '蛋'],
#  ['无法', '堂食', '堂食', '回家', '兄弟', '烤盘', '星', '环球'],
#  ['茶'],
#  ['诗'],
#  ['大暑', '勇士'],
#  ['香气'],
#  ['堂食'],
#  ['油'],
#  ['碎片'],
#  ['军人', '杯酒', '味苦', '辣', '时间', '积蕴'],
#  ['天地', '难容'],
#  ['气死'],
#  ['人', '市中心'],
#  ['风雨'],
#  ['层层加码', '摘星'],
#  ['逻辑', '力会', '想象力', '云游四方'],
#  ['广场', '领舞', '候选人'],
#  ['车牌号', '毛病'],
#  ['高度'],
#  ['天', '早饭', '烤红薯', '人'],
#  ['成色', '服务行业'],
#  ['瓜', '摊', '老板', '瓜', '世界'],
#  ['盆友', '留胡子'],
#  ['裤衩', '水平'],
#  ['准度', '医疗', '技术', '事情'],
#  ['小孩'],
#  ['人', '运气'],
#  ['数枪', '爸爸'],
#  ['牌位'],
#  ['凡哥', '打人'],
#  ['流量', '钱', '粉丝', '大众', '旱', '涝'],
#  ['风格'],
#  ['好运'],
#  ['主创', '资格', '饭', '离谱'],
#  ['题材', '感兴趣', '选角', '奇幻', '剧', '烂尾'],
#  ['鹅', '大剧片', '单', '饼', '大饼', '饼', '女演员', '资格'],
#  ['专辑', '单曲', '演唱会'],
#  ['星落', '男女', '主', '配音', '电视剧', '星落'],
#  ['小赖', '新剧', '姐姐', '部', '天花板', '事儿'],
#  ['浪姐',
#   '舞台',
#   '大',
#   '心动',
#   '嗓音',
#   '舞台',
#   '唱功',
#   '嗓音',
#   '故事',
#   '声唱',
#   '笔笔',
#   '收尾',
#   '博',
#   '综艺'],
#  ['咖啡', '器具', '小时', '咖啡', '器具', '过程', '偏差', '事情', '人'],
#  ['咖啡'],
#  ['余额',
#   '余额',
#   '油站',
#   '人员',
#   '系统故障',
#   '余额',
#   '油站',
#   '人员',
#   '先生',
#   '评论',
#   '钱',
#   '对方',
#   '评论'],
#  ['人', '高温'],
#  ['网络平台', '记者', '短文', '谣言', '文风', '节操'],
#  ['核酸', '功课', '绿码', '核酸', '地方', '小区', '楼', '新冠', '病毒', '手段', '风车'],
#  ['尾灯', '车'],
#  ['垃圾',
#   '电梯',
#   '一楼',
#   '口罩',
#   '夜色',
#   '回家',
#   '坐电梯',
#   '楼梯',
#   '毛豆',
#   '卤用',
#   '扫码',
#   '核酸',
#   '小时',
#   '残疾'],
#  ['订单', '总算', '空调', '核酸', '事', '核酸'],
#  ['口水', '花钱'],
#  ['街道', '核酸', '居委', '加码', '核酸', '小区', '全民', '品质'],
#  ['早餐',
#   '黑米',
#   '鲜',
#   '虾饼',
#   '半成品',
#   '平底锅',
#   '午餐',
#   '绿豆',
#   '饭团',
#   '绿豆',
#   '绿豆',
#   '牛奶',
#   '冰糖',
#   '豆浆机',
#   '模式',
#   '饭团',
#   '用料',
#   '糯米',
#   '电饭锅',
#   '饭',
#   '肉松',
#   '咸菜',
#   '笋丝',
#   '辣味',
#   '辣味',
#   '糯米饭',
#   '摊平',
#   '食材',
#   '茶',
#   '金丝',
#   '菊',
#   '柠檬'],
#  ['早饭',
#   '天气',
#   '口罩',
#   '汗水',
#   '计划',
#   '空调',
#   '小区',
#   '全员',
#   '核酸',
#   '核酸',
#   '核酸',
#   '阴性',
#   '绿码',
#   '小区',
#   '大门',
#   '人',
#   '小区',
#   '核酸',
#   '小区',
#   '人',
#   '核酸',
#   '早饭',
#   '午饭',
#   '钱',
#   '大妈',
#   '买点'],
#  ['晚饭',
#   '小区',
#   '人',
#   '车',
#   '楼群',
#   '核酸',
#   '惯例',
#   '小区',
#   '村',
#   '阳性',
#   '小区',
#   '核酸',
#   '检测点',
#   '小区',
#   '人',
#   '核酸',
#   '结果',
#   '司机',
#   '市',
#   '疫情',
#   '新闻',
#   '发布会',
#   '通报',
#   '市',
#   '常态',
#   '化',
#   '核酸',
#   '检测点',
#   '大家'],
#  ['高温', '记录'],
#  ['新冠', '病毒', '版', '时', '小区', '对面', '咖啡', '感觉', '烤炉', '五花肉', '粉'],
#  ['高温', '茉莉花'],
#  ['茉莉花',
#   '状态',
#   '晾衣服',
#   '茉莉花',
#   '芍药',
#   '玫瑰',
#   '色彩',
#   '香味',
#   '人们',
#   '茉莉花茶',
#   '茉莉花',
#   '开花',
#   '疫情',
#   '紧张感',
#   '波',
#   '疫情',
#   '数字',
#   '话题',
#   '月份'],
#  ['日子',
#   '日本首相',
#   '演讲时',
#   '商量',
#   '生日蛋糕',
#   '冰箱',
#   '榴莲',
#   '蛋糕',
#   '大热天',
#   '蛋糕',
#   '蛋糕',
#   '徒弟',
#   '街道',
#   '核酸',
#   '常态',
#   '化',
#   '核酸',
#   '疫情',
#   '核酸',
#   '核酸',
#   '距离',
#   '妈妈',
#   '大寿',
#   '疫情',
#   '嫂子',
#   '无法',
#   '回家',
#   '妈妈',
#   '做寿',
#   '看运气'],
#  ['老友', '聚会', '聚会', '疫情', '饭店', '经历', '老友', '大家', '大家', '时期', '更让人'],
#  ['记忆'],
#  ['茉莉花', '芽', '新芽', '枝叶', '枝叶', '枝干', '意料'],
#  ['人生', '视野', '作家', '先生', '形式'],
#  ['空气',
#   '炸锅',
#   '食谱',
#   '配方',
#   '酸奶',
#   '蛋糕',
#   '鸡蛋',
#   '淀粉',
#   '酸奶',
#   '蛋糕',
#   '模具',
#   '气泡',
#   '空气',
#   '炸锅',
#   '蛋糕',
#   '模式',
#   '成品',
#   '淀粉',
#   '量'],
#  ['后娘',
#   '作者',
#   '题材',
#   '女主',
#   '前生',
#   '设计师',
#   '主义者',
#   '农村',
#   '姑娘',
#   '丧偶',
#   '儿子',
#   '军官',
#   '儿子',
#   '丈夫',
#   '儿子',
#   '亲戚',
#   '利用',
#   '粮票',
#   '布票',
#   '食物',
#   '日子',
#   '人物',
#   '个性',
#   '文风',
#   '故事情节',
#   '画面感',
#   '人',
#   '幻想',
#   '演员',
#   '成',
#   '电视剧',
#   '大火'],
#  ['表妹',
#   '空气',
#   '炸锅',
#   '菜',
#   '心动',
#   '空气',
#   '炸锅',
#   '颜值',
#   '价格',
#   '网评',
#   '客服',
#   '钱',
#   '大妈',
#   '半成品',
#   '鸡翅',
#   '体验',
#   '大热天',
#   '节约',
#   '人工',
#   '节约',
#   '油',
#   '蛋糕',
#   '模式'],
#  ['小区',
#   '常态',
#   '化',
#   '核酸',
#   '日子',
#   '轮椅',
#   '全副武装',
#   '鸭舌帽',
#   '长袖',
#   '衣',
#   '核酸',
#   '口罩',
#   '汗水',
#   '大白',
#   '回家',
#   '整件',
#   '汗衫',
#   '汗湿',
#   '温度',
#   '时',
#   '温度',
#   '小区',
#   '核酸',
#   '时',
#   '点位',
#   '点位',
#   '女孩',
#   '天气',
#   '大白',
#   '头',
#   '脚',
#   '积蓄',
#   '热气',
#   '人们',
#   '常态',
#   '化',
#   '核酸'],
#  ['朋友',
#   '礼物',
#   '知己',
#   '好友',
#   '古色古香',
#   '花丝',
#   '工艺',
#   '好友',
#   '礼物',
#   '香片',
#   '柠檬',
#   '香味',
#   '味',
#   '走珠',
#   '香片',
#   '办公桌',
#   '地方',
#   '索性',
#   '工作服',
#   '口袋',
#   '动作',
#   '味道',
#   '人闻',
#   '车',
#   '时',
#   '车',
#   '视线',
#   '香片',
#   '消耗',
#   '有点',
#   '礼物',
#   '人'],
#  ['同学',
#   '朋友圈',
#   '事',
#   '疫情',
#   '学校',
#   '学生',
#   '上学',
#   '交通',
#   '方式',
#   '亲戚家',
#   '孩子',
#   '骑车',
#   '上学',
#   '自行车',
#   '报案',
#   '自行车',
#   '自行车',
#   '遭遇',
#   '孩子',
#   '轻骑',
#   '爸妈',
#   '功夫',
#   '报案',
#   '声息',
#   '市',
#   '医院',
#   '时',
#   '手机',
#   '厕所',
#   '隔间',
#   '大厅',
#   '单位',
#   '人',
#   '厕所',
#   '摄像头',
#   '轻骑',
#   '经验',
#   '计划',
#   '外地',
#   '报警',
#   '同事',
#   '医院',
#   '无权',
#   '权限',
#   '派出所',
#   '备案',
#   '外地',
#   '民警',
#   '流程',
#   '备案',
#   '时',
#   '医院',
#   '人',
#   '民警',
#   '派出所',
#   '大门',
#   '报警',
#   '声息',
#   '医院',
#   '机密',
#   '单位',
#   '医院',
#   '人',
#   '同事',
#   '外人',
#   '同事',
#   '报案',
#   '声息',
#   '无法',
#   '记录',
#   '情况',
#   '原因',
#   '起码',
#   '电话',
#   '案件',
#   '声息'],
#  ['理', '小区', '核酸', '志愿者', '索性', '电', '工具', '感觉', '练练手', '职业'],
#  ['车',
#   '下车时',
#   '手机',
#   '亲属',
#   '老',
#   '问题',
#   '亲属',
#   '信息',
#   '仔细阅读',
#   '亲属',
#   '人',
#   '工作人员',
#   '全文'],
#  ['小区',
#   '封闭式',
#   '核酸',
#   '小时',
#   '楼',
#   '楼',
#   '工作日',
#   '床单',
#   '蚊子',
#   '血',
#   '原',
#   '回家',
#   '时间',
#   '枕套',
#   '洗衣机',
#   '核酸',
#   '太值',
#   '温度',
#   '天气',
#   '客用',
#   '棉',
#   '拖鞋',
#   '床单',
#   '充分利用',
#   '时间',
#   '天气',
#   '核酸',
#   '小区',
#   '时',
#   '小区',
#   '私家车',
#   '车主',
#   '声音',
#   '核酸',
#   '问题',
#   '高温',
#   '小区',
#   '油价',
#   '人民',
#   '单位',
#   '群',
#   '信息',
#   '园区',
#   '核酸',
#   '核酸',
#   '路'],
#  ['外地',
#   '朋友',
#   '问',
#   '疫情',
#   '有点',
#   '对面',
#   '小区',
#   '镇',
#   '小区',
#   '楼',
#   '马路',
#   '小区',
#   '同事',
#   '短信',
#   '数据',
#   '新冠',
#   '感染者',
#   '风险',
#   '楼',
#   '小区',
#   '物理',
#   '照片',
#   '有点',
#   '小区',
#   '封闭式',
#   '核酸',
#   '社区',
#   '核酸',
#   '形势',
#   '人',
#   '有点',
#   '心慌慌'],
#  ['同事',
#   '人生',
#   '单',
#   '女同事',
#   '辫子',
#   '同事',
#   '头发',
#   '夹子',
#   '头发',
#   '人',
#   '午饭',
#   '时间',
#   '时间',
#   '有点',
#   '主义者',
#   '内心',
#   '有点',
#   '时间',
#   '看点',
#   '视频'],
#  ['人生', '剪刀', '评价', '人', '战胜', '新技能'],
#  ['对面',
#   '村',
#   '小区',
#   '问',
#   '村',
#   '小时',
#   '村',
#   '铁皮',
#   '大门',
#   '照片',
#   '视频',
#   '感觉',
#   '村',
#   '楼',
#   '文件',
#   '感觉',
#   '语文',
#   '文件',
#   '大家',
#   '总结',
#   '小区',
#   '分块',
#   '阳',
#   '范围',
#   '区域',
#   '限度',
#   '损失',
#   '物理',
#   '铁皮',
#   '个人',
#   '状态'],
#  ['小区',
#   '封闭式',
#   '核酸',
#   '妈妈',
#   '药',
#   '小区',
#   '时节',
#   '晚饭',
#   '对面',
#   '小区',
#   '小区',
#   '居民',
#   '买菜',
#   '感觉',
#   '同事',
#   '单位',
#   '方便面',
#   '睡袋',
#   '用品'],
#  ['小区',
#   '封闭式',
#   '核酸',
#   '小区',
#   '美容院',
#   '小区',
#   '阳性',
#   '表弟',
#   '小区',
#   '阳性',
#   '原本',
#   '表妹',
#   '产假',
#   '大家',
#   '有点',
#   '关',
#   '心态',
#   '药',
#   '妈妈',
#   '常用药',
#   '居委',
#   '交代',
#   '医生',
#   '量',
#   '同事',
#   '药',
#   '药',
#   '市东',
#   '医院',
#   '医院',
#   '药',
#   '量',
#   '医生',
#   '药都',
#   '顺带',
#   '核酸',
#   '报告',
#   '医院',
#   '陌生',
#   '大姐',
#   '配药',
#   '全程',
#   '小时',
#   '买菜',
#   '买菜',
#   '队',
#   '取件',
#   '疫情',
#   '地区',
#   '无法',
#   '寄件',
#   '地址',
#   '单位',
#   '下单',
#   '午饭',
#   '药',
#   '单位',
#   '门卫室',
#   '车',
#   '油',
#   '油价',
#   '内容',
#   '内',
#   '核酸',
#   '黄码',
#   '核酸',
#   '核酸',
#   '报告',
#   '阳性',
#   '核酸',
#   '镇',
#   '全镇',
#   '菜',
#   '药',
#   '小区'],
#  ['猫猫'],
#  ['小', '黑豆', '睡姿'],
#  ['睡姿', '意思'],
#  ['疫情', '事件', '事件', '社会', '资本化', '负面', '消息'],
#  ['酷夏', '小鸟', '猫'],
#  ['行业', '薪资', '世界', '高材生'],
#  ['状态', '时间', '事情', '时候', '人', '事情'],
#  ['部门', '老人家', '大厂', '背景'],
#  ['餐饮',
#   '品牌',
#   '商场',
#   '品牌',
#   '午饭',
#   '商场',
#   '餐饮',
#   '商场',
#   '体验',
#   '店',
#   '口味',
#   '川菜',
#   '厨子',
#   '味道',
#   '品牌',
#   '味道'],
#  ['小区', '朋友圈', '卖东西', '专业对口', '衣物', '玩具', '朋友圈', '卖东西'],
#  ['原因', '方圆', '根系'],
#  ['鲜肉', '月饼'],
#  ['副业', '卖货', '卖货'],
#  ['国', '企事业', '单位', '老师', '法式', '姥姥', '保险', '员工'],
#  ['半成品', '食材'],
#  ['方式', '大家', '院子', '院子', '农村', '面积', '大面积', '农田', '院子'],
#  ['环境', '人'],
#  ['疫情',
#   '节奏',
#   '无法',
#   '探亲',
#   '无法',
#   '情绪',
#   '疫情',
#   '堂食',
#   '餐饮',
#   '关店',
#   '好事',
#   '职业',
#   '小区',
#   '餐饮店',
#   '老板'],
#  ['收益', '低息', '银行'],
#  ['房', '车', '贷款', '存款', '水平', '水平', '套房'],
#  ['公司', '核酸', '小区', '核酸', '工作日', '抗原'],
#  ['老家', '亲戚', '病例'],
#  ['大'],
#  ['茶'],
#  ['地铁', '医院'],
#  ['兆头', '公司', '全员', '雨'],
#  ['下家',
#   '商场',
#   '店面',
#   '小店',
#   '夜市',
#   '感觉',
#   '灯火通明',
#   '冷气',
#   '厕所',
#   '卫生纸',
#   '店',
#   '大家',
#   '活力',
#   '样子',
#   '公司',
#   '高端',
#   '商场',
#   '人',
#   '人',
#   '人',
#   '全文'],
#  ['大家', '疫情', '商场', '家人', '空间'],
#  ['家庭', '能力', '成绩', '人生'],
#  ['跑步',
#   '皮划艇',
#   '机构',
#   '办学',
#   '地址',
#   '人',
#   '皮划艇',
#   '机构',
#   '小孩子',
#   '皮划艇',
#   '感觉',
#   '孩子',
#   '大人',
#   '政府',
#   '野游',
#   '人',
#   '皮划艇',
#   '人',
#   '小伙子',
#   '皮划艇',
#   '悲剧',
#   '人',
#   '野泳',
#   '学校',
#   '每学期',
#   '家长',
#   '人',
#   '时候',
#   '湖面',
#   '野泳',
#   '皮划艇',
#   '人',
#   '脑子',
#   '疫情',
#   '方式',
#   '人',
#   '商场',
#   '大家',
#   '搭帐篷',
#   '玩水'],
#  ['楼', '小', '店铺', '苍蝇', '馆子', '大家', '人', '商场', '家店', '疫情', '房租', '员工', '损失'],
#  ['公司', '小时候', '田地'],
#  ['地铁', '年轻人', '年轻人', '老人家', '扫码', '疫情', '老年人', '大家'],
#  ['朋友',
#   '危机',
#   '领导',
#   '裁员',
#   '风险',
#   '本地人',
#   '套房',
#   '市区',
#   '学区',
#   '房',
#   '老婆',
#   '全职',
#   '存款',
#   '豪车',
#   '生',
#   '胎',
#   '副业',
#   '失业',
#   '资金',
#   '女儿',
#   '存款',
#   '底气'],
#  ['商业',
#   '卖菜',
#   '婴儿车',
#   '蚊子',
#   '肿块',
#   '疫情',
#   '印象',
#   '疫情',
#   '买菜',
#   '老板娘',
#   '车',
#   '老家',
#   '商铺',
#   '老板',
#   '娃娃',
#   '一家子',
#   '菜摊',
#   '娃娃',
#   '纸',
#   '壳子',
#   '毛坯房',
#   '卖菜',
#   '钱'],
#  ['眼神', '同类'],
#  ['猫'],
#  ['陪伴', '情'],
#  ['国金', '号口'],
#  ['模式', '日照'],
#  ['大'],
#  ['人', '爷爷', '天堂', '爸爸'],
#  ['早餐'],
#  ['朋友', '见面'],
#  ['太苦', '宇宙'],
#  ['共情'],
#  ['衣服', '鞋子', '美女'],
#  ['照片'],
#  ['大家', '小', '梦想', '高校', '咖啡'],
#  ['大家', '玩具'],
#  ['事'],
#  ['工作室', '视角'],
#  ['旅'],
#  ['人', '区', '废物', '状态'],
#  ['小学', '朋友', '放学', '天空'],
#  ['秘密', '秘密'],
#  ['老家'],
#  ['事情', '机构', '事情', '性格'],
#  ['妈', '女生', '错'],
#  ['佳园', '街坊'],
#  ['佳园', '街坊'],
#  ['落日', '夜景', '风情', '文化', '遗址'],
#  ['时间', '连续剧', '小说', '过剧', '差点', '剧里', '男女'],
#  ['后背', '肌肉', '佳园', '街坊'],
#  ['计划', '全部'],
#  ['感觉', '佳园', '街坊'],
#  ['办公室', '办公室', '根源', '广场'],
#  ['早饭', '空气', '炸锅', '佳园', '街坊'],
#  ['黑', '裙子', '佳园', '街坊'],
#  ['佳园', '街坊'],
#  ['高境', '二村'],
#  ['疫情', '见面', '女人', '八卦', '汇'],
#  ['居家', '办公', '时间', '佳园', '街坊'],
#  ['层楼', '佳园', '街坊'],
#  ['心脏病', '地铁站'],
#  ['集团', '报告', '佳园', '街坊'],
#  ['医院', '回家', '坐垫'],
#  ['总结报告', '佳园', '街坊'],
#  ['事情', '兴趣', '无趣', '人生', '广场'],
#  ['所闻', '星子', '佳园', '街坊'],
#  ['地铁站'],
#  ['地铁', '地铁站'],
#  ['绿色', '棒棒糖', '糖', '脂', '地铁站'],
#  ['配色'],
#  ['工作服', '地方', '空气', '味道', '水族馆', '水族馆'],
#  ['纪念', '人'],
#  ['爬楼', '小时', '楼梯', '浑身', '汗水', '雨水', '往下滴', '佳园', '街坊'],
#  ['空气', '炸锅', '懒人', '做菜', '伴侣'],
#  ['游乐场', '家居', '商场'],
#  ['武', '康路', '人', '世界', '基本', '口罩', '口罩', '异类', '康路', '交叉口'],
#  ['人', '模板', '模板', '时间', '模板'],
#  ['字', '佳园', '街坊'],
#  ['咖啡', '佳园', '街坊'],
#  ['天地', '父母'],
#  ['总', '佳园', '街坊'],
#  ['时候', '人', '小毛病', '佳园', '街坊'],
#  ['心',
#   '眼',
#   '泪滴',
#   '脸',
#   '刹那之间',
#   '情景',
#   '化',
#   '烟',
#   '人',
#   '人',
#   '苦',
#   '人',
#   '人生',
#   '流星',
#   '道光',
#   '漫长',
#   '黑夜',
#   '人世间',
#   '风',
#   '歌唱',
#   '人'],
#  ['感觉', '地铁站'],
#  ['结果', '人生', '时候', '无人', '无人', '路', '普通人', '人生', '状态', '人生'],
#  ['线下', '涨价', '角', '佳园', '街坊'],
#  ['鹅', '嘴', '鹅', '袋子', '太丑'],
#  ['好景'],
#  ['名字', '桃子', '甜度', '水分'],
#  ['小岛', '风情', '东风', '水库'],
#  ['男足', '国', '男足', '国队'],
#  ['油烟机', '鸟窝'],
#  ['蔬菜', '老农', '玫瑰', '玫瑰', '假货', '玫瑰', '茉莉', '标志', '玫瑰'],
#  ['微信', '消息', '系统'],
#  ['泄题', '题目', '手写', '人', '手抄', '源头', '人', '题'],
#  ['感觉'],
#  ['昙花'],
#  ['笔记本', '充电器', '手机'],
#  ['四字',
#   '事件',
#   '结果',
#   '国家',
#   '话剧院',
#   '流量',
#   '时代',
#   '商业利益',
#   '规则',
#   '潜规则',
#   '题家',
#   '时代',
#   '主旋律'],
#  ['文字游戏'],
#  ['全家', '便利店', '店'],
#  ['博',
#   '电影',
#   '助力',
#   '好友',
#   '年度',
#   '影片',
#   '电影',
#   '市场',
#   '机会',
#   '电影',
#   '博',
#   '电影',
#   '年度',
#   '电影'],
#  ['聚力', '视界', '微光', '观众', '博', '视界', '大会', '微光'],
#  ['少女', '心', '超现实'],
#  ['风'],
#  ['圈内人', '圈外人', '内娱', '电影'],
#  ['人气', '粉丝', '头衔'],
#  ['核酸', '证明'],
#  ['时候', '静态', '实体'],
#  ['速度', '覆盖面', '方式', '数字', '数字', '来源', '链接'],
#  ['孩子', '儿孙'],
#  ['图', '酒店', '大堂', '科幻片', '人', '心情', '总会', '魔幻', '生病', '居委', '胆子', '假日酒店'],
#  ['疫苗', '地步', '原则', '朋友', '亲人'],
#  ['政策', '人'],
#  ['疫苗'],
#  ['公寓', '市井', '气息', '人家', '弄堂', '面馆', '路店'],
#  ['拿大奖', '地方'],
#  ['感觉',
#   '灰',
#   '店门口',
#   '蓝',
#   '衣服',
#   '人',
#   '时刻',
#   '大家',
#   '扫码',
#   '购物',
#   '热情',
#   '堂食',
#   '地方',
#   '商业街'],
#  ['时代', '风景', '扫码', '堂食', '地方', '时代广场'],
#  ['总想', '小区', '大家', '数字', '奴隶', '厕所', '时效', '疫情'],
#  ['人心'],
#  ['世纪', '世纪', '二楼', '活力'],
#  ['平常心', '事', '人'],
#  ['信任', '结果'],
#  ['园区', '小朋友', '美女', '勇者', '日文版', '孤身', '暗巷', '模样'],
#  ['小时', '汤', '冰箱', '冰镇', '汤', '健脾', '脾'],
#  ['心生', '人心', '点儿', '脸'],
#  ['小店'],
#  ['图片', '风景', '旅游区'],
#  ['小区',
#   '场所',
#   '码入',
#   '场所',
#   '码',
#   '风',
#   '回家',
#   '冰箱',
#   '冰',
#   '芒果汁',
#   '冰',
#   '芒果汁',
#   '一段距离',
#   '方向',
#   '陌生',
#   '地铁口',
#   '父子',
#   '比'],
#  ['爷爷奶奶', '梦'],
#  ['人', '利益', '事实'],
#  ['梦', '梦'],
#  ['雪糕'],
#  ['剧情', '剧情', '心情', '感觉'],
#  ['咖啡馆',
#   '小朋友',
#   '姐姐',
#   '问道',
#   '班',
#   '小朋友',
#   '姐姐',
#   '妈妈',
#   '小朋友',
#   '小时',
#   '时光',
#   '朋友',
#   '孩子',
#   '缘',
#   '心',
#   '孩子',
#   '眼睛'],
#  ['人', '原则'],
#  ['堂弟', '婚因', '疫情'],
#  ['前路', '物', '沙棘', '姐妹'],
#  ['大署', '清风', '烈日', '专场', '水弹'],
#  ['太'],
#  ['力', '热', '光', '爱', '酒', '朋友', '乖囡'],
#  ['女人', '天花板', '对方', '绊脚石', '塑料', '姐妹花'],
#  ['世界', '吃货', '心想'],
#  ['番茄', '油桃', '方圆', '生态农业', '观光'],
#  ['时', '光', '专业', '专'],
#  ['记录', '百度', '勒庞', '作者', '汗颜', '毕业', '军医', '物理', '方面', '著作'],
#  ['审片', '人员', '部位', '部位', '字眼', '字典', '大家'],
#  ['云', '色彩', '脱裤子'],
#  ['状态', '人生', '时光', '索性', '学会', '心态'],
#  ['回家', '回家', '人'],
#  ['想象', '泳衣', '性感', '时间', '荒原'],
#  ['债'],
#  ['民主自由', '国家', '党', '决议'],
#  ['事情',
#   '标签',
#   '故事',
#   '薯片',
#   '薯片',
#   '时间',
#   '意义',
#   '事情',
#   '大家',
#   '手机',
#   '疾控中心',
#   '大',
#   '人员',
#   '光明',
#   '话',
#   '人',
#   '个人信息',
#   '同行者',
#   '信息',
#   '事实',
#   '大病',
#   '酒店',
#   '理由',
#   '居委',
#   '电话',
#   '酒店',
#   '同事',
#   '酒店',
#   '定性',
#   '同桌',
#   '人阳',
#   '时空',
#   '时段',
#   '饭馆',
#   '人',
#   '人员',
#   '地方',
#   '条件',
#   '酒店',
#   '条件',
#   '区政府',
#   '酒店',
#   '冠上',
#   '字',
#   '感觉',
#   '公民',
#   '身份',
#   '随性',
#   '午饭',
#   '人',
#   '薯片',
#   '薯片',
#   '人',
#   '坏毛病',
#   '同理',
#   '行李箱',
#   '薯片',
#   '房间',
#   '散步',
#   '时候',
#   '电脑',
#   '时候',
#   '时候',
#   '薯片',
#   '妈妈',
#   '行李',
#   '薯片',
#   '袋装',
#   '结伴',
#   '门',
#   '规章制度',
#   '房门',
#   '有点',
#   '薯片',
#   '脑',
#   '场面',
#   '篮子',
#   '弧度',
#   '小',
#   '爪子',
#   '老娘',
#   '火',
#   '大家',
#   '大戏',
#   '老人',
#   '孩子',
#   '恶心',
#   '至极',
#   '房门',
#   '胆子',
#   '工作人员',
#   '时间',
#   '意义',
#   '时间',
#   '意义',
#   '核酸',
#   '体温',
#   '量',
#   '准点',
#   '时间',
#   '现实',
#   '意义',
#   '真空',
#   '社会性',
#   '属性',
#   '事情',
#   '规则',
#   '疫情',
#   '产业',
#   '社会',
#   '模式',
#   '正常人',
#   '平行',
#   '空间',
#   '人',
#   '社会',
#   '属性',
#   '真空',
#   '人',
#   '空间',
#   '角色',
#   '时间',
#   '意义',
#   '社会',
#   '交际',
#   '亲人',
#   '朋友',
#   '感觉',
#   '兽器',
#   '陷阱',
#   '世界',
#   '猎人',
#   '事情',
#   '房间',
#   '房间',
#   '声',
#   '生气',
#   '人',
#   '心态',
#   '怪',
#   '谍报',
#   '手机',
#   '模式',
#   '军事',
#   '装甲车',
#   '火箭筒',
#   '手榴弹',
#   '战壕',
#   '体能训练',
#   '小时',
#   '模式',
#   '照片',
#   '模式',
#   '手机',
#   '体验',
#   '兄弟',
#   '精彩',
#   '满足感',
#   '手机',
#   '常规',
#   '新闻',
#   '视频',
#   '韧带',
#   '时间',
#   '猫眼',
#   '大白',
#   '信群',
#   '人员',
#   '房间',
#   '全都',
#   '空房',
#   '房间',
#   '平板'],
#  ['光明', '事件', '作文', '脑袋', '有点', '卡', '信息量', '有点'],
#  ['半池', '鱼', '戏', '莲间', '意'],
#  ['办公室',
#   '空调',
#   '有点',
#   '有点',
#   '脚',
#   '有点',
#   '楼',
#   '走廊',
#   '走廊',
#   '女孩',
#   '门',
#   '楼',
#   '平台',
#   '透透气',
#   '风口',
#   '处',
#   '风',
#   '鼻腔',
#   '口罩',
#   '感觉',
#   '大厦',
#   '白色',
#   '简易房',
#   '刻板',
#   '无趣',
#   '风',
#   '梦'],
#  ['妈', '听筒', '病人', '总算'],
#  ['青空', '卧虹', '浮云'],
#  ['骑马', '猪', '戒', '猪', '鼻子', '箩', '妖婆', '妖婆'],
#  ['小学', '同学', '动手', '老师', '双方', '假装', '怒色'],
#  ['老婆', '孩子', '女朋友', '朋友圈', '媒体', '朋友圈'],
#  ['二舅', '百姓', '缩影', '励志', '能量', '二舅', '人生', '微澜'],
#  ['疫情', '个门', '光是', '码', '人', '街面上', '百姓', '病毒'],
#  ['客流量', '高铁', '造型', '基本'],
#  ['环境',
#   '地理位置',
#   '气候',
#   '所限',
#   '旅游区',
#   '营业',
#   '商户',
#   '从业者',
#   '涨价',
#   '现行',
#   '政策',
#   '营业时间',
#   '景区'],
#  ['疫情', '国家', '经济', '建议', '国家', '国际', '运动会'],
#  ['汽车品牌',
#   '汽车',
#   '人',
#   '热衷',
#   '新能源',
#   '电动车',
#   '时',
#   '传统',
#   '燃油',
#   '发动机',
#   '费用',
#   '燃油',
#   '发动机',
#   '领域',
#   '国家'],
#  ['科', '学科', '时'],
#  ['全国', '高校'],
#  ['过程', '合法'],
#  ['全款', '买房', '业主', '楼盘', '烂尾'],
#  ['家庭', '买房', '几代人', '积蓄', '主体', '失业', '压力'],
#  ['老年人', '影响力', '台独分子'],
#  ['国家', '激将法', '过度'],
#  ['对'],
#  ['举办权', '方式'],
#  ['疫情', '战争', '病毒', '敌人', '时', '控区', '合围', '区'],
#  ['国防力量', '外敌', '外敌', '文化', '人种', '国家'],
#  ['精准', '赋红码'],
#  ['老一辈', '艺术家', '经典', '影视作品', '经历', '影视剧', '实际', '贴近生活', '群众', '观众', '心'],
#  ['烧烤店', '暴徒', '作案', '情况', '经历', '作案', '风头', '初犯', '犯事', '打人'],
#  ['聚力', '视界', '人', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '微光', '观众', '博', '视界', '大会', '微光'],
#  ['聚力', '视界', '剧集', '作品', '时刻', '博', '视界', '大会', '微光'],
#  ['芒果', '海风'],
#  ['小', '粉丝', '心情', '篇章'],
#  ['小', '粉丝', '躺平'],
#  ['饭', '心情', '过程'],
#  ['爸爸', '父亲节', '爸爸', '全世界', '爸爸', '父亲节'],
#  ['面包'],
#  ['文章', '读史', '毛主席', '坦率', '空想', '血', '著作'],
#  ['儿子',
#   '国际',
#   '海水浴场',
#   '细水',
#   '公路',
#   '电动',
#   '助力车',
#   '风景',
#   '宾馆',
#   '菜',
#   '品味',
#   '鲜汁',
#   '浓',
#   '炸',
#   '里脊',
#   '白菜',
#   '虾',
#   '汤',
#   '技法',
#   '锅包肉',
#   '印象'],
#  ['核酸',
#   '核酸',
#   '检测点',
#   '全部',
#   '选项',
#   '检测点',
#   '时段',
#   '时间',
#   '检测点',
#   '排队',
#   '人',
#   '排队',
#   '情况'],
#  ['当地人', '本地人', '游客', '天', '赋灰码', '黄码'],
#  ['核酸',
#   '问',
#   '前台',
#   '外省',
#   '人员',
#   '定点',
#   '检测点',
#   '排队',
#   '身份证',
#   '条形码',
#   '扫码',
#   '核酸',
#   '绿码',
#   '购物'],
#  ['风险',
#   '区',
#   '高铁',
#   '目的地',
#   '分流',
#   '需时',
#   '行程',
#   '码',
#   '信息',
#   '离站',
#   '出租车',
#   '目的地',
#   '社区',
#   '人员',
#   '电话',
#   '人员',
#   '信息',
#   '态度',
#   '宾馆',
#   '身份证'],
#  ['弹词',
#   '开篇',
#   '美帝',
#   '寿命长',
#   '阵营',
#   '人民',
#   '一甲子',
#   '局势',
#   '消长',
#   '好象',
#   '无魂',
#   '主人',
#   '视频',
#   '弹词',
#   '开篇',
#   '美帝',
#   '寿命',
#   '黑胶',
#   '唱片'],
#  ['教授'],
#  ['强势', '时'],
#  ['摄影师', '镜头', '摄影师', '镜头'],
#  ['文章', '政治', '历史观'],
#  ['常态',
#   '化',
#   '核酸',
#   '排队',
#   '人',
#   '老',
#   '买菜',
#   '右手',
#   '马',
#   '夹袋',
#   '环抱',
#   '莴笋',
#   '大',
#   '购物袋',
#   '时',
#   '核酸'],
#  ['冠', '人员', '复阳', '大巴', '小区', '复阳', '少见'],
#  ['楼',
#   '喇叭',
#   '全体人员',
#   '核酸',
#   '人员',
#   '人员',
#   '词',
#   '小区',
#   '信群',
#   '冠',
#   '阳性',
#   '人员',
#   '阳性',
#   '摘帽',
#   '人员'],
#  ['妻子',
#   '电话',
#   '核酸',
#   '抗原',
#   '结果',
#   '老人',
#   '地问',
#   '红色',
#   '妻子',
#   '杠就',
#   '行',
#   '腿脚',
#   '会儿',
#   '黄码',
#   '居委'],
#  ['国产', '老电影', '哔哩', '哔哩'],
#  ['人家', '事业型', '妇'],
#  ['树屋', '咖啡', '人', '狗', '店'],
#  ['作业', '父母', '干嘛', '孩子', '自律', '父母', '生气', '孩子', '父母', '讲道理', '孩子', '问题'],
#  ['人家', '勾值'],
#  ['奶酪', '饼干', '零食', '咖啡', '鲜萃', '鲜奶', '家庭', '概率', '披萨'],
#  ['牙', '仙子', '金币'],
#  ['树屋',
#   '咖啡',
#   '老板',
#   '月份',
#   '开业',
#   '大树',
#   '日式',
#   '木质',
#   '居家',
#   '风格',
#   '咖啡',
#   '风味',
#   '定价',
#   '性价比',
#   '情商',
#   '柴犬',
#   '人',
#   '撸',
#   '撸的',
#   '弟弟',
#   '机会',
#   '撸'],
#  ['笑声', '魔性'],
#  ['电影院'],
#  ['做寿',
#   '餐厅',
#   '回家',
#   '锅',
#   '酱汁',
#   '店里',
#   '无菌',
#   '蛋',
#   '调料',
#   '马家',
#   '牛肉',
#   '品质',
#   '豆制品',
#   '蔬菜',
#   '肉'],
#  ['人', '梳妆台', '写字', '梳妆台'],
#  ['侧门', '消', '隐患'],
#  ['水面', '小黄花', '参差', '菜', '诗经', '形象'],
#  ['菜',
#   '酱汁',
#   '花卷',
#   '味道',
#   '马蹄',
#   '肉丸',
#   '酱汁',
#   '加点',
#   '芝麻',
#   '向日葵',
#   '花瓣',
#   '质感',
#   '色彩',
#   '花花'],
#  ['宝', '腿', '柜角', '时候', '小刀', '家具', '柜角', '好气', '腿'],
#  ['物业', '街道', '文件', '文件', '办事', '时候'],
#  ['菜用',
#   '空气',
#   '炸锅',
#   '炸',
#   '猪排',
#   '感觉',
#   '饼',
#   '空气',
#   '炸锅',
#   '炸',
#   '样子',
#   '浓油',
#   '赤酱',
#   '小',
#   '素鸡',
#   '皮蛋',
#   '豆瓣',
#   '大家',
#   '菜',
#   '菠菜',
#   '菜'],
#  ['中式', '轻食', '感觉', '胃'],
#  ['问题', '平台', '车型', '时候', '空调', '选项', '问题'],
#  ['队友', '披萨', '披萨', '披萨', '口感', '花园', '口感', '肉', '披萨', '感觉'],
#  ['大叔', '形象'],
#  ['疫情'],
#  ['瑰夏', '果汁', '味'],
#  ['阳性', '人'],
#  ['人情'],
#  ['晚餐',
#   '办法',
#   '菜饭',
#   '土豆',
#   '条',
#   '花生',
#   '蔬菜',
#   '装盘',
#   '酱',
#   '菜',
#   '宝',
#   '装盘',
#   '麻麻',
#   '烤鱼',
#   '晚餐'],
#  ['人', '岛', '车速', '赛车手'],
#  ['咖啡师', '主题', '纸浆', '圆筒', '装饰', '广场'],
#  ['公司'],
#  ['内地', '门店', '蛋糕', '照片', '店', '频'],
#  ['猫猫', '黏人'],
#  ['父母'],
#  ['咖啡', '暑气', '咖啡师', '墙裂', '干花', '鸡爪', '插花'],
#  ['父母', '孩子'],
#  ['学校', '作业', '家长', '问', '历史', '历史', '地区', '成陆', '意思', '陆地'],
#  ['道理', '机票', '钥匙', '证', '老人', '小孩'],
#  ['队友',
#   '黄油',
#   '面包',
#   '面包',
#   '牛排',
#   '面包',
#   '碱水',
#   '香肠',
#   '奶酪',
#   '碱水',
#   '黄油',
#   '面包',
#   '碳水',
#   '反省'],
#  ['垃圾桶', '孩子'],
#  ['换点', '气'],
#  ['黄油',
#   '面包',
#   '闺蜜',
#   '心心念念',
#   '店',
#   '小时',
#   '队',
#   '排队',
#   '战斧',
#   '牛排',
#   '牛排',
#   '面包',
#   '天',
#   '空调',
#   '人',
#   '店里',
#   '冰',
#   '铁',
#   '味道',
#   '面包',
#   '店名',
#   '黄油',
#   '奶油味'],
#  ['泥', '点子', '本泥'],
#  ['蜂蜜', '坚果', '核桃仁', '口感', '切片', '奶酪', '队友', '香肠', '奶昔', '煎蛋', '咖啡'],
#  ['流浪'],
#  ['葡萄', '玻璃', '珍珠', '紫', '玻璃'],
#  ['奶昔', '香蕉', '风声', '有点'],
#  ['原则', '表情'],
#  ['概率', '事件'],
#  ['菜',
#   '凉菜',
#   '皮蛋',
#   '蔬菜',
#   '奶酪',
#   '口感',
#   '粉丝',
#   '菜',
#   '盐水鸭',
#   '刀工',
#   '太丑',
#   '主食',
#   '种酱',
#   '馒头'],
#  ['裙装', '欧式', '宫廷', '裙装'],
#  ['电影',
#   '鼠',
#   '菜',
#   '美食家',
#   '杂菜',
#   '图',
#   '道菜',
#   '电影',
#   '味道',
#   '味道',
#   '香草',
#   '烤鸡',
#   '配菜',
#   '土豆',
#   '奶油',
#   '酱',
#   '饼',
#   '鹰嘴豆',
#   '泥和油',
#   '番茄',
#   '异域',
#   '风味',
#   '橄榄',
#   '番茄酱',
#   '叶酱',
#   '卷心菜',
#   '队友',
#   '野餐',
#   '热狗',
#   '异域',
#   '风情'],
#  ['雨'],
#  ['典型', '风格', '客观', '主题曲', '青花瓷', '夜曲', '老歌'],
#  ['天气', '外送', '味道', '手', '包菜', '牛肉', '县', '豆', '饭菜', '番茄'],
#  ['高温', '气象', '记录', '高温', '核酸', '队', '感觉', '热狗'],
#  ['热狗',
#   '热狗',
#   '事情',
#   '酱料',
#   '芥末',
#   '酱',
#   '黄瓜',
#   '酱',
#   '番茄酱',
#   '洋葱',
#   '香肠',
#   '面包',
#   '尺寸',
#   '香肠',
#   '热狗'],
#  ['妈呀', '玩儿'],
#  ['香肠', '红糖', '花卷', '鸡胸', '鸡蛋', '奶昔', '咖啡', '队友', '百合', '玫瑰', '鸡腿'],
#  ['储物柜'],
#  ['背', '古诗', '意思', '男性', '地问', '女性', '老妈', '老母'],
#  ['马', '运力', '菜', '菜', '问题'],
#  ['邻居们', '群里', '柠檬', '挑战赛', '持平', '头', '柠檬'],
#  ['花园', '环境', '餐厅', '经', '风格'],
#  ['下单', '运力', '单', '感觉', '人', '大家', '消息', '真假', '菜'],
#  ['花园',
#   '队友',
#   '牛排',
#   '烩饭',
#   '面包',
#   '核桃仁',
#   '小面包',
#   '薯条',
#   '下午茶',
#   '咖啡',
#   '熔岩',
#   '蛋糕',
#   '香草',
#   '冰激凌',
#   '口感'],
#  ['传', '人'],
#  ['回家', '光明', '冰', '砖', '降降温'],
#  ['区'],
#  ['小伴', '咖啡', '路上行人', '店', '咖啡店', '小伴', '天气', '冰', '咖啡', '冰杯', '分层', '店', '桥'],
#  ['人', '事件'],
#  ['菜', '烤麸', '花生', '味道', '芝麻', '风味', '半成品', '酸菜鱼', '味道', '店里', '四季豆', '队友'],
#  ['表示同意'],
#  ['世纪', '事情'],
#  ['风险', '区'],
#  ['奶酪',
#   '奶酪',
#   '奶酪',
#   '红酒',
#   '咖啡',
#   '啤酒',
#   '风味',
#   '食材',
#   '食物',
#   '风格',
#   '小',
#   '碟子',
#   '中式',
#   '风韵',
#   '小',
#   '杯子',
#   '有点'],
#  ['风险', '区'],
#  ['冰激凌', '雪糕', '人'],
#  ['电影', '心', '有点'],
#  ['墨鱼', '水饺', '蔬菜', '醋汁', '干酪', '咖啡', '鲜奶', '有点'],
#  ['社', '会面', '区', '地鼠'],
#  ['感觉', '朋友', '边缘', '人', '疫情', '人', '人', '心智', '常态', '节奏'],
#  ['菜才',
#   '堂食',
#   '餐饮',
#   '娱乐场所',
#   '风险',
#   '区',
#   '做饭吃',
#   '队友',
#   '鱼',
#   '皮蛋',
#   '豆腐',
#   '小米',
#   '辣',
#   '蔬菜',
#   '饼',
#   '番茄酱',
#   '蔬菜',
#   '小孩子',
#   '蔬菜'],
#  ['社', '会面', '疫情', '核酸'],
#  ['咖啡',
#   '奶茶',
#   '基地',
#   '咖啡',
#   '茶叶',
#   '鸳鸯',
#   '奶茶',
#   '咖啡',
#   '茶',
#   '配料',
#   '特调',
#   '咖啡吧',
#   '粥',
#   '化',
#   '甜品'],
#  ['菜',
#   '冷面',
#   '时候',
#   '鸡丝',
#   '凉面',
#   '玻璃',
#   '晶碗',
#   '小',
#   '雏菊',
#   '虾仁',
#   '鱼丸',
#   '油麦',
#   '菜',
#   '菜',
#   '主食',
#   '糍饭',
#   '冷面',
#   '主食',
#   '碳水'],
#  ['草',
#   '美容院',
#   '员工',
#   '员工',
#   '小时',
#   '核酸',
#   '人',
#   '小区',
#   '美容院',
#   '楼',
#   '全员',
#   '核酸',
#   '疫情',
#   '人'],
#  ['空气', '有点', '小区', '楼', '小区', '楼'],
#  ['有点', '样子', '话', '朋友', '疫情', '疫情'],
#  ['菜',
#   '椒盐',
#   '排条',
#   '粉丝',
#   '梭子蟹',
#   '菜',
#   '菜',
#   '热',
#   '味道',
#   '鸡毛',
#   '菜',
#   '辣酱',
#   '蛋炒饭',
#   '堂食',
#   '餐饮',
#   '场所',
#   '风险',
#   '区',
#   '感觉',
#   '外食'],
#  ['前三位', '书', '歌', '山楂', '叉'],
#  ['关门', '朋友', '菜', '资', '纪念'],
#  ['同款'],
#  ['食府',
#   '环宇',
#   '次堂',
#   '食',
#   '晚餐',
#   '食材',
#   '环境',
#   '人',
#   '感觉',
#   '房间',
#   '锅',
#   '火锅',
#   '疫情',
#   '肉',
#   '肉',
#   '队友',
#   '饮食',
#   '热量'],
#  ['航司', '国', '航班', '入境', '人员', '内'],
#  ['店', '店', '错', '错', '队友', '冰', '美式', '糖', '白色', '线条', '镜面', '店'],
#  ['作业', '风险', '爸妈', '需谨慎'],
#  ['次堂',
#   '食',
#   '贡献',
#   '爷爷',
#   '冰',
#   '美式',
#   '倍感',
#   '公共场合',
#   '口罩',
#   '有点',
#   '角落',
#   '桌子',
#   '感觉',
#   '大家',
#   '样子',
#   '堂食',
#   '感觉'],
#  ['脾气', '水杯', '杯子', '感觉'],
#  ['离谱', '星', '爸爸', '热', '有点', '血糖', '手指', '血糖'],
#  ['电影院', '电影'],
#  ['办事', '大家', '回家'],
#  ['菜', '茄汁', '对虾', '豆豉', '土豆', '消失'],
#  ['葱油饼'],
#  ['奶昔',
#   '有点',
#   '队友',
#   '蔬菜',
#   '火龙果',
#   '早餐',
#   '咖啡',
#   '耳',
#   '疫情',
#   '咖啡',
#   '品质',
#   '速溶',
#   '咖啡',
#   '咖啡',
#   '饮品',
#   '趣味',
#   '饮品',
#   '咖啡',
#   '文化',
#   '内涵'],
#  ['馋猫'],
#  ['户口', '购房', '资格', '小孩子', '读书会', '方', '硕士生'],
#  ['有点', '堂食', '关心', '时候'],
#  ['学会'],
#  ['菜',
#   '辣子鸡',
#   '糖醋',
#   '鳝背',
#   '葱姜',
#   '腥气',
#   '桃太郎',
#   '番茄',
#   '番茄',
#   '白菜',
#   '腐竹',
#   '油炸',
#   '豆皮',
#   '腐竹',
#   '味道'],
#  ['玩'],
#  ['站台'],
#  ['入境', '人员', '时间', '飞', '航班', '地区', '风险', '区', '旅居', '人员', '核酸', '意思', '外地'],
#  ['探店', '店里', '冰', '美式'],
#  ['煎蛋',
#   '肠',
#   '花卷',
#   '果蔬',
#   '奶昔',
#   '咖啡',
#   '花果',
#   '调性',
#   '咖啡',
#   '芒果',
#   '荔枝',
#   '风味',
#   '咖啡',
#   '风味',
#   '咖啡',
#   '风味',
#   '美式',
#   '奶',
#   '咖',
#   '原本',
#   '风味',
#   '做奶',
#   '咖的',
#   '豆子',
#   '花魁',
#   '奶',
#   '人',
#   '酒',
#   '香味',
#   '豆子',
#   '奶',
#   '咖'],
#  ['咖啡',
#   '咖啡',
#   '原液',
#   '口味',
#   '鲜奶',
#   '水',
#   '美式',
#   '铁',
#   '方',
#   '期望值',
#   '程度',
#   '风味',
#   '疫情',
#   '个位数'],
#  ['社', '会面'],
#  ['菜', '时候', '人', '人', '菜'],
#  ['人', '帖子', '人', '堂食', '办法', '堂食', '时候', '事'],
#  ['豆豉', '炒青菜', '味道', '鸡蛋', '蘑菇', '学会', '四季豆', '队友', '道菜', '菜', '堂食', '做菜'],
#  ['疫情', '做饭吃'],
#  ['电影院'],
#  ['肉包'],
#  ['晚霞', '粉色', '地方', '办事'],
#  ['年轮', '音乐', '人用', '弹簧', '耳勺', '挖耳朵', '力道', '差点', '挖耳朵', '耳朵', '音乐', '人'],
#  ['菜', '烤麸', '口感', '浓油', '赤酱', '马家', '盐水鸭', '腿', '口感'],
#  ['人', '风雅'],
#  ['效'],
#  ['骗子', '全都'],
#  ['例', '行', '航华', '区域'],
#  ['菜',
#   '小时',
#   '老鸭',
#   '火腿',
#   '汤',
#   '小土豆',
#   '咖喱',
#   '酱',
#   '咖喱',
#   '土豆',
#   '擂椒',
#   '皮蛋',
#   '时令',
#   '菜油',
#   '茭白',
#   '鸡毛',
#   '菜'],
#  ['银行', '业务'],
#  ['人', '落日'],
#  ['小时', '核酸', '排队', '小时', '大家', '核酸'],
#  ['菜', '功汤', '马家', '土豆', '牛排', '空心菜', '椰浆', '饭', '时候', '椰浆', '椰浆', '饭', '有点'],
#  ['男友', '女友', '头发', '家暴'],
#  ['咖啡', '鲜花', '美食', '电影', '电影院'],
#  ['女子', '肋骨', '骨折', '颅骨', '骨折', '创面', '瘢痕'],
#  ['早餐', '拇指', '黄瓜', '香蕉', '奶昔', '蛋', '咖啡', '疫情', '外地', '有点'],
#  ['研究生'],
#  ['午餐', '披萨', '午餐', '蔬菜', '奶油', '奶油', '面包', '披萨'],
#  ['天'],
#  ['时候', '时候', '基本上'],
#  ['波', '小区', '核酸', '月份', '课', '小区'],
#  ['队友',
#   '早餐',
#   '蛋',
#   '系统',
#   '原因',
#   '照片',
#   '无法',
#   '吐司',
#   '咖啡',
#   '果蔬',
#   '奶昔',
#   '重瓣',
#   '芍',
#   '向日葵',
#   '心情'],
#  ['大面积', '人口'],
#  ['学期'],
#  ['重症', '人', '重症', '人', '人'],
#  ['火锅', '锅', '无菌', '蛋', '料', '牛肉', '无菌', '蛋', '口感', '父亲节', '队友', '披萨'],
#  ['孩子', '狗子'],
#  ['反省'],
#  ['人', '正气'],
#  ['队友', '早餐', '咖啡', '酒香', '风味', '有点', '肉包', '浆', '肠', '鸡蛋', '果蔬', '奶昔'],
#  ['化工厂', '炸'],
#  ['全都', '小区'],
#  ['银行', '比', '核酸', '队伍'],
#  ['菜',
#   '手',
#   '包菜',
#   '猪油',
#   '猪油',
#   '渣',
#   '感觉',
#   '花椒油',
#   '百叶',
#   '结',
#   '肉',
#   '菜',
#   '酱油',
#   '菜'],
#  ['病', '有点', '女生'],
#  ['个门'],
#  ['菜',
#   '冰箱',
#   '油条',
#   '油条',
#   '虾',
#   '酱',
#   '黄油',
#   '奶油',
#   '牛奶',
#   '酱',
#   '烤肉',
#   '薄片',
#   '蒜泥',
#   '酱',
#   '豆腐',
#   '芝麻',
#   '韭菜',
#   '蘑菇'],
#  ['餐厅'],
#  ['太小'],
#  ['茶', '奶茶', '人', '人', '奶茶', '店', '开业'],
#  ['事情', '人', '女孩子', '视线', '饮料'],
#  ['饭',
#   '椰浆',
#   '椰浆',
#   '饭',
#   '盐',
#   '椰浆',
#   '水',
#   '椰浆',
#   '饭',
#   '炸',
#   '猪排',
#   '辣酱油',
#   '四季豆',
#   '油'],
#  ['原', '计划', '宝', '奶奶', '票', '条条框框'],
#  ['酸奶', '牛奶', '菌', '配料'],
#  ['证据', '过瘾', '人', '制', '黏贴'],
#  ['干酪', '成熟期', '奶味', '黄瓜', '番茄', '橄榄', '酱', '车', '香肠', '爆浆', '早餐', '咖啡', '奶昔'],
#  ['时候', '生气'],
#  ['波', '小区', '核酸'],
#  ['女生', '警觉', '无法', '想象', '后果'],
#  ['菜', '葡萄', '名字', '玻璃', '辣味', '鱼', '烤鱼'],
#  ['不争气', '眼泪', '嘴角'],
#  ['绿化带', '野草', '中草'],
#  ['核酸'],
#  ['菜',
#   '鲜肉',
#   '咸肉',
#   '火腿',
#   '百叶',
#   '结',
#   '锅',
#   '海蜇头',
#   '柠檬汁',
#   '风味',
#   '神器',
#   '种草',
#   '奶茶',
#   '马',
#   '味道'],
#  ['天堂', '酒吧'],
#  ['生气', '新闻', '宝', '数据', '生气', '紫色', '手环'],
#  ['菜', '印象', '味道', '花生', '队友', '菜', '鱿鱼', '队友', '午饭', '菜'],
#  ['土著', '国家', '动物'],
#  ['限流', '原路'],
#  ['马', '大家', '区别', '珍珠', '瀑布'],
#  ['犀牛', '海', '图', '风景', '名胜区'],
#  ['娃', '西游记', '景色', '珍珠', '瀑布', '珍珠', '珍珠', '风景', '名胜区'],
#  ['风景', '名胜区'],
#  ['箭竹', '海', '海'],
#  ['天堂'],
#  ['女儿', '女儿', '女儿'],
#  ['问题', '外地'],
#  ['瓜'],
#  ['评委'],
#  ['煙枪', '两块钱', '盐水', '冰棍'],
#  ['下午茶'],
#  ['两块钱', '绿色', '心情'],
#  ['高温', '疫情', '电', '音节', '高温', '装备', '疫情'],
#  ['感天动地',
#   '堂食',
#   '鸡蛋',
#   '虾仁',
#   '时候',
#   '眼泪',
#   '水',
#   '正餐',
#   '过瘾',
#   '冰室',
#   '甜点',
#   '晚饭',
#   '朋友',
#   '店家',
#   '服务态度',
#   '天物',
#   '空间'],
#  ['父', '爸'],
#  ['头', '关系', '实锤'],
#  ['电影院', '电影', '人', '月球', '喜剧片', '结果'],
#  ['粉丝', '专属', '背景', '粉籍', '粉丝'],
#  ['下单'],
#  ['堂食'],
#  ['馄饨',
#   '店',
#   '荠菜',
#   '纯肉',
#   '店里',
#   '桌子',
#   '牛肉',
#   '锅',
#   '钟头',
#   '鸡',
#   '小时',
#   '感觉',
#   '时候',
#   '贵',
#   '烤肉店',
#   '券用',
#   '头发'],
#  ['大众', '奶茶', '水果', '茶', '羊肉串', '味道', '价格', '丝瓜', '蛋汤', '樱花', '颜值'],
#  ['堂食', '味道', '麻麻', '肉饼', '秒杀', '饭', '堂食', '柠檬茶'],
#  ['瑕疵', '黑点'],
#  ['管长', '羊毛', '味道', '小区', '环城', '河步道', '走路', '小橘', '猫'],
#  ['场景', '系', '野猪'],
#  ['生菜', '分量'],
#  ['聚力', '视界', '微光', '类别', '重磅', '心仪', '助', '微光', '观众', '博', '视界', '大会', '微光'],
#  ['男生'],
#  ['科学', '医学', '数据'],
#  ['仙乐', '耳'],
#  ['机会'],
#  ['作品'],
#  ['短信'],
#  ['妈', '工位', '公司'],
#  ['事物'],
#  ['空腹', '小时', '证据'],
#  ['晨曦', '天空', '梦幻', '视觉', '盛宴', '大团', '大团', '云'],
#  ['人', '天空', '风', '懒猫', '咪'],
#  ['人间', '风', '梦'],
#  ['常态', '化后', '小区', '懒猫', '咪'],
#  ['硬生生', '熱', '线', '男明星', '状态'],
#  ['雨'],
#  ['核酸', '砖', '狗', '懒猫', '咪'],
#  ['核酸', '常态', '化', '晚霞'],
#  ['懒猫', '咪'],
#  ['疫情', '激情', '干的事', '封城', '花式', '店铺', '地点', '餐厅', '人', '营业', '人们'],
#  ['直升机', '环岛游', '时期', '年轻人', '婚假', '本市', '时候', '懒猫', '咪'],
#  ['大暑', '羊肉', '晚饭', '空调', '外挂', '机', '风', '轻身', '懒猫', '咪'],
#  ['老服', '毛病', '懒猫', '咪'],
#  ['小区', '核酸', '懒猫', '咪'],
#  ['退休金', '增幅', '年度', '懒猫', '咪'],
#  ['祖辈', '木船', '地方', '遗址'],
#  ['夜路', '懒猫', '咪'],
#  ['核酸', '人', '团队', '项目'],
#  ['父母', '花花草草', '懒猫', '咪'],
#  ['碎念',
#   '雨',
#   '点菜',
#   '带回家',
#   '恶心',
#   '食欲',
#   '中署',
#   '感觉',
#   '晚饭',
#   '妹夫',
#   '全家人',
#   '懒猫',
#   '咪'],
#  ['人员', '防护服', '伤感', '懒猫', '咪'],
#  ['母亲', '锅铲', '晚餐'],
#  ['雨', '风', '温度', '总算', '懒猫', '咪'],
#  ['高温',
#   '红色',
#   '高温',
#   '晨练',
#   '晚饭',
#   '散步',
#   '速度',
#   '时间',
#   '小时',
#   '走路',
#   '时',
#   '晚霞',
#   '懒猫',
#   '咪'],
#  ['衣服', '懒猫', '咪'],
#  ['炒菜', '衣裳', '眼睛', '疼'],
#  ['高温', '苦夏', '晚餐', '苦瓜', '汤'],
#  ['小时', '效果', '核酸', '排队', '排队', '懒猫', '咪'],
#  ['全员', '核酸', '高音喇叭', '高温', '红色', '中', '高风险', '区', '核酸', '时', '枝叶'],
#  ['晚饭', '小区', '核酸', '高温', '空气', '空调', '云', '日落', '高温', '疫情'],
#  ['懒猫', '咪'],
#  ['世界', '霞光', '魔幻', '暑气', '高温', '疫情', '微', '懒猫', '咪'],
#  ['小暑', '懒猫', '咪'],
#  ['疫情', '核酸', '核酸', '棒冰', '雪糕', '身价', '小时候', '毛钱', '棒冰', '懒猫', '咪'],
#  ['星空',
#   '菊',
#   '颜色',
#   '洋甘菊',
#   '鲜花',
#   '寿命',
#   '原本',
#   '鲜花',
#   '图',
#   '鲜',
#   '字',
#   '鲜',
#   '通向',
#   '路',
#   '懒猫',
#   '咪'],
#  ...]

# %%
import gensim.downloader as api
from gensim.models import TfidfModel
from gensim.corpora import Dictionary

# %%
dictionary = corpora.Dictionary(text)
dictionary.filter_extremes(no_below=2, no_above=0.8, keep_n=None)
corpus = [dictionary.doc2bow(tmp) for tmp in text]

# %%
tfidf = TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

# %%
# 困惑度的XY坐标
x_perplexity = [] 
y_perplexity = [] 
# 一致性的XY坐标
x_coherence = [] 
y_coherence = [] 
#id2word：就是上边构造的dictionary字典
#passes：模型的训练次数
for i in range(1, 31):     
    # 循环生成主题数为i的模型， passes代表模型训练次数，数据量太大了，搞小一点。     
    lda = gensim.models.ldamodel.LdaModel(corpus_tfidf, num_topics=i, id2word=dictionary, passes=10)     
    # 计算当前模型困惑度
    cur_perplexity = lda.log_perplexity(corpus_tfidf)     
    # 构造横纵坐标轴数据
    x_perplexity.append(i)
    y_perplexity.append(cur_perplexity) 
    # 计算一致性
    cv_tmp = CoherenceModel(model=lda, texts=text, dictionary=dictionary, coherence='c_v') 
    x_coherence.append(i) 
    y_coherence.append(cv_tmp.get_coherence())

# %%
# 绘制一致性折线图 
plt.plot(x_coherence, y_coherence) 
plt.xlabel('num topics') 
plt.ylabel('coherence score') 
plt.legend(('coherence_values'), loc='best') 
plt.savefig('D:\\my_research\\gensim_group\\new_3.jpg') 
plt.show()

# %%
cohen = pd.DataFrame(y_coherence, x_coherence)
cohen.to_csv('D:\my_research\gensim_group\group_coherence_3.csv',encoding="utf-8_sig")

# %%
perp =  pd.DataFrame(y_perplexity, x_perplexity)
perp.to_csv('D:\my_research\gensim_group\group_perplexity_3.csv',encoding="utf-8_sig")

# %%
lda = gensim.models.ldamodel.LdaModel(corpus_tfidf, num_topics=4, id2word=dictionary, passes=10)

# %%
pyLDAvis.enable_notebook()
data = pyLDAvis.gensim.prepare(lda, corpus_tfidf, dictionary)
# Out:
# D:\Program_Files\anaconda\lib\site-packages\pyLDAvis\_prepare.py:228: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info  = pd.DataFrame({'saliency': saliency, 'Term': vocab, \

# %%
# 可视化 html 文件路径
html_path = 'D:\\my_research\\gensim_group\\new_3_8.html'
pyLDAvis.save_html(data, html_path)
# 清屏
os.system('clear')
# 浏览器打开 html 文件以查看可视化结果
os.system(f'start {html_path}')
# Out:
# 0
